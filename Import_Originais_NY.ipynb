# %% [markdown]
# <a href="https://colab.research.google.com/github/giobritos/soul_code_projeto_final/blob/main/Import_Originais_NY.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![NY](https://storage.googleapis.com/projeto-final-agsw/Imagens/novayorkpd.jpeg)
#
# # 👮 **Importação da Base Original de Nova York**
#
# Os dados escolhidos estão disponíveis no site **NYC Open Data**, administrado pelos órgão públicos da cidade de **Nova York**, que fica nos **Estados Unidos da América**. Você tem acesso a eles [neste link](https://data.cityofnewyork.us/Public-Safety/NYPD-Complaint-Data-Historic/qgea-i56i) para consulta e download publicamente.
#
# Este conjunto de dados inclui todos os crimes válidos, contravenções e violações relatados ao **Departamento de Polícia da Cidade de Nova York** (NYPD) de 2006 até o final de 2021, para nosso estudo, utilizaremos do ano de **2018** até **2021**.
#
# Link para a documentação completa do projeto: [clique aqui](https://www.notion.so/Mindful-Data-Consultoria-d495964059c34acb9c8fe3d21dbb5cf6)

# %% [markdown]
# ## **📚 1 - Instalação e importação das bibliotecas**

# %%
# Instalador gcs
# %%capture
# %pip install gcsfs

# Conector MySQL
# %pip install mysql-connector-python
# %pip install PyMySQL

# %%
# install dependencies
import sys
# !{sys.executable} -m pip install cloud-sql-python-connector["pymysql"] SQLAlchemy

# %%
# Conexão do Storage
from google.cloud import storage

# Importa sistema operacional
import os

# Conector do MySQL
from google.cloud.sql.connector import Connector
import sqlalchemy

# Pandas
import pandas as pd

# setando configurações de display do pandas
pd.set_option('display.max_columns',100)

# %% [markdown]
# ## 🔗 **2 - Conexão com o DataLake**

# %%
# Configuração da chave de segurança
serviceAccount = '/content/projeto-final-373521-25961e56ca37.json'
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = serviceAccount

# Fazer acesso ao bucket do Cloud Storage
client = storage.Client()

# Criar uma variável para receber o nome do bucket
bucket = client.get_bucket('projeto-final-agsw')

# %% [markdown]
# ## ⚒️📑 **3 - Extração e padronização das bases de dados**

# %%
# Carregando o df pelo Pandas via GCS
df = pd.read_csv('gs://datasets-originais-agsw/ny/NYPD_Complaint_Data_Historic.csv')
# Out:
# /usr/local/lib/python3.8/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (18,20) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
# Visualizando o df
df.head(5)
# Out:
#    CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 0   506547392   03/29/2018     20:30:00          NaN          NaN
# 1   629632833   02/06/2018     23:15:00          NaN          NaN
# 2   787203902   11/21/2018     00:15:00   11/21/2018     00:20:00
# 3   280364018   06/09/2018     21:42:00   06/09/2018     21:43:00
# 4   985800320   11/10/2018     19:40:00   11/10/2018     19:45:00
#
#    ADDR_PCT_CD      RPT_DT  KY_CD                       OFNS_DESC  PD_CD  \
# 0         32.0  03/30/2018    351  CRIMINAL MISCHIEF & RELATED OF  254.0
# 1         52.0  02/07/2018    341                   PETIT LARCENY  333.0
# 2         75.0  11/21/2018    341                   PETIT LARCENY  321.0
# 3         10.0  06/10/2018    361   OFF. AGNST PUB ORD SENSBLTY &  639.0
# 4         19.0  11/10/2018    341                   PETIT LARCENY  333.0
#
#                           PD_DESC CRM_ATPT_CPTD_CD   LAW_CAT_CD    BORO_NM  \
# 0  MISCHIEF, CRIMINAL 4, OF MOTOR        COMPLETED  MISDEMEANOR  MANHATTAN
# 1  LARCENY,PETIT FROM STORE-SHOPL        COMPLETED  MISDEMEANOR      BRONX
# 2         LARCENY,PETIT FROM AUTO        COMPLETED  MISDEMEANOR   BROOKLYN
# 3         AGGRAVATED HARASSMENT 2        COMPLETED  MISDEMEANOR  MANHATTAN
# 4  LARCENY,PETIT FROM STORE-SHOPL        COMPLETED  MISDEMEANOR  MANHATTAN
#
#   LOC_OF_OCCUR_DESC                PREM_TYP_DESC        JURIS_DESC  \
# 0          FRONT OF  PARKING LOT/GARAGE (PUBLIC)  N.Y. POLICE DEPT
# 1            INSIDE             DEPARTMENT STORE  N.Y. POLICE DEPT
# 2          FRONT OF                       STREET  N.Y. POLICE DEPT
# 3            INSIDE       RESIDENCE - APT. HOUSE  N.Y. POLICE DEPT
# 4            INSIDE                  CHAIN STORE  N.Y. POLICE DEPT
#
#    JURISDICTION_CODE PARKS_NM HADEVELOPT HOUSING_PSA  X_COORD_CD  Y_COORD_CD  \
# 0                0.0      NaN        NaN         NaN   1000565.0    234704.0
# 1                0.0      NaN        NaN         NaN   1009690.0    257590.0
# 2                0.0      NaN        NaN         NaN   1016034.0    176756.0
# 3                0.0      NaN        NaN         NaN    985717.0    215911.0
# 4                0.0      NaN        NaN         NaN    992359.0    217816.0
#
#   SUSP_AGE_GROUP       SUSP_RACE SUSP_SEX  TRANSIT_DISTRICT   Latitude  \
# 0            NaN             NaN      NaN               NaN  40.810877
# 1          45-64           BLACK        F               NaN  40.873671
# 2          25-44  WHITE HISPANIC        F               NaN  40.651782
# 3          25-44  WHITE HISPANIC        M               NaN  40.759310
# 4            <18  BLACK HISPANIC        F               NaN  40.764536
#
#    Longitude                        Lat_Lon              PATROL_BORO  \
# 0 -73.941064  (40.810877241, -73.941064151)    PATROL BORO MAN NORTH
# 1 -73.908014  (40.873671035, -73.908013649)        PATROL BORO BRONX
# 2 -73.885457  (40.651782232, -73.885456761)  PATROL BORO BKLYN NORTH
# 3 -73.994706  (40.759310399, -73.994706072)    PATROL BORO MAN SOUTH
# 4 -73.970728  (40.764535539, -73.970728388)    PATROL BORO MAN NORTH
#
#   STATION_NAME VIC_AGE_GROUP        VIC_RACE VIC_SEX
# 0          NaN         25-44           WHITE       F
# 1          NaN       UNKNOWN         UNKNOWN       D
# 2          NaN       UNKNOWN         UNKNOWN       D
# 3          NaN         18-24  WHITE HISPANIC       F
# 4          NaN       UNKNOWN         UNKNOWN       D

# %%
# Checando os tipos de dados
df.dtypes
# Out:
# CMPLNT_NUM             int64
# CMPLNT_FR_DT          object
# CMPLNT_FR_TM          object
# CMPLNT_TO_DT          object
# CMPLNT_TO_TM          object
# ADDR_PCT_CD          float64
# RPT_DT                object
# KY_CD                  int64
# OFNS_DESC             object
# PD_CD                float64
# PD_DESC               object
# CRM_ATPT_CPTD_CD      object
# LAW_CAT_CD            object
# BORO_NM               object
# LOC_OF_OCCUR_DESC     object
# PREM_TYP_DESC         object
# JURIS_DESC            object
# JURISDICTION_CODE    float64
# PARKS_NM              object
# HADEVELOPT            object
# HOUSING_PSA           object
# X_COORD_CD           float64
# Y_COORD_CD           float64
# SUSP_AGE_GROUP        object
# SUSP_RACE             object
# SUSP_SEX              object
# TRANSIT_DISTRICT     float64
# Latitude             float64
# Longitude            float64
# Lat_Lon               object
# PATROL_BORO           object
# STATION_NAME          object
# VIC_AGE_GROUP         object
# VIC_RACE              object
# VIC_SEX               object
# dtype: object

# %% [markdown]
# ### ☑️ **Filtrando Data Frame**

# %%
# Analisando os tipos de crimes presentes
pd.unique(df['OFNS_DESC'])
# Out:
# array(['CRIMINAL MISCHIEF & RELATED OF', 'PETIT LARCENY',
#        'OFF. AGNST PUB ORD SENSBLTY &', 'FORGERY', 'DANGEROUS WEAPONS',
#        'ASSAULT 3 & RELATED OFFENSES', 'FELONY ASSAULT', 'GRAND LARCENY',
#        'OFFENSES AGAINST PUBLIC ADMINI', 'ROBBERY', 'HARRASSMENT 2',
#        'DANGEROUS DRUGS', 'SEX CRIMES', 'VEHICLE AND TRAFFIC LAWS',
#        'OTHER OFFENSES RELATED TO THEF', 'CRIMINAL TRESPASS',
#        'OFFENSES AGAINST THE PERSON', 'BURGLARY',
#        'POSSESSION OF STOLEN PROPERTY', 'MISCELLANEOUS PENAL LAW',
#        'ARSON', 'GRAND LARCENY OF MOTOR VEHICLE', 'RAPE',
#        'OFFENSES INVOLVING FRAUD', 'INTOXICATED & IMPAIRED DRIVING',
#        'UNAUTHORIZED USE OF A VEHICLE', 'NYS LAWS-UNCLASSIFIED FELONY',
#        'OTHER STATE LAWS (NON PENAL LA', 'FRAUDS', 'THEFT-FRAUD',
#        'ADMINISTRATIVE CODE', nan, 'OFFENSES AGAINST PUBLIC SAFETY',
#        'DISORDERLY CONDUCT', 'ANTICIPATORY OFFENSES', 'JOSTLING',
#        'KIDNAPPING & RELATED OFFENSES', 'MURDER & NON-NEGL. MANSLAUGHTER',
#        'ALCOHOLIC BEVERAGE CONTROL LAW', 'THEFT OF SERVICES',
#        "BURGLAR'S TOOLS", 'FRAUDULENT ACCOSTING', 'GAMBLING',
#        'PETIT LARCENY OF MOTOR VEHICLE',
#        'AGRICULTURE & MRKTS LAW-UNCLASSIFIED',
#        'PROSTITUTION & RELATED OFFENSES', 'CHILD ABANDONMENT/NON SUPPORT',
#        'OFFENSES RELATED TO CHILDREN', 'ENDAN WELFARE INCOMP', 'ABORTION',
#        'NYS LAWS-UNCLASSIFIED VIOLATION', 'OTHER STATE LAWS',
#        'INTOXICATED/IMPAIRED DRIVING', 'KIDNAPPING', 'ESCAPE 3',
#        'HOMICIDE-NEGLIGENT,UNCLASSIFIE', 'LOITERING/GAMBLING (CARDS, DIC',
#        'NEW YORK CITY HEALTH CODE', 'UNLAWFUL POSS. WEAP. ON SCHOOL',
#        'UNDER THE INFLUENCE OF DRUGS', 'HOMICIDE-NEGLIGENT-VEHICLE',
#        'OTHER TRAFFIC INFRACTION', 'ADMINISTRATIVE CODES',
#        'OTHER STATE LAWS (NON PENAL LAW)',
#        'DISRUPTION OF A RELIGIOUS SERV', 'FELONY SEX CRIMES',
#        'OFFENSES AGAINST MARRIAGE UNCL', 'FORTUNE TELLING',
#        'KIDNAPPING AND RELATED OFFENSES', 'LOITERING',
#        'LOITERING FOR DRUG PURPOSES', 'LOITERING/DEVIATE SEX'],
#       dtype=object)

# %% [markdown]
# **Tipos de crimes que iremos trabalhar:**
#
#
# ---
#
#
# * MURDER & NON-NEGL. MANSLAUGHTER
#
# * HOMICIDE-NEGLIGENT,UNCLASSIFIE
#
# * HOMICIDE-NEGLIGENT-VEHICLE

# %%
# Filtrando dados nulos da coluna OFNS_DESC(descrição da ocorrência)
ft_null1 = df['OFNS_DESC'].notnull()

df = df.loc[ft_null1]
df
# Out:
#          CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 0         506547392   03/29/2018     20:30:00          NaN          NaN
# 1         629632833   02/06/2018     23:15:00          NaN          NaN
# 2         787203902   11/21/2018     00:15:00   11/21/2018     00:20:00
# 3         280364018   06/09/2018     21:42:00   06/09/2018     21:43:00
# 4         985800320   11/10/2018     19:40:00   11/10/2018     19:45:00
# ...             ...          ...          ...          ...          ...
# 7825494   104527061   05/01/2008     18:55:00   05/01/2018     19:00:00
# 7825495   284201488   05/18/2018     14:50:00   05/18/2018     14:55:00
# 7825496   808565901   11/19/2018     02:25:00   11/19/2018     02:30:00
# 7825497   649441648   02/03/2018     10:02:00   02/03/2018     12:15:00
# 7825498   803166404   01/05/2018     14:40:00   01/05/2018     16:00:00
#
#          ADDR_PCT_CD      RPT_DT  KY_CD                       OFNS_DESC  \
# 0               32.0  03/30/2018    351  CRIMINAL MISCHIEF & RELATED OF
# 1               52.0  02/07/2018    341                   PETIT LARCENY
# 2               75.0  11/21/2018    341                   PETIT LARCENY
# 3               10.0  06/10/2018    361   OFF. AGNST PUB ORD SENSBLTY &
# 4               19.0  11/10/2018    341                   PETIT LARCENY
# ...              ...         ...    ...                             ...
# 7825494         10.0  05/01/2018    235                 DANGEROUS DRUGS
# 7825495        122.0  05/22/2018    344    ASSAULT 3 & RELATED OFFENSES
# 7825496        110.0  11/19/2018    109                   GRAND LARCENY
# 7825497        122.0  02/03/2018    578                   HARRASSMENT 2
# 7825498         79.0  01/08/2018    233                      SEX CRIMES
#
#          PD_CD                                PD_DESC CRM_ATPT_CPTD_CD  \
# 0        254.0         MISCHIEF, CRIMINAL 4, OF MOTOR        COMPLETED
# 1        333.0         LARCENY,PETIT FROM STORE-SHOPL        COMPLETED
# 2        321.0                LARCENY,PETIT FROM AUTO        COMPLETED
# 3        639.0                AGGRAVATED HARASSMENT 2        COMPLETED
# 4        333.0         LARCENY,PETIT FROM STORE-SHOPL        COMPLETED
# ...        ...                                    ...              ...
# 7825494  511.0         CONTROLLED SUBSTANCE, POSSESSI        COMPLETED
# 7825495  101.0                              ASSAULT 3        COMPLETED
# 7825496  421.0  LARCENY,GRAND FROM VEHICLE/MOTORCYCLE        COMPLETED
# 7825497  638.0                  HARASSMENT,SUBD 3,4,5        COMPLETED
# 7825498  175.0                       SEXUAL ABUSE 3,2        COMPLETED
#
#           LAW_CAT_CD        BORO_NM LOC_OF_OCCUR_DESC  \
# 0        MISDEMEANOR      MANHATTAN          FRONT OF
# 1        MISDEMEANOR          BRONX            INSIDE
# 2        MISDEMEANOR       BROOKLYN          FRONT OF
# 3        MISDEMEANOR      MANHATTAN            INSIDE
# 4        MISDEMEANOR      MANHATTAN            INSIDE
# ...              ...            ...               ...
# 7825494  MISDEMEANOR      MANHATTAN          FRONT OF
# 7825495  MISDEMEANOR  STATEN ISLAND               NaN
# 7825496       FELONY         QUEENS          FRONT OF
# 7825497    VIOLATION  STATEN ISLAND          FRONT OF
# 7825498  MISDEMEANOR       BROOKLYN          FRONT OF
#
#                        PREM_TYP_DESC        JURIS_DESC  JURISDICTION_CODE  \
# 0        PARKING LOT/GARAGE (PUBLIC)  N.Y. POLICE DEPT                0.0
# 1                   DEPARTMENT STORE  N.Y. POLICE DEPT                0.0
# 2                             STREET  N.Y. POLICE DEPT                0.0
# 3             RESIDENCE - APT. HOUSE  N.Y. POLICE DEPT                0.0
# 4                        CHAIN STORE  N.Y. POLICE DEPT                0.0
# ...                              ...               ...                ...
# 7825494                       STREET  N.Y. POLICE DEPT                0.0
# 7825495                       STREET  N.Y. POLICE DEPT                0.0
# 7825496                       STREET  N.Y. POLICE DEPT                0.0
# 7825497              RESIDENCE-HOUSE  N.Y. POLICE DEPT                0.0
# 7825498                       STREET  N.Y. POLICE DEPT                0.0
#
#         PARKS_NM HADEVELOPT HOUSING_PSA  X_COORD_CD  Y_COORD_CD  \
# 0            NaN        NaN         NaN   1000565.0    234704.0
# 1            NaN        NaN         NaN   1009690.0    257590.0
# 2            NaN        NaN         NaN   1016034.0    176756.0
# 3            NaN        NaN         NaN    985717.0    215911.0
# 4            NaN        NaN         NaN    992359.0    217816.0
# ...          ...        ...         ...         ...         ...
# 7825494      NaN        NaN         NaN    985209.0    214992.0
# 7825495      NaN        NaN         NaN    955828.0    149854.0
# 7825496      NaN        NaN         NaN   1022372.0    210067.0
# 7825497      NaN        NaN         NaN    959533.0    155574.0
# 7825498      NaN        NaN         NaN    999634.0    190253.0
#
#         SUSP_AGE_GROUP       SUSP_RACE SUSP_SEX  TRANSIT_DISTRICT   Latitude  \
# 0                  NaN             NaN      NaN               NaN  40.810877
# 1                45-64           BLACK        F               NaN  40.873671
# 2                25-44  WHITE HISPANIC        F               NaN  40.651782
# 3                25-44  WHITE HISPANIC        M               NaN  40.759310
# 4                  <18  BLACK HISPANIC        F               NaN  40.764536
# ...                ...             ...      ...               ...        ...
# 7825494          45-64  WHITE HISPANIC        F               NaN  40.756788
# 7825495            <18           BLACK        M               NaN  40.577953
# 7825496        UNKNOWN           WHITE        M               NaN  40.743188
# 7825497          45-64           WHITE        F               NaN  40.593665
# 7825498            NaN             NaN      NaN               NaN  40.688872
#
#          Longitude                        Lat_Lon                PATROL_BORO  \
# 0       -73.941064  (40.810877241, -73.941064151)      PATROL BORO MAN NORTH
# 1       -73.908014  (40.873671035, -73.908013649)          PATROL BORO BRONX
# 2       -73.885457  (40.651782232, -73.885456761)    PATROL BORO BKLYN NORTH
# 3       -73.994706  (40.759310399, -73.994706072)      PATROL BORO MAN SOUTH
# 4       -73.970728  (40.764535539, -73.970728388)      PATROL BORO MAN NORTH
# ...            ...                            ...                        ...
# 7825494 -73.996540  (40.756788048, -73.996539912)      PATROL BORO MAN SOUTH
# 7825495 -74.102317  (40.577953265, -74.102316756)  PATROL BORO STATEN ISLAND
# 7825496 -73.862427  (40.743188053, -73.862427079)   PATROL BORO QUEENS NORTH
# 7825497 -74.089000  (40.593664627, -74.089000194)  PATROL BORO STATEN ISLAND
# 7825498 -73.944529  (40.688872153, -73.944529032)    PATROL BORO BKLYN NORTH
#
#         STATION_NAME VIC_AGE_GROUP                  VIC_RACE VIC_SEX
# 0                NaN         25-44                     WHITE       F
# 1                NaN       UNKNOWN                   UNKNOWN       D
# 2                NaN       UNKNOWN                   UNKNOWN       D
# 3                NaN         18-24            WHITE HISPANIC       F
# 4                NaN       UNKNOWN                   UNKNOWN       D
# ...              ...           ...                       ...     ...
# 7825494          NaN       UNKNOWN                   UNKNOWN       E
# 7825495          NaN           <18            WHITE HISPANIC       M
# 7825496          NaN         25-44  ASIAN / PACIFIC ISLANDER       M
# 7825497          NaN         45-64                     WHITE       M
# 7825498          NaN           <18                     WHITE       F
#
# [7806667 rows x 35 columns]

# %%
# Filtrando o df para os casos de homicídio que iremos trabalhar
ft_crime = df['OFNS_DESC'].str.contains('MURDER|HOMICIDE')

df = df.loc[ft_crime]
df
# Out:
#          CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 1034      589015329   07/09/2018     14:25:00          NaN          NaN
# 2082      842779485   03/14/2018     05:00:00          NaN          NaN
# 2220      886259402   04/18/2018     20:40:00          NaN          NaN
# 2940      586251167   06/03/2013     21:45:00          NaN          NaN
# 3537      175402761   05/18/2018     08:05:00          NaN          NaN
# ...             ...          ...          ...          ...          ...
# 7814915   794560311   11/22/2018     03:43:00   11/22/2018     03:44:00
# 7820560   378477164   07/17/2018     19:58:00          NaN          NaN
# 7822010   166327108   10/19/2018     22:50:00   10/19/2018     23:48:00
# 7823517   522352135   03/14/2018     05:00:00          NaN          NaN
# 7824699   999874213   06/11/2018     20:34:00          NaN          NaN
#
#          ADDR_PCT_CD      RPT_DT  KY_CD                        OFNS_DESC  \
# 1034            41.0  07/09/2018    101  MURDER & NON-NEGL. MANSLAUGHTER
# 2082            73.0  03/14/2018    101  MURDER & NON-NEGL. MANSLAUGHTER
# 2220            79.0  04/18/2018    101  MURDER & NON-NEGL. MANSLAUGHTER
# 2940           104.0  06/03/2013    101  MURDER & NON-NEGL. MANSLAUGHTER
# 3537            18.0  05/18/2018    101  MURDER & NON-NEGL. MANSLAUGHTER
# ...              ...         ...    ...                              ...
# 7814915        108.0  11/22/2018    103   HOMICIDE-NEGLIGENT,UNCLASSIFIE
# 7820560         32.0  07/17/2018    101  MURDER & NON-NEGL. MANSLAUGHTER
# 7822010         32.0  10/19/2018    103   HOMICIDE-NEGLIGENT,UNCLASSIFIE
# 7823517         73.0  03/14/2018    101  MURDER & NON-NEGL. MANSLAUGHTER
# 7824699         40.0  06/11/2018    101  MURDER & NON-NEGL. MANSLAUGHTER
#
#          PD_CD                         PD_DESC CRM_ATPT_CPTD_CD LAW_CAT_CD  \
# 1034       NaN                             NaN        COMPLETED     FELONY
# 2082       NaN                             NaN        COMPLETED     FELONY
# 2220       NaN                             NaN        COMPLETED     FELONY
# 2940       NaN                             NaN        COMPLETED     FELONY
# 3537       NaN                             NaN        COMPLETED     FELONY
# ...        ...                             ...              ...        ...
# 7814915  125.0  HOMICIDE,NEGLIGENT,UNCLASSIFIE        COMPLETED     FELONY
# 7820560    NaN                             NaN        COMPLETED     FELONY
# 7822010  125.0  HOMICIDE,NEGLIGENT,UNCLASSIFIE        COMPLETED     FELONY
# 7823517    NaN                             NaN        COMPLETED     FELONY
# 7824699    NaN                             NaN        COMPLETED     FELONY
#
#            BORO_NM LOC_OF_OCCUR_DESC PREM_TYP_DESC        JURIS_DESC  \
# 1034           NaN            INSIDE           NaN             OTHER
# 2082           NaN            INSIDE           NaN  N.Y. POLICE DEPT
# 2220           NaN           OUTSIDE           NaN  N.Y. POLICE DEPT
# 2940           NaN            INSIDE           NaN  N.Y. POLICE DEPT
# 3537           NaN           OUTSIDE           NaN  N.Y. POLICE DEPT
# ...            ...               ...           ...               ...
# 7814915     QUEENS          FRONT OF        STREET  N.Y. POLICE DEPT
# 7820560        NaN           OUTSIDE           NaN  N.Y. POLICE DEPT
# 7822010  MANHATTAN          FRONT OF        STREET  N.Y. POLICE DEPT
# 7823517        NaN            INSIDE           NaN  N.Y. POLICE DEPT
# 7824699        NaN            INSIDE           NaN  N.Y. POLICE DEPT
#
#          JURISDICTION_CODE PARKS_NM HADEVELOPT HOUSING_PSA  X_COORD_CD  \
# 1034                   NaN      NaN        NaN         NaN   1017934.0
# 2082                   NaN      NaN        NaN         NaN   1009869.0
# 2220                   NaN      NaN        NaN         NaN    999636.0
# 2940                   NaN      NaN        NaN         NaN   1006551.0
# 3537                   NaN      NaN        NaN         NaN    990284.0
# ...                    ...      ...        ...         ...         ...
# 7814915                0.0      NaN        NaN         NaN   1006145.0
# 7820560                NaN      NaN        NaN         NaN   1001749.0
# 7822010                0.0      NaN        NaN         NaN   1001079.0
# 7823517                NaN      NaN        NaN         NaN   1009869.0
# 7824699                NaN      NaN        NaN         NaN   1008141.0
#
#          Y_COORD_CD SUSP_AGE_GROUP       SUSP_RACE SUSP_SEX  TRANSIT_DISTRICT  \
# 1034       232221.0          25-44  WHITE HISPANIC        M               NaN
# 2082       180290.0          25-44           BLACK        M               NaN
# 2220       192000.0            NaN             NaN      NaN               NaN
# 2940       198590.0            NaN             NaN      NaN               NaN
# 3537       214597.0          45-64           BLACK        F               NaN
# ...             ...            ...             ...      ...               ...
# 7814915    210199.0        UNKNOWN           WHITE        M               NaN
# 7820560    240971.0          25-44           BLACK        M               NaN
# 7822010    240747.0        UNKNOWN         UNKNOWN        U               NaN
# 7823517    180290.0          25-44           BLACK        M               NaN
# 7824699    234042.0          45-64           BLACK        M               NaN
#
#           Latitude  Longitude                        Lat_Lon  \
# 1034     40.804013 -73.878332  (40.804012949, -73.878331833)
# 2082     40.661502 -73.907661  (40.661502264, -73.907661037)
# 2220     40.693667 -73.944518   (40.693667261, -73.94451783)
# 2940     40.711741 -73.919560  (40.711740538, -73.919559767)
# 3537     40.755702 -73.978222  (40.755701867, -73.978221916)
# ...            ...        ...                            ...
# 7814915  40.743605 -73.920986   (40.74360542, -73.920986473)
# 7820560  40.828076 -73.936771  (40.828076123, -73.936770657)
# 7822010  40.827463 -73.939192  (40.827462608, -73.939192193)
# 7823517  40.661502 -73.907661  (40.661502264, -73.907661037)
# 7824699  40.809043 -73.913699  (40.809042997, -73.913698516)
#
#                       PATROL_BORO STATION_NAME VIC_AGE_GROUP        VIC_RACE  \
# 1034                          NaN          NaN         25-44           BLACK
# 2082                          NaN          NaN           <18           BLACK
# 2220                          NaN          NaN         25-44           BLACK
# 2940                          NaN          NaN         18-24  WHITE HISPANIC
# 3537                          NaN          NaN           <18           WHITE
# ...                           ...          ...           ...             ...
# 7814915  PATROL BORO QUEENS NORTH          NaN         18-24           WHITE
# 7820560                       NaN          NaN         18-24           BLACK
# 7822010     PATROL BORO MAN NORTH          NaN         25-44           BLACK
# 7823517                       NaN          NaN         45-64           BLACK
# 7824699                       NaN          NaN           65+         UNKNOWN
#
#         VIC_SEX
# 1034          M
# 2082          F
# 2220          M
# 2940          M
# 3537          M
# ...         ...
# 7814915       M
# 7820560       M
# 7822010       M
# 7823517       M
# 7824699       M
#
# [7049 rows x 35 columns]

# %%
# Filtrando dados nulos da coluna RPT_DT(data de registro da ocorrência)
ft_null2 = df['CMPLNT_FR_DT'].notnull()

df = df.loc[ft_null2]
df
# Out:
#          CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 1034      589015329   07/09/2018     14:25:00          NaN          NaN
# 2082      842779485   03/14/2018     05:00:00          NaN          NaN
# 2220      886259402   04/18/2018     20:40:00          NaN          NaN
# 2940      586251167   06/03/2013     21:45:00          NaN          NaN
# 3537      175402761   05/18/2018     08:05:00          NaN          NaN
# ...             ...          ...          ...          ...          ...
# 7814915   794560311   11/22/2018     03:43:00   11/22/2018     03:44:00
# 7820560   378477164   07/17/2018     19:58:00          NaN          NaN
# 7822010   166327108   10/19/2018     22:50:00   10/19/2018     23:48:00
# 7823517   522352135   03/14/2018     05:00:00          NaN          NaN
# 7824699   999874213   06/11/2018     20:34:00          NaN          NaN
#
#          ADDR_PCT_CD      RPT_DT  KY_CD                        OFNS_DESC  \
# 1034            41.0  07/09/2018    101  MURDER & NON-NEGL. MANSLAUGHTER
# 2082            73.0  03/14/2018    101  MURDER & NON-NEGL. MANSLAUGHTER
# 2220            79.0  04/18/2018    101  MURDER & NON-NEGL. MANSLAUGHTER
# 2940           104.0  06/03/2013    101  MURDER & NON-NEGL. MANSLAUGHTER
# 3537            18.0  05/18/2018    101  MURDER & NON-NEGL. MANSLAUGHTER
# ...              ...         ...    ...                              ...
# 7814915        108.0  11/22/2018    103   HOMICIDE-NEGLIGENT,UNCLASSIFIE
# 7820560         32.0  07/17/2018    101  MURDER & NON-NEGL. MANSLAUGHTER
# 7822010         32.0  10/19/2018    103   HOMICIDE-NEGLIGENT,UNCLASSIFIE
# 7823517         73.0  03/14/2018    101  MURDER & NON-NEGL. MANSLAUGHTER
# 7824699         40.0  06/11/2018    101  MURDER & NON-NEGL. MANSLAUGHTER
#
#          PD_CD                         PD_DESC CRM_ATPT_CPTD_CD LAW_CAT_CD  \
# 1034       NaN                             NaN        COMPLETED     FELONY
# 2082       NaN                             NaN        COMPLETED     FELONY
# 2220       NaN                             NaN        COMPLETED     FELONY
# 2940       NaN                             NaN        COMPLETED     FELONY
# 3537       NaN                             NaN        COMPLETED     FELONY
# ...        ...                             ...              ...        ...
# 7814915  125.0  HOMICIDE,NEGLIGENT,UNCLASSIFIE        COMPLETED     FELONY
# 7820560    NaN                             NaN        COMPLETED     FELONY
# 7822010  125.0  HOMICIDE,NEGLIGENT,UNCLASSIFIE        COMPLETED     FELONY
# 7823517    NaN                             NaN        COMPLETED     FELONY
# 7824699    NaN                             NaN        COMPLETED     FELONY
#
#            BORO_NM LOC_OF_OCCUR_DESC PREM_TYP_DESC        JURIS_DESC  \
# 1034           NaN            INSIDE           NaN             OTHER
# 2082           NaN            INSIDE           NaN  N.Y. POLICE DEPT
# 2220           NaN           OUTSIDE           NaN  N.Y. POLICE DEPT
# 2940           NaN            INSIDE           NaN  N.Y. POLICE DEPT
# 3537           NaN           OUTSIDE           NaN  N.Y. POLICE DEPT
# ...            ...               ...           ...               ...
# 7814915     QUEENS          FRONT OF        STREET  N.Y. POLICE DEPT
# 7820560        NaN           OUTSIDE           NaN  N.Y. POLICE DEPT
# 7822010  MANHATTAN          FRONT OF        STREET  N.Y. POLICE DEPT
# 7823517        NaN            INSIDE           NaN  N.Y. POLICE DEPT
# 7824699        NaN            INSIDE           NaN  N.Y. POLICE DEPT
#
#          JURISDICTION_CODE PARKS_NM HADEVELOPT HOUSING_PSA  X_COORD_CD  \
# 1034                   NaN      NaN        NaN         NaN   1017934.0
# 2082                   NaN      NaN        NaN         NaN   1009869.0
# 2220                   NaN      NaN        NaN         NaN    999636.0
# 2940                   NaN      NaN        NaN         NaN   1006551.0
# 3537                   NaN      NaN        NaN         NaN    990284.0
# ...                    ...      ...        ...         ...         ...
# 7814915                0.0      NaN        NaN         NaN   1006145.0
# 7820560                NaN      NaN        NaN         NaN   1001749.0
# 7822010                0.0      NaN        NaN         NaN   1001079.0
# 7823517                NaN      NaN        NaN         NaN   1009869.0
# 7824699                NaN      NaN        NaN         NaN   1008141.0
#
#          Y_COORD_CD SUSP_AGE_GROUP       SUSP_RACE SUSP_SEX  TRANSIT_DISTRICT  \
# 1034       232221.0          25-44  WHITE HISPANIC        M               NaN
# 2082       180290.0          25-44           BLACK        M               NaN
# 2220       192000.0            NaN             NaN      NaN               NaN
# 2940       198590.0            NaN             NaN      NaN               NaN
# 3537       214597.0          45-64           BLACK        F               NaN
# ...             ...            ...             ...      ...               ...
# 7814915    210199.0        UNKNOWN           WHITE        M               NaN
# 7820560    240971.0          25-44           BLACK        M               NaN
# 7822010    240747.0        UNKNOWN         UNKNOWN        U               NaN
# 7823517    180290.0          25-44           BLACK        M               NaN
# 7824699    234042.0          45-64           BLACK        M               NaN
#
#           Latitude  Longitude                        Lat_Lon  \
# 1034     40.804013 -73.878332  (40.804012949, -73.878331833)
# 2082     40.661502 -73.907661  (40.661502264, -73.907661037)
# 2220     40.693667 -73.944518   (40.693667261, -73.94451783)
# 2940     40.711741 -73.919560  (40.711740538, -73.919559767)
# 3537     40.755702 -73.978222  (40.755701867, -73.978221916)
# ...            ...        ...                            ...
# 7814915  40.743605 -73.920986   (40.74360542, -73.920986473)
# 7820560  40.828076 -73.936771  (40.828076123, -73.936770657)
# 7822010  40.827463 -73.939192  (40.827462608, -73.939192193)
# 7823517  40.661502 -73.907661  (40.661502264, -73.907661037)
# 7824699  40.809043 -73.913699  (40.809042997, -73.913698516)
#
#                       PATROL_BORO STATION_NAME VIC_AGE_GROUP        VIC_RACE  \
# 1034                          NaN          NaN         25-44           BLACK
# 2082                          NaN          NaN           <18           BLACK
# 2220                          NaN          NaN         25-44           BLACK
# 2940                          NaN          NaN         18-24  WHITE HISPANIC
# 3537                          NaN          NaN           <18           WHITE
# ...                           ...          ...           ...             ...
# 7814915  PATROL BORO QUEENS NORTH          NaN         18-24           WHITE
# 7820560                       NaN          NaN         18-24           BLACK
# 7822010     PATROL BORO MAN NORTH          NaN         25-44           BLACK
# 7823517                       NaN          NaN         45-64           BLACK
# 7824699                       NaN          NaN           65+         UNKNOWN
#
#         VIC_SEX
# 1034          M
# 2082          F
# 2220          M
# 2940          M
# 3537          M
# ...         ...
# 7814915       M
# 7820560       M
# 7822010       M
# 7823517       M
# 7824699       M
#
# [7049 rows x 35 columns]

# %%
# Filtrando o df para range de datas que iremos trabalhar

ftano1 = df['CMPLNT_FR_DT'].str.contains('2021')
ftano2 = df['CMPLNT_FR_DT'].str.contains('2020')
ftano3 = df['CMPLNT_FR_DT'].str.contains('2019')
ftano4 = df['CMPLNT_FR_DT'].str.contains('2018')

df = df.loc[ftano1 | ftano2 |  ftano3 | ftano4]
df
# Out:
#          CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 1034      589015329   07/09/2018     14:25:00          NaN          NaN
# 2082      842779485   03/14/2018     05:00:00          NaN          NaN
# 2220      886259402   04/18/2018     20:40:00          NaN          NaN
# 3537      175402761   05/18/2018     08:05:00          NaN          NaN
# 4155      321494527   09/10/2018     08:00:00          NaN          NaN
# ...             ...          ...          ...          ...          ...
# 7814915   794560311   11/22/2018     03:43:00   11/22/2018     03:44:00
# 7820560   378477164   07/17/2018     19:58:00          NaN          NaN
# 7822010   166327108   10/19/2018     22:50:00   10/19/2018     23:48:00
# 7823517   522352135   03/14/2018     05:00:00          NaN          NaN
# 7824699   999874213   06/11/2018     20:34:00          NaN          NaN
#
#          ADDR_PCT_CD      RPT_DT  KY_CD                        OFNS_DESC  \
# 1034            41.0  07/09/2018    101  MURDER & NON-NEGL. MANSLAUGHTER
# 2082            73.0  03/14/2018    101  MURDER & NON-NEGL. MANSLAUGHTER
# 2220            79.0  04/18/2018    101  MURDER & NON-NEGL. MANSLAUGHTER
# 3537            18.0  05/18/2018    101  MURDER & NON-NEGL. MANSLAUGHTER
# 4155            48.0  09/10/2018    101  MURDER & NON-NEGL. MANSLAUGHTER
# ...              ...         ...    ...                              ...
# 7814915        108.0  11/22/2018    103   HOMICIDE-NEGLIGENT,UNCLASSIFIE
# 7820560         32.0  07/17/2018    101  MURDER & NON-NEGL. MANSLAUGHTER
# 7822010         32.0  10/19/2018    103   HOMICIDE-NEGLIGENT,UNCLASSIFIE
# 7823517         73.0  03/14/2018    101  MURDER & NON-NEGL. MANSLAUGHTER
# 7824699         40.0  06/11/2018    101  MURDER & NON-NEGL. MANSLAUGHTER
#
#          PD_CD                         PD_DESC CRM_ATPT_CPTD_CD LAW_CAT_CD  \
# 1034       NaN                             NaN        COMPLETED     FELONY
# 2082       NaN                             NaN        COMPLETED     FELONY
# 2220       NaN                             NaN        COMPLETED     FELONY
# 3537       NaN                             NaN        COMPLETED     FELONY
# 4155       NaN                             NaN        COMPLETED     FELONY
# ...        ...                             ...              ...        ...
# 7814915  125.0  HOMICIDE,NEGLIGENT,UNCLASSIFIE        COMPLETED     FELONY
# 7820560    NaN                             NaN        COMPLETED     FELONY
# 7822010  125.0  HOMICIDE,NEGLIGENT,UNCLASSIFIE        COMPLETED     FELONY
# 7823517    NaN                             NaN        COMPLETED     FELONY
# 7824699    NaN                             NaN        COMPLETED     FELONY
#
#            BORO_NM LOC_OF_OCCUR_DESC PREM_TYP_DESC        JURIS_DESC  \
# 1034           NaN            INSIDE           NaN             OTHER
# 2082           NaN            INSIDE           NaN  N.Y. POLICE DEPT
# 2220           NaN           OUTSIDE           NaN  N.Y. POLICE DEPT
# 3537           NaN           OUTSIDE           NaN  N.Y. POLICE DEPT
# 4155           NaN            INSIDE           NaN  N.Y. POLICE DEPT
# ...            ...               ...           ...               ...
# 7814915     QUEENS          FRONT OF        STREET  N.Y. POLICE DEPT
# 7820560        NaN           OUTSIDE           NaN  N.Y. POLICE DEPT
# 7822010  MANHATTAN          FRONT OF        STREET  N.Y. POLICE DEPT
# 7823517        NaN            INSIDE           NaN  N.Y. POLICE DEPT
# 7824699        NaN            INSIDE           NaN  N.Y. POLICE DEPT
#
#          JURISDICTION_CODE PARKS_NM HADEVELOPT HOUSING_PSA  X_COORD_CD  \
# 1034                   NaN      NaN        NaN         NaN   1017934.0
# 2082                   NaN      NaN        NaN         NaN   1009869.0
# 2220                   NaN      NaN        NaN         NaN    999636.0
# 3537                   NaN      NaN        NaN         NaN    990284.0
# 4155                   NaN      NaN        NaN         NaN   1016309.0
# ...                    ...      ...        ...         ...         ...
# 7814915                0.0      NaN        NaN         NaN   1006145.0
# 7820560                NaN      NaN        NaN         NaN   1001749.0
# 7822010                0.0      NaN        NaN         NaN   1001079.0
# 7823517                NaN      NaN        NaN         NaN   1009869.0
# 7824699                NaN      NaN        NaN         NaN   1008141.0
#
#          Y_COORD_CD SUSP_AGE_GROUP       SUSP_RACE SUSP_SEX  TRANSIT_DISTRICT  \
# 1034       232221.0          25-44  WHITE HISPANIC        M               NaN
# 2082       180290.0          25-44           BLACK        M               NaN
# 2220       192000.0            NaN             NaN      NaN               NaN
# 3537       214597.0          45-64           BLACK        F               NaN
# 4155       247659.0          45-64           BLACK        M               NaN
# ...             ...            ...             ...      ...               ...
# 7814915    210199.0        UNKNOWN           WHITE        M               NaN
# 7820560    240971.0          25-44           BLACK        M               NaN
# 7822010    240747.0        UNKNOWN         UNKNOWN        U               NaN
# 7823517    180290.0          25-44           BLACK        M               NaN
# 7824699    234042.0          45-64           BLACK        M               NaN
#
#           Latitude  Longitude                        Lat_Lon  \
# 1034     40.804013 -73.878332  (40.804012949, -73.878331833)
# 2082     40.661502 -73.907661  (40.661502264, -73.907661037)
# 2220     40.693667 -73.944518   (40.693667261, -73.94451783)
# 3537     40.755702 -73.978222  (40.755701867, -73.978221916)
# 4155     40.846392 -73.884128   (40.846391886, -73.88412771)
# ...            ...        ...                            ...
# 7814915  40.743605 -73.920986   (40.74360542, -73.920986473)
# 7820560  40.828076 -73.936771  (40.828076123, -73.936770657)
# 7822010  40.827463 -73.939192  (40.827462608, -73.939192193)
# 7823517  40.661502 -73.907661  (40.661502264, -73.907661037)
# 7824699  40.809043 -73.913699  (40.809042997, -73.913698516)
#
#                       PATROL_BORO STATION_NAME VIC_AGE_GROUP VIC_RACE VIC_SEX
# 1034                          NaN          NaN         25-44    BLACK       M
# 2082                          NaN          NaN           <18    BLACK       F
# 2220                          NaN          NaN         25-44    BLACK       M
# 3537                          NaN          NaN           <18    WHITE       M
# 4155                          NaN          NaN         45-64    BLACK       F
# ...                           ...          ...           ...      ...     ...
# 7814915  PATROL BORO QUEENS NORTH          NaN         18-24    WHITE       M
# 7820560                       NaN          NaN         18-24    BLACK       M
# 7822010     PATROL BORO MAN NORTH          NaN         25-44    BLACK       M
# 7823517                       NaN          NaN         45-64    BLACK       M
# 7824699                       NaN          NaN           65+  UNKNOWN       M
#
# [1560 rows x 35 columns]

# %% [markdown]
# ##💿 **4 - Upload do arquivo original no Data Lake**

# %%
# Fazendo o load para enviar o arquivo ao GCS
df.to_csv('ny_orig.csv', index=False)

# %% [markdown]
# ###⬆️ **Envio ao Google Cloud Storage**

# %%
# Função para fazer upload de arquivo no bucket
def upload_blob(bucket, arquivo, destino):
    client = storage.Client()
    bucket = client.bucket(bucket)
    blob = bucket.blob(destino)

    blob.upload_from_filename(arquivo)

    print(
        f"Arquivo {arquivo} enviado a {destino}."
    )

# %%
# Upload do arquivo 
bucket = 'projeto-final-agsw'
arquivo = '/content/ny_orig.csv'
destino = 'originais/ny_orig.csv'
upload_blob(bucket, arquivo, destino)
# Out:
# Arquivo /content/ny_orig.csv enviado a originais/ny_orig.csv.

# %%
# Confirmando disponibilidade do arquivo pelo pandas
df1 = pd.pandas.read_csv('gs://projeto-final-agsw/originais/ny_orig.csv')
df1
# Out:
#       CMPLNT_NUM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT CMPLNT_TO_TM  \
# 0      589015329   07/09/2018     14:25:00          NaN          NaN
# 1      842779485   03/14/2018     05:00:00          NaN          NaN
# 2      886259402   04/18/2018     20:40:00          NaN          NaN
# 3      175402761   05/18/2018     08:05:00          NaN          NaN
# 4      321494527   09/10/2018     08:00:00          NaN          NaN
# ...          ...          ...          ...          ...          ...
# 1555   794560311   11/22/2018     03:43:00   11/22/2018     03:44:00
# 1556   378477164   07/17/2018     19:58:00          NaN          NaN
# 1557   166327108   10/19/2018     22:50:00   10/19/2018     23:48:00
# 1558   522352135   03/14/2018     05:00:00          NaN          NaN
# 1559   999874213   06/11/2018     20:34:00          NaN          NaN
#
#       ADDR_PCT_CD      RPT_DT  KY_CD                        OFNS_DESC  PD_CD  \
# 0            41.0  07/09/2018    101  MURDER & NON-NEGL. MANSLAUGHTER    NaN
# 1            73.0  03/14/2018    101  MURDER & NON-NEGL. MANSLAUGHTER    NaN
# 2            79.0  04/18/2018    101  MURDER & NON-NEGL. MANSLAUGHTER    NaN
# 3            18.0  05/18/2018    101  MURDER & NON-NEGL. MANSLAUGHTER    NaN
# 4            48.0  09/10/2018    101  MURDER & NON-NEGL. MANSLAUGHTER    NaN
# ...           ...         ...    ...                              ...    ...
# 1555        108.0  11/22/2018    103   HOMICIDE-NEGLIGENT,UNCLASSIFIE  125.0
# 1556         32.0  07/17/2018    101  MURDER & NON-NEGL. MANSLAUGHTER    NaN
# 1557         32.0  10/19/2018    103   HOMICIDE-NEGLIGENT,UNCLASSIFIE  125.0
# 1558         73.0  03/14/2018    101  MURDER & NON-NEGL. MANSLAUGHTER    NaN
# 1559         40.0  06/11/2018    101  MURDER & NON-NEGL. MANSLAUGHTER    NaN
#
#                              PD_DESC CRM_ATPT_CPTD_CD LAW_CAT_CD    BORO_NM  \
# 0                                NaN        COMPLETED     FELONY        NaN
# 1                                NaN        COMPLETED     FELONY        NaN
# 2                                NaN        COMPLETED     FELONY        NaN
# 3                                NaN        COMPLETED     FELONY        NaN
# 4                                NaN        COMPLETED     FELONY        NaN
# ...                              ...              ...        ...        ...
# 1555  HOMICIDE,NEGLIGENT,UNCLASSIFIE        COMPLETED     FELONY     QUEENS
# 1556                             NaN        COMPLETED     FELONY        NaN
# 1557  HOMICIDE,NEGLIGENT,UNCLASSIFIE        COMPLETED     FELONY  MANHATTAN
# 1558                             NaN        COMPLETED     FELONY        NaN
# 1559                             NaN        COMPLETED     FELONY        NaN
#
#      LOC_OF_OCCUR_DESC PREM_TYP_DESC        JURIS_DESC  JURISDICTION_CODE  \
# 0               INSIDE           NaN             OTHER                NaN
# 1               INSIDE           NaN  N.Y. POLICE DEPT                NaN
# 2              OUTSIDE           NaN  N.Y. POLICE DEPT                NaN
# 3              OUTSIDE           NaN  N.Y. POLICE DEPT                NaN
# 4               INSIDE           NaN  N.Y. POLICE DEPT                NaN
# ...                ...           ...               ...                ...
# 1555          FRONT OF        STREET  N.Y. POLICE DEPT                0.0
# 1556           OUTSIDE           NaN  N.Y. POLICE DEPT                NaN
# 1557          FRONT OF        STREET  N.Y. POLICE DEPT                0.0
# 1558            INSIDE           NaN  N.Y. POLICE DEPT                NaN
# 1559            INSIDE           NaN  N.Y. POLICE DEPT                NaN
#
#      PARKS_NM HADEVELOPT  HOUSING_PSA  X_COORD_CD  Y_COORD_CD SUSP_AGE_GROUP  \
# 0         NaN        NaN          NaN   1017934.0    232221.0          25-44
# 1         NaN        NaN          NaN   1009869.0    180290.0          25-44
# 2         NaN        NaN          NaN    999636.0    192000.0            NaN
# 3         NaN        NaN          NaN    990284.0    214597.0          45-64
# 4         NaN        NaN          NaN   1016309.0    247659.0          45-64
# ...       ...        ...          ...         ...         ...            ...
# 1555      NaN        NaN          NaN   1006145.0    210199.0        UNKNOWN
# 1556      NaN        NaN          NaN   1001749.0    240971.0          25-44
# 1557      NaN        NaN          NaN   1001079.0    240747.0        UNKNOWN
# 1558      NaN        NaN          NaN   1009869.0    180290.0          25-44
# 1559      NaN        NaN          NaN   1008141.0    234042.0          45-64
#
#            SUSP_RACE SUSP_SEX  TRANSIT_DISTRICT   Latitude  Longitude  \
# 0     WHITE HISPANIC        M               NaN  40.804013 -73.878332
# 1              BLACK        M               NaN  40.661502 -73.907661
# 2                NaN      NaN               NaN  40.693667 -73.944518
# 3              BLACK        F               NaN  40.755702 -73.978222
# 4              BLACK        M               NaN  40.846392 -73.884128
# ...              ...      ...               ...        ...        ...
# 1555           WHITE        M               NaN  40.743605 -73.920986
# 1556           BLACK        M               NaN  40.828076 -73.936771
# 1557         UNKNOWN        U               NaN  40.827463 -73.939192
# 1558           BLACK        M               NaN  40.661502 -73.907661
# 1559           BLACK        M               NaN  40.809043 -73.913699
#
#                             Lat_Lon               PATROL_BORO STATION_NAME  \
# 0     (40.804012949, -73.878331833)                       NaN          NaN
# 1     (40.661502264, -73.907661037)                       NaN          NaN
# 2      (40.693667261, -73.94451783)                       NaN          NaN
# 3     (40.755701867, -73.978221916)                       NaN          NaN
# 4      (40.846391886, -73.88412771)                       NaN          NaN
# ...                             ...                       ...          ...
# 1555   (40.74360542, -73.920986473)  PATROL BORO QUEENS NORTH          NaN
# 1556  (40.828076123, -73.936770657)                       NaN          NaN
# 1557  (40.827462608, -73.939192193)     PATROL BORO MAN NORTH          NaN
# 1558  (40.661502264, -73.907661037)                       NaN          NaN
# 1559  (40.809042997, -73.913698516)                       NaN          NaN
#
#      VIC_AGE_GROUP VIC_RACE VIC_SEX
# 0            25-44    BLACK       M
# 1              <18    BLACK       F
# 2            25-44    BLACK       M
# 3              <18    WHITE       M
# 4            45-64    BLACK       F
# ...            ...      ...     ...
# 1555         18-24    WHITE       M
# 1556         18-24    BLACK       M
# 1557         25-44    BLACK       M
# 1558         45-64    BLACK       M
# 1559           65+  UNKNOWN       M
#
# [1560 rows x 35 columns]

# %%
pd.unique(df1['OFNS_DESC'])
# Out:
# array(['MURDER & NON-NEGL. MANSLAUGHTER',
#        'HOMICIDE-NEGLIGENT,UNCLASSIFIE', 'HOMICIDE-NEGLIGENT-VEHICLE'],
#       dtype=object)

# %% [markdown]
# ###⬆️ **Envio ao Cloud SQL (MySQL)**

# %%
# Indicando parametros de conexão
INSTANCE_CONNECTION_NAME = f"projeto-final-373521:southamerica-east1:mindfull-crime"
print(f"Você se conectou a instância: {INSTANCE_CONNECTION_NAME}")
DB_USER = "root"
DB_PASS = "root"
DB_NAME = "dados-originais"
# Out:
# Você se conectou a instância: projeto-final-373521:southamerica-east1:mindfull-crime

# %%
# iniciando variável de conexão
connector = Connector()

# Gerando função de retorno da conexão
def getconn():
    conn = connector.connect(
        INSTANCE_CONNECTION_NAME,
        "pymysql",
        user=DB_USER,
        password=DB_PASS,
        db=DB_NAME
    )
    return conn

# Criando a conexão
pool = sqlalchemy.create_engine(
    "mysql+pymysql://",
    creator=getconn,
)

# %%
# Enviando para o MYSQL

# DF lesão
df.to_sql('dfny_orig', con=pool)

# %%
# Utilizando sparkSQL para verificar se as tabelas estão no banco 
pool.connect().execute("SHOW TABLES;").fetchall()
# Out:
# [('dfny_orig',),
#  ('dfsp_homicidio_orig',),
#  ('dfsp_latrocinio_orig',),
#  ('dfsp_lesao_orig',),
#  ('dfsp_policia_orig',)]

# %%
# Para limpar a conexão
connector.close()
