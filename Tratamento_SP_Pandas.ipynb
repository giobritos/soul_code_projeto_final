# %% [markdown]
# <a href="https://colab.research.google.com/github/giobritos/soul_code_projeto_final/blob/main/Tratamento_SP_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ![saopaulo](https://storage.googleapis.com/projeto-final-agsw/Imagens/saopaulo.jpeg)
# # 👮‍♀️ **Tratamento dos Data Frames de São Paulo com Pandas**
#
# Link para a documentação completa do projeto: [clique aqui](https://www.notion.so/Mindful-Data-Consultoria-d495964059c34acb9c8fe3d21dbb5cf6)

# %% [markdown]
# ## **📚 1 - Instalação e importação das bibliotecas**

# %%
# Instaladores 

# Google Cloud Storage
# %%capture
# %pip install gcsfs

# Conector MySQL
# %pip install mysql-connector-python
# %pip install PyMySQL

# Apache Beam (cada um executado individualmente e reiniciado o kernel)
#pip install --upgrade pip
#pip install apache_beam[interactive]
#pip install apache_beam[gcp]

# %%
# Conexão do Storage
from google.cloud import storage

# Importa sistema operacional
import os

# Conector do MySQL
from mysql.connector import Error
from sqlalchemy import create_engine

# Pandas
import pandas as pd

# Numpy
import numpy as np

# Matplotlib
import matplotlib.pyplot as plt

# MongoClient
from pymongo import MongoClient

# Apache Beam
import apache_beam as beam

# setando configurações de display do pandas
pd.set_option('display.max_columns',100)

# %% [markdown]
# ## 🔗 **2 - Conexão com o DataLake**

# %%
# Configuração da chave de segurança
serviceAccount = '/content/projeto-final-373521-25961e56ca37.json'
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = serviceAccount

# Fazer acesso ao bucket do Cloud Storage
client = storage.Client()

# Criar uma variável para receber o nome do bucket
bucket = client.get_bucket('projeto-final-agsw')

# %% [markdown]
# ## ⚒️ **3 - Extração das bases de dados**

# %%
# Criando variavel com endereço dos arquivos
path1 = 'gs://projeto-final-agsw/originais/homicidios_Sp_orig.xlsx'
path2 = 'gs://projeto-final-agsw/originais/latrocinio_Sp_orig.xlsx'
path3 = 'gs://projeto-final-agsw/originais/lesao_Sp_orig.xlsx'
path4 = 'gs://projeto-final-agsw/originais/policia_Sp_orig.xlsx'

# %%
# Gerando Data Frames
dfsp_hom = pd.read_excel(path1)
dfsp_lat = pd.read_excel(path2)
dfsp_les = pd.read_excel(path3)
dfsp_pol = pd.read_excel(path4)

# %%
# Fazendo Back Up dos dados
dfsp_hom_bk = dfsp_hom.copy()
dfsp_lat_bk = dfsp_lat.copy()
dfsp_les_bk = dfsp_les.copy()
dfsp_pol_bk = dfsp_pol.copy()

# %% [markdown]
# ## 🔨**4 - Padronização dos DF's**

# %% [markdown]
# ### ☑️ **Dados de homicidios dolosos**

# %%
# Visualizando dados
dfsp_hom.head(1)
# Out:
#   DEPARTAMENTO_CIRCUNSCRICAO SECCIONAL_CIRCUNSCRICAO MUNICIPIO_CIRCUNSCRICAO  \
# 0                      DECAP                  1ª SEC               São Paulo
#
#      DP_CIRCUNSCRICAO    HD  Nº DE VÍT HD  ID_DELEGACIA  MÊS ESTATISTICA  \
# 0  002 DP - Bom Retiro  1.0             1        200100                1
#
#    ANO ESTATISTICA DATAHORA_REGISTRO_BO NUM_BO  ANO_BO MUNICIPIO_ELABORACAO  \
# 0             2018           2018-01-07     16    2018              S.PAULO
#
#           DP_ELABORACAO                    SEC_ELABORACAO DEP_ELABORACAO  \
# 0  DHPP DIV. HOMICIDIOS  DHPP - DEP. HOM. PROTECAO PESSOA           DHPP
#
#    DATA_FATO HORA_FATO DESC_TIPOLOCAL                         LOGRADOURO  \
# 0 2018-01-06  20:06:00    Via pública  AVENIDA PRESIDENTE CASTELO BRANCO
#
#   NUMERO_LOGRADOURO   LATITUDE  LONGITUDE TIPO_PESSOA SEXO_PESSOA  \
# 0              6173 -23.523712 -46.606388      Vítima   Masculino
#
#    IDADE_PESSOA DATA_NASCIMENTO_PESSOA  COR_PELE PROFISSAO  NATUREZA_APURADA
# 0           NaN                    NaT  Ignorada       NaN  HOMICÍDIO DOLOSO

# %%
# Verificando nome das colunas
dfsp_hom.columns
# Out:
# Index(['DEPARTAMENTO_CIRCUNSCRICAO', 'SECCIONAL_CIRCUNSCRICAO',
#        'MUNICIPIO_CIRCUNSCRICAO', 'DP_CIRCUNSCRICAO ', 'HD', 'Nº DE VÍT HD',
#        'ID_DELEGACIA', 'MÊS ESTATISTICA', 'ANO ESTATISTICA',
#        'DATAHORA_REGISTRO_BO', 'NUM_BO', 'ANO_BO', 'MUNICIPIO_ELABORACAO',
#        'DP_ELABORACAO', 'SEC_ELABORACAO', 'DEP_ELABORACAO', 'DATA_FATO',
#        'HORA_FATO', 'DESC_TIPOLOCAL', 'LOGRADOURO', 'NUMERO_LOGRADOURO',
#        'LATITUDE', 'LONGITUDE', 'TIPO_PESSOA', 'SEXO_PESSOA', 'IDADE_PESSOA',
#        'DATA_NASCIMENTO_PESSOA', 'COR_PELE', 'PROFISSAO', 'NATUREZA_APURADA'],
#       dtype='object')

# %%
# Verificando itens diferentes
pd.unique(dfsp_hom['HD'])
# Out:
# array([ 1., nan])

# %%
pd.unique(dfsp_hom['Nº DE VÍT HD'])
# Out:
# array([1])

# %%
# Realizando drop das colunas
dfsp_hom.drop(labels=['HD',
                      'ID_DELEGACIA',
                      'MUNICIPIO_ELABORACAO',
                      'DP_ELABORACAO',
                      'SEC_ELABORACAO',
                      'DEP_ELABORACAO'], axis=1, inplace = True)

# %%
#Renomear as colunas Homicidio
dfsp_hom.rename(columns={
    'DEPARTAMENTO_CIRCUNSCRICAO': 'departamento_circunscricao', 'SECCIONAL_CIRCUNSCRICAO' : 'seccional_circunscricao',
    'MUNICIPIO_CIRCUNSCRICAO': 'cidade', 'DP_CIRCUNSCRICAO ': 'dp_circunscricao','Nº DE VÍT HD': 'n_vitimas',
    'MÊS ESTATISTICA': 'mes_ocorrencia','ANO ESTATISTICA': 'ano_ocorrencia','DATAHORA_REGISTRO_BO': 'datahora_bo',
    'NUM_BO': 'num_bo','ANO_BO': 'ano_bo','DATA_FATO': 'dt_fato','HORA_FATO': 'hora_fato','DESC_TIPOLOCAL':'tipo_local_fato',
    'LOGRADOURO': 'logradouro','NUMERO_LOGRADOURO': 'n_logradouro','LATITUDE': 'latitude','LONGITUDE': 'longitude',
    'TIPO_PESSOA':'tipo_pessoa','SEXO_PESSOA': 'sexo_pessoa','IDADE_PESSOA': 'idade_pessoa','DATA_NASCIMENTO_PESSOA': 'dt_nasc_pessoa',
    'COR_PELE': 'cor_pele','PROFISSAO':'profissao','NATUREZA_APURADA': 'tipo_crime'},inplace=True)

# %%
dfsp_hom.columns
# Out:
# Index(['departamento_circunscricao', 'seccional_circunscricao', 'cidade',
#        'dp_circunscricao', 'n_vitimas', 'mes_ocorrencia', 'ano_ocorrencia',
#        'datahora_bo', 'num_bo', 'ano_bo', 'dt_fato', 'hora_fato',
#        'tipo_local_fato', 'logradouro', 'n_logradouro', 'latitude',
#        'longitude', 'tipo_pessoa', 'sexo_pessoa', 'idade_pessoa',
#        'dt_nasc_pessoa', 'cor_pele', 'profissao', 'tipo_crime'],
#       dtype='object')

# %% [markdown]
# ### ☑️ **Dados de latrocinio**

# %%
# Visualizando dados
dfsp_lat.head(1)
# Out:
#   DEPARTAMENTO_CIRCUNSCRICAO SECCIONAL_CIRCUNSCRICAO MUNICIPIO_CIRCUNSCRICAO  \
# 0                      DECAP                  1ª SEC               São Paulo
#
#     DP_CIRCUNSCRICAO   LATRO  Nº DE VIT EM LATRO  ID_DELEGACIA  \
# 0  005 DP - Aclimação    1.0                   1         10342
#
#    MÊS ESTATISTICA  ANO ESTATISTICA DATAHORA_REGISTRO_BO  NUM_BO  ANO_BO  \
# 0                1             2018           2018-01-21     550    2018
#
#              MUNICIPIO_ELABORACAO     DP_ELABORACAO     SEC_ELABORACAO  \
# 0  S.PAULO                         78º D.P. JARDINS  DEL.SEC.1º CENTRO
#
#   DEP_ELABORACAO  DATA_FATO HORA_FATO DESC_TIPOLOCAL  \
# 0          DECAP 2018-01-21  00:02:00    Via pública
#
#                         LOGRADOURO  NUMERO_LOGRADOURO   LATITUDE  LONGITUDE  \
# 0  AVENIDA BRIGADEIRO LUIS ANTONIO             1572.0 -23.562435 -46.645048
#
#   TIPO_PESSOA SEXO_PESSOA  IDADE_PESSOA DATA_NASCIMENTO_PESSOA COR_PELE  \
# 0      Vítima   Masculino          59.0             1958-02-18   Branca
#
#     PROFISSAO NATUREZA_APURADA
# 0  JORNALISTA      LATROCÍNIO

# %%
# Verificando nome das colunas
dfsp_lat.columns
# Out:
# Index(['DEPARTAMENTO_CIRCUNSCRICAO', 'SECCIONAL_CIRCUNSCRICAO',
#        'MUNICIPIO_CIRCUNSCRICAO', 'DP_CIRCUNSCRICAO ', 'LATRO',
#        'Nº DE VIT EM LATRO', 'ID_DELEGACIA', 'MÊS ESTATISTICA',
#        'ANO ESTATISTICA', 'DATAHORA_REGISTRO_BO', 'NUM_BO', 'ANO_BO',
#        'MUNICIPIO_ELABORACAO', 'DP_ELABORACAO', 'SEC_ELABORACAO',
#        'DEP_ELABORACAO', 'DATA_FATO', 'HORA_FATO', 'DESC_TIPOLOCAL',
#        'LOGRADOURO', 'NUMERO_LOGRADOURO', 'LATITUDE', 'LONGITUDE',
#        'TIPO_PESSOA', 'SEXO_PESSOA', 'IDADE_PESSOA', 'DATA_NASCIMENTO_PESSOA',
#        'COR_PELE', 'PROFISSAO', 'NATUREZA_APURADA'],
#       dtype='object')

# %%
# Verificando itens diferentes
pd.unique(dfsp_lat['LATRO'])
# Out:
# array([ 1., nan,  0.])

# %%
pd.unique(dfsp_lat['Nº DE VIT EM LATRO'])
# Out:
# array([1])

# %%
# Realizando drop das colunas
dfsp_lat.drop(labels=['LATRO',
                      'ID_DELEGACIA',
                      'MUNICIPIO_ELABORACAO',
                      'DP_ELABORACAO',
                      'SEC_ELABORACAO',
                      'DEP_ELABORACAO'], axis=1, inplace = True)

# %%
#Renomear as colunas lATROCINIO
dfsp_lat.rename(columns={
    'DEPARTAMENTO_CIRCUNSCRICAO': 'departamento_circunscricao', 'SECCIONAL_CIRCUNSCRICAO' : 'seccional_circunscricao',
    'MUNICIPIO_CIRCUNSCRICAO': 'cidade', 'DP_CIRCUNSCRICAO ': 'dp_circunscricao','Nº DE VIT EM LATRO': 'n_vitimas',
    'MÊS ESTATISTICA': 'mes_ocorrencia','ANO ESTATISTICA': 'ano_ocorrencia','DATAHORA_REGISTRO_BO': 'datahora_bo',
    'NUM_BO': 'num_bo','ANO_BO': 'ano_bo','DATA_FATO': 'dt_fato','HORA_FATO': 'hora_fato','DESC_TIPOLOCAL':'tipo_local_fato',
    'LOGRADOURO': 'logradouro','NUMERO_LOGRADOURO': 'n_logradouro','LATITUDE': 'latitude','LONGITUDE': 'longitude',
    'TIPO_PESSOA':'tipo_pessoa','SEXO_PESSOA': 'sexo_pessoa','IDADE_PESSOA': 'idade_pessoa','DATA_NASCIMENTO_PESSOA': 'dt_nasc_pessoa',
    'COR_PELE': 'cor_pele','PROFISSAO':'profissao','NATUREZA_APURADA': 'tipo_crime'},inplace=True)

# %%
# Verificando alterações
dfsp_lat.columns
# Out:
# Index(['departamento_circunscricao', 'seccional_circunscricao', 'cidade',
#        'dp_circunscricao', 'n_vitimas', 'mes_ocorrencia', 'ano_ocorrencia',
#        'datahora_bo', 'num_bo', 'ano_bo', 'dt_fato', 'hora_fato',
#        'tipo_local_fato', 'logradouro', 'n_logradouro', 'latitude',
#        'longitude', 'tipo_pessoa', 'sexo_pessoa', 'idade_pessoa',
#        'dt_nasc_pessoa', 'cor_pele', 'profissao', 'tipo_crime'],
#       dtype='object')

# %% [markdown]
# ### ☑️ **Dados de Lesão corporal seguida de morte**

# %%
# Visualizando dados
dfsp_les.head(1)
# Out:
#   DEPARTAMENTO_CIRCUNSCRICAO SECCIONAL_CIRCUNSCRICAO MUNICIPIO_CIRCUNSCRICAO  \
# 0                      DECAP                  5ª SEC               São Paulo
#
#        DP_CIRCUNSCRICAO  LCSM  Unnamed: 5 ID_DELEGACIA  MÊS ESTATISTICA  \
# 0  056 DP - Vila Alpina     1         NaN        10310                1
#
#    ANO ESTATISTICA DATAHORA_REGISTRO_BO NUM_BO ANO_BO MUNICIPIO_ELABORACAO  \
# 0             2017  2017-01-05 00:00:00     74   2017              S.PAULO
#
#           DP_ELABORACAO    SEC_ELABORACAO DEP_ELABORACAO            DATA_FATO  \
# 0  56º D.P. VILA ALPINA  DEL.SEC.5º LESTE          DECAP  2017-01-05 00:00:00
#
#   HORA_FATO DESC_TIPOLOCAL                 LOGRADOURO NUMERO_LOGRADOURO  \
# 0  08:10:00          Saúde  AVENIDA FRANCISCO FALCONI              1501
#
#   LATITUDE LONGITUDE TIPO_PESSOA SEXO_PESSOA IDADE_PESSOA  \
# 0      NaN       NaN      Vítima    Feminino           32
#
#   DATA_NASCIMENTO_PESSOA COR_PELE    PROFISSAO  \
# 0    1984-12-06 00:00:00    Parda  VENDEDOR(A)
#
#                   NATUREZA_APURADA
# 0  LESÃO CORPORAL SEGUIDA DE MORTE

# %%
# Verificando nome das colunas
dfsp_les.columns
# Out:
# Index(['DEPARTAMENTO_CIRCUNSCRICAO', 'SECCIONAL_CIRCUNSCRICAO',
#        'MUNICIPIO_CIRCUNSCRICAO', 'DP_CIRCUNSCRICAO', 'LCSM', 'Unnamed: 5',
#        'ID_DELEGACIA', 'MÊS ESTATISTICA', 'ANO ESTATISTICA',
#        'DATAHORA_REGISTRO_BO', 'NUM_BO', 'ANO_BO', 'MUNICIPIO_ELABORACAO',
#        'DP_ELABORACAO', 'SEC_ELABORACAO', 'DEP_ELABORACAO', 'DATA_FATO',
#        'HORA_FATO', 'DESC_TIPOLOCAL', 'LOGRADOURO', 'NUMERO_LOGRADOURO',
#        'LATITUDE', 'LONGITUDE', 'TIPO_PESSOA', 'SEXO_PESSOA', 'IDADE_PESSOA',
#        'DATA_NASCIMENTO_PESSOA', 'COR_PELE', 'PROFISSAO', 'NATUREZA_APURADA'],
#       dtype='object')

# %%
# Verificando dados das colunas
pd.unique(dfsp_les['LCSM'])
# Out:
# array([1])

# %%
# Realizando drop das colunas
dfsp_les.drop(labels=['LCSM',
                      'ID_DELEGACIA',
                      'MUNICIPIO_ELABORACAO',
                      'DP_ELABORACAO',
                      'SEC_ELABORACAO',
                      'DEP_ELABORACAO'], axis=1, inplace = True)

# %%
# verificando se foi dropada
dfsp_les.columns
# Out:
# Index(['DEPARTAMENTO_CIRCUNSCRICAO', 'SECCIONAL_CIRCUNSCRICAO',
#        'MUNICIPIO_CIRCUNSCRICAO', 'DP_CIRCUNSCRICAO', 'Unnamed: 5',
#        'MÊS ESTATISTICA', 'ANO ESTATISTICA', 'DATAHORA_REGISTRO_BO', 'NUM_BO',
#        'ANO_BO', 'DATA_FATO', 'HORA_FATO', 'DESC_TIPOLOCAL', 'LOGRADOURO',
#        'NUMERO_LOGRADOURO', 'LATITUDE', 'LONGITUDE', 'TIPO_PESSOA',
#        'SEXO_PESSOA', 'IDADE_PESSOA', 'DATA_NASCIMENTO_PESSOA', 'COR_PELE',
#        'PROFISSAO', 'NATUREZA_APURADA'],
#       dtype='object')

# %%
# Renomeando colunas
dfsp_les.rename(columns={'DEPARTAMENTO_CIRCUNSCRICAO': 'departamento_circunscricao',
                         'SECCIONAL_CIRCUNSCRICAO' : 'seccional_circunscricao',
                         'MUNICIPIO_CIRCUNSCRICAO': 'cidade', 
                         'DP_CIRCUNSCRICAO': 'dp_circunscricao',
                         'Unnamed: 5': 'n_vitimas',
                         'MÊS ESTATISTICA': 'mes_ocorrencia',
                         'ANO ESTATISTICA': 'ano_ocorrencia',
                         'DATAHORA_REGISTRO_BO': 'datahora_bo',
                         'NUM_BO': 'num_bo',
                         'ANO_BO': 'ano_bo',
                         'DATA_FATO': 'dt_fato',
                         'HORA_FATO': 'hora_fato',
                         'DESC_TIPOLOCAL':'tipo_local_fato',
                         'LOGRADOURO': 'logradouro',
                         'NUMERO_LOGRADOURO': 'n_logradouro',
                         'LATITUDE': 'latitude',
                         'LONGITUDE': 'longitude',
                         'TIPO_PESSOA':'tipo_pessoa',
                         'SEXO_PESSOA': 'sexo_pessoa',
                         'IDADE_PESSOA': 'idade_pessoa',
                         'DATA_NASCIMENTO_PESSOA': 'dt_nasc_pessoa',
                         'COR_PELE': 'cor_pele',
                         'PROFISSAO':'profissao',
                         'NATUREZA_APURADA': 'tipo_crime'
                         
}, inplace = True)

# %%
# verificando se foi dropada
dfsp_les.columns
# Out:
# Index(['departamento_circunscricao', 'seccional_circunscricao', 'cidade',
#        'dp_circunscricao', 'n_vitimas', 'mes_ocorrencia', 'ano_ocorrencia',
#        'datahora_bo', 'num_bo', 'ano_bo', 'dt_fato', 'hora_fato',
#        'tipo_local_fato', 'logradouro', 'n_logradouro', 'latitude',
#        'longitude', 'tipo_pessoa', 'sexo_pessoa', 'idade_pessoa',
#        'dt_nasc_pessoa', 'cor_pele', 'profissao', 'tipo_crime'],
#       dtype='object')

# %% [markdown]
# ### ☑️ **Dados de morte decorrente de intervenção policial**

# %%
# Verificando Data Frame
dfsp_pol.head(5)
# Out:
#         DEPARTAMENTO_CIRCUNSCRICAO  SECCIONAL_CIRCUNSCRICAO  \
# 0                          DEMACRO  DEL.SEC.TABOÃO DA SERRA
# 1                          DEMACRO      DEL.SEC.SANTO ANDRÉ
# 2  DEINTER 1 - SAO JOSE DOS CAMPOS      DEL.SEC.S.SEBASTIAO
# 3           DEINTER 9 - PIRACICABA        DEL.SEC.RIO CLARO
# 4                            DECAP           DEL.SEC.2º SUL
#
#   MUNICIPIO_CIRCUNSCRICAO             DP_CIRCUNSCRICAO  COORPORAÇÃO SITUAÇÃO  \
# 0    ITAPECERICA DA SERRA  DEL.POL.ITAPECERICA DA SERRA          PM    folga
# 1                 S.ANDRE          06º D.P. SANTO ANDRÉ          PM  serviço
# 2                 UBATUBA               DEL.POL.UBATUBA          PM  serviço
# 3               RIO CLARO            01º D.P. RIO CLARO          PM  serviço
# 4                 S.PAULO       97º D.P. AMERICANOPOLIS          PM  serviço
#
#   ID_DELEGACIA  MÊS ESTATISTICA  ANO ESTATISTICA DATAHORA_REGISTRO_BO NUM_BO  \
# 0        30406                1             2017  2017-01-01 00:00:00      1
# 1        30105                1             2017  2017-01-01 00:00:00     15
# 2        40304                1             2017  2017-01-03 00:00:00     64
# 3        70924                1             2017  2017-01-03 00:00:00     88
# 4       200100                1             2017  2017-01-04 00:00:00      8
#
#   ANO_BO  MUNICIPIO_ELABORACAO                 DP_ELABORACAO  \
# 0   2017  ITAPECERICA DA SERRA  DEL.POL.ITAPECERICA DA SERRA
# 1   2017               S.ANDRE          04º D.P. SANTO ANDRÉ
# 2   2017               UBATUBA               DEL.POL.UBATUBA
# 3   2017             RIO CLARO     DEL.SEC.RIO CLARO PLANTÃO
# 4   2017               S.PAULO          DHPP DIV. HOMICIDIOS
#
#                      SEC_ELABORACAO                   DEP_ELABORACAO  \
# 0           DEL.SEC.TABOÃO DA SERRA                          DEMACRO
# 1               DEL.SEC.SANTO ANDRÉ                          DEMACRO
# 2               DEL.SEC.S.SEBASTIAO  DEINTER 1 - SAO JOSE DOS CAMPOS
# 3                 DEL.SEC.RIO CLARO           DEINTER 9 - PIRACICABA
# 4  DHPP - DEP. HOM. PROTECAO PESSOA                             DHPP
#
#              DATA_FATO HORA_FATO    DESC_TIPOLOCAL  \
# 0  2017-01-01 00:00:00  01:00:00       Via pública
# 1  2017-01-01 00:00:00  16:00:00  Area não ocupada
# 2  2017-01-02 00:00:00  22:00:00       Via pública
# 3  2017-01-02 00:00:00  23:55:00       Via pública
# 4  2017-01-03 00:00:00  22:55:00        Residência
#
#                                       LOGRADOURO NUMERO_LOGRADOURO   LATITUDE  \
# 0                     RUA JULIO MANOEL DE ARAUJO               218 -23.703543
# 1                             RUA SAGUI DA SERRA               861 -23.741765
# 2                                     RUA CRAVOS                 0  -23.43665
# 3                                         RUA 17                 0 -22.415139
# 4  DA VEDAÇÃO DA DIVULGAÇÃO DOS DADOS RELATIVOS                NaN        NaN
#
#    LONGITUDE   TIPO_PESSOA SEXO_PESSOA IDADE_PESSOA DATA_NASCIMENTO_PESSOA  \
# 0  -46.80364  Autor/Vitima   Masculino           27    1989-01-07 00:00:00
# 1 -46.475464  Autor/Vitima   Masculino           27    1989-05-08 00:00:00
# 2 -45.088326  Autor/Vitima   Masculino          NaN                    NaN
# 3 -47.555497        Vítima   Masculino           22    1994-01-24 00:00:00
# 4        NaN  Autor/Vitima   Masculino          NaN                    NaN
#
#   COR_PELE         PROFISSAO                          NATUREZA_APURADA
# 0    Parda  GUARDA MUNICIPAL  MORTE DECORRENTE DE INTERVENÇÃO POLICIAL
# 1   Branca               NaN  MORTE DECORRENTE DE INTERVENÇÃO POLICIAL
# 2   Branca               NaN  MORTE DECORRENTE DE INTERVENÇÃO POLICIAL
# 3   Branca   DESEMPREGADO(A)  MORTE DECORRENTE DE INTERVENÇÃO POLICIAL
# 4    Parda               NaN  MORTE DECORRENTE DE INTERVENÇÃO POLICIAL

# %%
sorted(pd.unique(dfsp_pol['MUNICIPIO_CIRCUNSCRICAO']))
# Out:
# ['AGUAI',
#  'AGUAS DE S. BARBARA',
#  'AGUDOS',
#  'ALTAIR',
#  'ALVARES MACHADO',
#  'ALVINLÂNDIA',
#  'AMERICANA',
#  'ARACARIGUAMA',
#  'ARACATUBA',
#  'ARAPEI',
#  'ARARAQUARA',
#  'ARARAS',
#  'ARIRANHA',
#  'ARTUR NOGUEIRA',
#  'ARUJA',
#  'ASSIS',
#  'ATIBAIA',
#  'AVARE',
#  'BADY BASSIT',
#  'BARRA BONITA',
#  'BARRETOS',
#  'BARRINHA',
#  'BARUERI',
#  'BASTOS',
#  'BATATAIS',
#  'BAURU',
#  'BEBEDOURO',
#  'BERTIOGA',
#  'BIRITIBA-MIRIM',
#  'BOFETE',
#  'BOITUVA',
#  'BOM JESUS DOS PERDOES',
#  'BOTUCATU',
#  'BRAGANCA PAULISTA',
#  'BURITAMA',
#  'CABRÁLIA PAULISTA',
#  'CACAPAVA',
#  'CAFELANDIA',
#  'CAIEIRAS',
#  'CAJAMAR',
#  'CAJATI',
#  'CAMPINAS',
#  'CAMPO LIMPO PAULISTA',
#  'CAMPOS DO JORDAO',
#  'CAMPOS NOVOS PAUL.',
#  'CANANEIA',
#  'CANDIDO MOTA',
#  'CAPELA DO ALTO',
#  'CAPIVARI',
#  'CARAGUATATUBA',
#  'CARAPICUIBA',
#  'CASA BRANCA',
#  'CATANDUVA',
#  'CATIGUA',
#  'CEDRAL',
#  'CERQUILHO',
#  'CHARQUEADA',
#  'CONCHAL',
#  'CORONEL MACEDO',
#  'CORUMBATAI',
#  'COSMOPOLIS',
#  'COTIA',
#  'CRIME MILITAR',
#  'CRUZEIRO',
#  'CUBATAO',
#  'DESCALVADO',
#  'DIADEMA',
#  'ELDORADO',
#  'ELIAS FAUSTO',
#  'ELISIÁRIO',
#  'EMBU',
#  'EMBU-GUACU',
#  'ENGENHEIRO COELHO',
#  'ESPIRITO STO. PINHAL',
#  'FARTURA',
#  'FERNANDOPOLIS',
#  'FERRAZ DE VASCONCELOS',
#  'FRANCA',
#  'FRANCISCO MORATO',
#  'FRANCO DA ROCHA',
#  'GAVIAO PEIXOTO',
#  'GAVIÃO PEIXOTO',
#  'GUAIRA',
#  'GUARARAPES',
#  'GUARAREMA',
#  'GUARATINGUETA',
#  'GUAREI',
#  'GUARUJA',
#  'GUARULHOS',
#  'GUARÁ',
#  'GUZOLÂNDIA',
#  'HORTOLANDIA',
#  'IACRI',
#  'IBATÉ',
#  'IBIRA',
#  'IBIUNA',
#  'IEPÊ',
#  'IGARATA',
#  'ILHA COMPRIDA',
#  'INDAIATUBA',
#  'INUBIA PAULISTA',
#  'IPERO',
#  'IPERÓ',
#  'IPEUNA',
#  'ITAI',
#  'ITANHAEM',
#  'ITAPECERICA DA SERRA',
#  'ITAPETININGA',
#  'ITAPEVA',
#  'ITAPEVI',
#  'ITAPIRA',
#  'ITAQUAQUECETUBA',
#  'ITARIRI',
#  'ITATIBA',
#  'ITIRAPINA',
#  'ITU',
#  'ITUPEVA',
#  'JABOTICABAL',
#  'JACAREI',
#  'JACI',
#  'JACUPIRANGA',
#  'JAGUARIUNA',
#  'JAMBEIRO',
#  'JANDIRA',
#  'JARDINOPOLIS',
#  'JARINU',
#  'JAU',
#  'JUNDIAI',
#  'JUQUITIBA',
#  'LARANJAL PAULISTA',
#  'LAVINIA',
#  'LAVRINHAS',
#  'LEME',
#  'LIMEIRA',
#  'LINS',
#  'LORENA',
#  'LOURENÇO DA SERRA',
#  'LOUVEIRA',
#  'MACATUBA',
#  'MAIRINQUE',
#  'MAIRIPORA',
#  'MARILIA',
#  'MARTINOPOLIS',
#  'MATAO',
#  'MAUA',
#  'MINEIROS DO TIETE',
#  'MIRACATU',
#  'MOGI DAS CRUZES',
#  'MOGI-GUACU',
#  'MOGI-MIRIM',
#  'MOMBUCA',
#  'MONGAGUA',
#  'MONTE APRAZIVEL',
#  'MONTE MOR',
#  'MORRO AGUDO',
#  'NAZARE PAULISTA',
#  'NEVES PAULISTA',
#  'NOVA ALIANCA',
#  'NOVA ODESSA',
#  'OLIMPIA',
#  'ONDA VERDE',
#  'OSASCO',
#  'OURINHOS',
#  'PALMITAL',
#  'PANORAMA',
#  'PARIQUERA-ACU',
#  'PAULICEIA',
#  'PAULINIA',
#  'PAULO DE FARIA',
#  'PEDERNEIRAS',
#  'PEDREGULHO',
#  'PEDRO DE TOLEDO',
#  'PERUIBE',
#  'PIEDADE',
#  'PILAR DO SUL',
#  'PINDAMONHANGABA',
#  'PIQUETE',
#  'PIRACICABA',
#  'PIRAPORA DO BOM JESUS',
#  'POA',
#  'POLONI',
#  'PONGAI',
#  'PONTAL',
#  'PORTO FELIZ',
#  'PORTO FERREIRA',
#  'PRACINHA',
#  'PRADOPOLIS',
#  'PRAIA GRANDE',
#  'PRESIDENTE PRUDENTE',
#  'Policia Federal',
#  'QUATA',
#  'REGISTRADO EM (MG)',
#  'REGISTRADO NA PF',
#  'REGISTRADO NA PF - BO 206/17',
#  'REGISTRO',
#  'RIBEIRAO BRANCO',
#  'RIBEIRAO GRANDE',
#  'RIBEIRAO PIRES',
#  'RIBEIRAO PRETO',
#  'RIFAINA',
#  'RINCAO',
#  'RINOPOLIS',
#  'RIO CLARO',
#  'RIO GRANDE DA SERRA',
#  'ROSANA',
#  'S.ANDRE',
#  'S.BARBARA D OESTE',
#  'S.BERNARDO DO CAMPO',
#  'S.CAETANO DO SUL',
#  'S.CARLOS',
#  'S.CRUZ DAS PALMEIRAS',
#  'S.ISABEL',
#  'S.JOSE DO RIO PRETO',
#  'S.JOSE DOS CAMPOS',
#  'S.LUIS DO PARAITINGA',
#  'S.PAULO',
#  'S.PEDRO',
#  'S.ROQUE',
#  'S.SEBASTIAO',
#  'S.SIMAO',
#  'S.VICENTE',
#  'SABINO',
#  'SALESOPOLIS',
#  'SALTO',
#  'SALTO DE PIRAPORA',
#  'SANTANA DE PARNAIBA',
#  'SANTOS',
#  'SAO JOAO DA BOA VISTA',
#  'SERRA NEGRA',
#  'SERRANA',
#  'SERTAOZINHO',
#  'SETE BARRAS',
#  'SOCORRO',
#  'SOROCABA',
#  'SUMARE',
#  'SUZANO',
#  'SÃO MANUEL',
#  'TABOAO DA SERRA',
#  'TANABI',
#  'TAQUARITINGA',
#  'TAQUARITUBA',
#  'TATUI',
#  'TAUBATE',
#  'TERRA ROXA',
#  'TIETE',
#  'TORRINHA',
#  'TREMEMBE',
#  'TUPA',
#  'UBATUBA',
#  'UCHOA',
#  'VALINHOS',
#  'VARGEM',
#  'VARGEM GRANDE PAULISTA',
#  'VARZEA PAULISTA',
#  'VOTORANTIM']

# %%
# Verificando colunas
dfsp_pol.columns
# Out:
# Index(['DEPARTAMENTO_CIRCUNSCRICAO', 'SECCIONAL_CIRCUNSCRICAO',
#        'MUNICIPIO_CIRCUNSCRICAO', 'DP_CIRCUNSCRICAO ', 'COORPORAÇÃO',
#        'SITUAÇÃO', 'ID_DELEGACIA', 'MÊS ESTATISTICA', 'ANO ESTATISTICA',
#        'DATAHORA_REGISTRO_BO', 'NUM_BO', 'ANO_BO', 'MUNICIPIO_ELABORACAO',
#        'DP_ELABORACAO', 'SEC_ELABORACAO', 'DEP_ELABORACAO', 'DATA_FATO',
#        'HORA_FATO', 'DESC_TIPOLOCAL', 'LOGRADOURO', 'NUMERO_LOGRADOURO',
#        'LATITUDE', 'LONGITUDE', 'TIPO_PESSOA', 'SEXO_PESSOA', 'IDADE_PESSOA',
#        'DATA_NASCIMENTO_PESSOA', 'COR_PELE', 'PROFISSAO', 'NATUREZA_APURADA'],
#       dtype='object')

# %%
# Realizando drop das colunas
dfsp_pol.drop(labels=['ID_DELEGACIA',
                      'MUNICIPIO_ELABORACAO',
                      'DP_ELABORACAO',
                      'SEC_ELABORACAO',
                      'DEP_ELABORACAO'], axis=1, inplace = True)

# %%
# Verificando modificação
dfsp_pol.columns
# Out:
# Index(['DEPARTAMENTO_CIRCUNSCRICAO', 'SECCIONAL_CIRCUNSCRICAO',
#        'MUNICIPIO_CIRCUNSCRICAO', 'DP_CIRCUNSCRICAO ', 'COORPORAÇÃO',
#        'SITUAÇÃO', 'MÊS ESTATISTICA', 'ANO ESTATISTICA',
#        'DATAHORA_REGISTRO_BO', 'NUM_BO', 'ANO_BO', 'DATA_FATO', 'HORA_FATO',
#        'DESC_TIPOLOCAL', 'LOGRADOURO', 'NUMERO_LOGRADOURO', 'LATITUDE',
#        'LONGITUDE', 'TIPO_PESSOA', 'SEXO_PESSOA', 'IDADE_PESSOA',
#        'DATA_NASCIMENTO_PESSOA', 'COR_PELE', 'PROFISSAO', 'NATUREZA_APURADA'],
#       dtype='object')

# %%
# Renomeando colunas
dfsp_pol.rename(columns={'DEPARTAMENTO_CIRCUNSCRICAO': 'departamento_circunscricao',
                         'SECCIONAL_CIRCUNSCRICAO' : 'seccional_circunscricao',
                         'MUNICIPIO_CIRCUNSCRICAO': 'cidade', 
                         'DP_CIRCUNSCRICAO ': 'dp_circunscricao',
                         'MÊS ESTATISTICA': 'mes_ocorrencia',
                         'ANO ESTATISTICA': 'ano_ocorrencia',
                         'DATAHORA_REGISTRO_BO': 'datahora_bo',
                         'NUM_BO': 'num_bo',
                         'ANO_BO': 'ano_bo',
                         'DATA_FATO': 'dt_fato',
                         'HORA_FATO': 'hora_fato',
                         'DESC_TIPOLOCAL':'tipo_local_fato',
                         'LOGRADOURO': 'logradouro',
                         'NUMERO_LOGRADOURO': 'n_logradouro',
                         'LATITUDE': 'latitude',
                         'LONGITUDE': 'longitude',
                         'TIPO_PESSOA':'tipo_pessoa',
                         'SEXO_PESSOA': 'sexo_pessoa',
                         'IDADE_PESSOA': 'idade_pessoa',
                         'DATA_NASCIMENTO_PESSOA': 'dt_nasc_pessoa',
                         'COR_PELE': 'cor_pele',
                         'PROFISSAO':'profissao',
                         'NATUREZA_APURADA': 'tipo_crime',
                         'COORPORAÇÃO':'corporacao_policial',
                         'SITUAÇÃO':'situacao_policial'
                         
}, inplace = True)

# %%
# Verificando modificação
dfsp_pol.columns
# Out:
# Index(['departamento_circunscricao', 'seccional_circunscricao', 'cidade',
#        'dp_circunscricao', 'corporacao_policial', 'situacao_policial',
#        'mes_ocorrencia', 'ano_ocorrencia', 'datahora_bo', 'num_bo', 'ano_bo',
#        'dt_fato', 'hora_fato', 'tipo_local_fato', 'logradouro', 'n_logradouro',
#        'latitude', 'longitude', 'tipo_pessoa', 'sexo_pessoa', 'idade_pessoa',
#        'dt_nasc_pessoa', 'cor_pele', 'profissao', 'tipo_crime'],
#       dtype='object')

# %%
#Renomeando Cidade
dfsp_pol.replace({'S.PAULO': 'São Paulo'}, inplace=True)

# %%
#Renomeando DPs
dfsp_pol.replace({'01º D.P. SE':'001 DP - Sé','03º D.P. CAMPOS ELISEOS':'003 DP - Campos Elíseos',
                   '04º D.P. CONSOLAÇÃO':'004 DP - Consolação','05º D.P., ACLIMACAO':'005 DP - Aclimação','06º D.P. CAMBUCI':'006 DP - Cambuci',
                   '07º D.P. LAPA':'007 DP - Lapa','08º D.P. BRAS':'008 DP - Brás', '09º D.P. - CARANDIRU':'009 DP - Carandiru',
                   '100º D.P. JDIM HERCULANO':'100 DP - Jardim Herculano','101º D.P. JDIM IMBUIAS':'101 DP - Jardim das Imbuias',
                   '102º D.P. SOCORRO':'102 DP - Socorro','103º D.P. COHABII/ITAQU.':'103 DP - Cohab Itaquera',
                   '10º D.P. PENHA DE FRANCA':'010 DP - Penha de França','11º D.P. SANTO AMARO':'011 DP - Santo Amaro',
                   '12º D.P. PARI':'012 DP - Pari','13º D.P. CASA VERDE':'013 DP - Casa Verde',
                   '14º D.P. PINHEIROS':'014 DP - Pinheiros','15ª DP DR LUCIANO H BEIGUELMAN':'015 DP - Itaim Bibi','15º D.P. DR. LUC. H BEIGUELMAN':'015 DP - Itaim Bibi',
                   '16º D.P. VILA CLEMENTINO':'016 DP - Vila Clementino','17º D.P. DOUTOR ALDO GALIANO':'017 DP - Ipiranga','18º D.P. ALTO DA MOOCA':'018 DP - Alto da Mooca',
                   '19º D.P. VILA MARIA':'019 DP - Vila Maria','20º D.P. AGUA FRIA':'020 DP - Água Fria',
                   '21º D.P. VILA MATILDE':'021 DP - Vila Matilde','22º D.P. SAO MIGUEL PTA':'022 DP - São Miguel Paulista',
                   '23º D.P. PERDIZES':'023 DP - Perdizes','24º D.P. PONTE RASA':'024 DP - Ponte Rasa',
                   '25º D.P. PARELHEIROS':'025 DP - Parelheiros','26º D.P. SACOMA':'026 DP - Sacomã',
                   '27º DP "DR. IGNÁCIO FRANCISCO"':'027 DP - Campo Belo','28º D.P. FREGUESIA DO O':'028 DP - Freguesia do Ó', 
                   '29º D.P. VILA PRUDENTE':'029 DP - Vila Diva','30º D.P. TATUAPE':'030 DP - Tatuapé','31º D.P. VILA CARRAO':'031 DP - Vila Carrão',
                   '32º D.P. ITAQUERA':'032 DP - Itaquera','33º D.P. PIRITUBA':'033 DP - Pirituba', '34º D.P. MORUMBI':'034 DP - Vila Sonia',
                   '35º D.P. JABAQUARA':'035 DP - Jabaquara','36º D.P. VILA MARIANA':'036 DP - Vila Mariana',
                   '37º D.P. CAMPO LIMPO':'037 DP - Campo Limpo','38º D.P. VILA AMALIA':'038 DP - Vila Amália',
                   '39º D.P. VILA GUSTAVO':'039 DP - Vila Gustavo','40º D.P. VILA STA MARIA':'040 DP - Vila Santa Maria',
                   '41º D.P. VILA RICA':'041 DP - Vila Rica','42º D.P. PARQUE S. LUCAS':'042 DP - Parque São Lucas',
                   '43º D.P. CIDADE ADEMAR':'043 DP - Cidade Ademar','44º D.P. GUAIANAZES':'044 DP - Guaianazes',
                   '45º D.P. V BRASILANDIA':'045 DP - Vila Brasilândia','46º D.P. PERUS':'046 DP - Perus',
                   '47º D.P. CAPAO REDONDO':'047 DP - Capão Redondo','48º D.P. CIDADE DUTRA':'048 DP - Cidade Dutra',
                   '49º D.P. SAO MATEUS':'049 DP - São Mateus', '50º D.P. ITAIM PAULISTA':'050 DP - Itaim Paulista',
                   '51º D.P. RIO PEQUENO':'051 DP - Butantã', '52º D.P. PARQUE S.JORGE':'052 DP - Parque São Jorge',
                   '53º D.P. PARQUE DO CARMO':'053 DP - Parque do Carmo','54º D.P. CID. TIRADENTES':'054 DP - Cidade Tiradentes',
                   '55º D.P. PARQUE S.RAFAEL':'055 DP - Parque São Rafael','56º D.P. VILA ALPINA':'056 DP - Vila Alpina',
                   '57º D.P. PARQUE DA MOOCA':'057 DP - Parque da Mooca','58º D.P. VILA FORMOSA':'058 DP - Vila Formosa',
                   '59º D.P. JARDIM DOS IPES':'059 DP - Jardim Noemia','62º D.P. ERMELINO MATARAZZO':'062 DP - Ermelino Matarazzo',
                   '63º D.P. VILA JACUI':'063 DP - Vila Jacuí','64º D.P. CID.AE CARVALHO':'064 DP - Cidade A E Carvalho',
                   '65º D.P. ARTUR ALVIM':'065 DP - Artur Alvim','66º D.P. JDIM ARICANDUVA':'066 DP - Vale do Aricanduva',
                   '67º D.P. JARDIM ROBRU':'067 DP - Jardim Robru','68º D.P. LAGEADO':'068 DP - Lajeado',
                   '69 D.P. - TEOTONIO VILELA':'069 DP - Teotônio Vilela','69º D.P. TEOTONIO VILELA':'069 DP - Teotônio Vilela', 
                   '70º D.P. VILA EMA':'070 DP - Vila Ema','72º D.P. VILA PENTEADO':'072 DP - Vila Penteado',
                   '73º D.P. JACANA':'073 DP - Jaçanã','74º D.P. PARADA TAIPAS':'074 DP - Jaraguá',
                   '75º D.P. JARDIM ARPOADOR':'075 DP - Jardim Arpoador','77º D.P. SANTA CECILIA':'077 DP - Santa Cecília',
                   '78º D.P. JARDINS':'078 DP - Jardins','80º D.P. VILA JOANIZA':'080 DP - Vila Joaniza',
                   '83º D.P. PARQUE BRISTOL':'083 DP - Parque Bristol','85º D.P. JARDIM MIRNA':'085 DP - Jardim Mirna',
                   '87º D.P. V. P. BARRETO':'087 DP - Vila Pereira Barreto','89º D.P. JARDIM TABOAO':'089 DP - Portal do Morumbi',
                   '90º D.P. PQ. NOVO MUNDO':'090 DP - Parque Novo Mundo','91º D.P. CEASA':'091 DP - Ceagesp',
                   '92º D.P. PQ. SANTO ANTONIO':'092 DP - Parque Santo Antônio','93º D.P. JAGUARÉ':'093 DP - Jaguaré',
                   '95º D.P. HELIÓPOLIS':'095 DP - Heliópolis','96º D.P. MONÇÕES':'096 DP - Monções',
                   '97º D.P. AMERICANOPOLIS':'097 DP - Americanópolis','98º D.P. JARDIM MIRIAM':'098 DP - Jardim Míriam',
                   '99º D.P. CAMPO GRANDE': '099 DP - Campo Grande'}, inplace=True)

# %% [markdown]
# ##📒 **5 - Concatenação dos arquivos e filtrando por cidade São Paulo**

# %%
# concat dos dados
dfsp_geral = pd.concat([dfsp_hom, dfsp_lat, dfsp_les,dfsp_pol])

# %%
# Verificando strings unicas em cidade
sorted(dfsp_geral['cidade'].unique())
# Out:
# ['8ª SEC',
#  'AGUAI',
#  'AGUAS DE S. BARBARA',
#  'AGUDOS',
#  'ALTAIR',
#  'ALVARES MACHADO',
#  'ALVINLÂNDIA',
#  'AMERICANA',
#  'ARACARIGUAMA',
#  'ARACATUBA',
#  'ARAPEI',
#  'ARARAQUARA',
#  'ARARAS',
#  'ARIRANHA',
#  'ARTUR NOGUEIRA',
#  'ARUJA',
#  'ASSIS',
#  'ATIBAIA',
#  'AVARE',
#  'Adamantina',
#  'Aguaí',
#  'Agudos',
#  'Alambari',
#  'Altair',
#  'Altinópolis',
#  'Alumínio',
#  'Alvinlândia',
#  'Americana',
#  'Amparo',
#  'Américo Brasiliense',
#  'Américo de Campos',
#  'Analândia',
#  'Andradina',
#  'Angatuba',
#  'Anhembi',
#  'Aparecida',
#  'Apiaí',
#  'Aramina',
#  'Arandu',
#  'Araraquara',
#  'Araras',
#  'Araçariguama',
#  'Araçatuba',
#  'Araçoiaba da Serra',
#  'Arealva',
#  'Areias',
#  'Areiópolis',
#  'Artur Nogueira',
#  'Arujá',
#  'Aspásia',
#  'Assis',
#  'Atibaia',
#  'Auriflama',
#  'Avanhandava',
#  'Avaré',
#  'BADY BASSIT',
#  'BARRA BONITA',
#  'BARRETOS',
#  'BARRINHA',
#  'BARUERI',
#  'BASTOS',
#  'BATATAIS',
#  'BAURU',
#  'BEBEDOURO',
#  'BERTIOGA',
#  'BIRITIBA-MIRIM',
#  'BOFETE',
#  'BOITUVA',
#  'BOM JESUS DOS PERDOES',
#  'BOTUCATU',
#  'BRAGANCA PAULISTA',
#  'BURITAMA',
#  'Bady Bassitt',
#  'Balbinos',
#  'Bananal',
#  'Bariri',
#  'Barra Bonita',
#  'Barra do Turvo',
#  'Barretos',
#  'Barrinha',
#  'Barueri',
#  'Bastos',
#  'Batatais',
#  'Bauru',
#  'Bebedouro',
#  'Bernardino de Campos',
#  'Bertioga',
#  'Birigui',
#  'Biritiba Mirim',
#  'Boa Esperança do Sul',
#  'Bocaina',
#  'Bofete',
#  'Boituva',
#  'Bom Jesus dos Perdões',
#  'Borborema',
#  'Botucatu',
#  'Bragança Paulista',
#  'Braúna',
#  'Brejo Alegre',
#  'Brodowski',
#  'Brotas',
#  'Buri',
#  'Buritama',
#  'Buritizal',
#  'Bálsamo',
#  'CABRÁLIA PAULISTA',
#  'CACAPAVA',
#  'CAFELANDIA',
#  'CAIEIRAS',
#  'CAJAMAR',
#  'CAJATI',
#  'CAMPINAS',
#  'CAMPO LIMPO PAULISTA',
#  'CAMPOS DO JORDAO',
#  'CAMPOS NOVOS PAUL.',
#  'CANANEIA',
#  'CANDIDO MOTA',
#  'CAPELA DO ALTO',
#  'CAPIVARI',
#  'CARAGUATATUBA',
#  'CARAPICUIBA',
#  'CASA BRANCA',
#  'CATANDUVA',
#  'CATIGUA',
#  'CEDRAL',
#  'CERQUILHO',
#  'CHARQUEADA',
#  'CONCHAL',
#  'CORONEL MACEDO',
#  'CORUMBATAI',
#  'COSMOPOLIS',
#  'COTIA',
#  'CRIME MILITAR',
#  'CRUZEIRO',
#  'CUBATAO',
#  'Cabreúva',
#  'Cabrália Paulista',
#  'Cachoeira Paulista',
#  'Caconde',
#  'Cafelândia',
#  'Caiabu',
#  'Caieiras',
#  'Caiuá',
#  'Cajamar',
#  'Cajati',
#  'Cajobi',
#  'Cajuru',
#  'Campina do Monte Alegre',
#  'Campinas',
#  'Campo Limpo Paulista',
#  'Campos Novos Paulista',
#  'Campos do Jordão',
#  'Cananéia',
#  'Canas',
#  'Canitar',
#  'Capela do Alto',
#  'Capivari',
#  'Capão Bonito',
#  'Caraguatatuba',
#  'Carapicuíba',
#  'Cardoso',
#  'Casa Branca',
#  'Castilho',
#  'Catanduva',
#  'Caçapava',
#  'Cedral',
#  'Cerqueira César',
#  'Cerquilho',
#  'Cesário Lange',
#  'Charqueada',
#  'Chavantes',
#  'Colina',
#  'Colômbia',
#  'Conchal',
#  'Cordeirópolis',
#  'Coroados',
#  'Coronel Macedo',
#  'Corumbataí',
#  'Cosmorama',
#  'Cosmópolis',
#  'Cotia',
#  'Cravinhos',
#  'Cristais Paulista',
#  'Cruzeiro',
#  'Cubatão',
#  'Cunha',
#  'Cândido Mota',
#  'DESCALVADO',
#  'DIADEMA',
#  'Descalvado',
#  'Diadema',
#  'Dobrada',
#  'Dois Córregos',
#  'Dourado',
#  'Dracena',
#  'Duartina',
#  'Dumont',
#  'ELDORADO',
#  'ELIAS FAUSTO',
#  'ELISIÁRIO',
#  'EMBU',
#  'EMBU-GUACU',
#  'ENGENHEIRO COELHO',
#  'ESPIRITO STO. PINHAL',
#  'Echaporã',
#  'Eldorado',
#  'Elias Fausto',
#  'Elisiário',
#  'Embu das Artes',
#  'Embu-Guaçu',
#  'Emilianópolis',
#  'Engenheiro Coelho',
#  'Espírito Santo do Pinhal',
#  'Espírito Santo do Turvo',
#  'Estiva Gerbi',
#  "Estrela D'Oeste",
#  'Estrela do Norte',
#  'FARTURA',
#  'FERNANDOPOLIS',
#  'FERRAZ DE VASCONCELOS',
#  'FRANCA',
#  'FRANCISCO MORATO',
#  'FRANCO DA ROCHA',
#  'Fartura',
#  'Fernando Prestes',
#  'Fernandópolis',
#  'Ferraz de Vasconcelos',
#  'Florínia',
#  'Flórida Paulista',
#  'Franca',
#  'Francisco Morato',
#  'Franco da Rocha',
#  'GAVIAO PEIXOTO',
#  'GAVIÃO PEIXOTO',
#  'GUAIRA',
#  'GUARARAPES',
#  'GUARAREMA',
#  'GUARATINGUETA',
#  'GUAREI',
#  'GUARUJA',
#  'GUARULHOS',
#  'GUARÁ',
#  'GUZOLÂNDIA',
#  'Garça',
#  'Gastão Vidigal',
#  'Gavião Peixoto',
#  'Getulina',
#  'Glicério',
#  'Guaimbê',
#  'Guaiçara',
#  'Guapiara',
#  'Guapiaçu',
#  'Guaraci',
#  'Guarantã',
#  'Guararapes',
#  'Guararema',
#  'Guaratinguetá',
#  'Guaraçaí',
#  'Guareí',
#  'Guariba',
#  'Guarujá',
#  'Guarulhos',
#  'Guará',
#  'Guatapará',
#  'Guaíra',
#  'Gália',
#  'HORTOLANDIA',
#  'Herculândia',
#  'Holambra',
#  'Hortolândia',
#  'IACRI',
#  'IBATÉ',
#  'IBIRA',
#  'IBIUNA',
#  'IEPÊ',
#  'IGARATA',
#  'ILHA COMPRIDA',
#  'INDAIATUBA',
#  'INUBIA PAULISTA',
#  'IPERO',
#  'IPERÓ',
#  'IPEUNA',
#  'ITAI',
#  'ITANHAEM',
#  'ITAPECERICA DA SERRA',
#  'ITAPETININGA',
#  'ITAPEVA',
#  'ITAPEVI',
#  'ITAPIRA',
#  'ITAQUAQUECETUBA',
#  'ITARIRI',
#  'ITATIBA',
#  'ITIRAPINA',
#  'ITU',
#  'ITUPEVA',
#  'Iacanga',
#  'Iacri',
#  'Iaras',
#  'Ibaté',
#  'Ibirarema',
#  'Ibirá',
#  'Ibitinga',
#  'Ibiúna',
#  'Icém',
#  'Iepê',
#  'Igarapava',
#  'Igaratá',
#  'Igaraçu do Tietê',
#  'Iguape',
#  'Ilha Comprida',
#  'Ilha Solteira',
#  'Ilhabela',
#  'Indaiatuba',
#  'Indiana',
#  'Indiaporã',
#  'Ipaussu',
#  'Iperó',
#  'Ipeúna',
#  'Ipiguá',
#  'Ipuã',
#  'Iracemápolis',
#  'Irapuã',
#  'Itaberá',
#  'Itajobi',
#  'Itaju',
#  'Itanhaém',
#  'Itapecerica da Serra',
#  'Itapetininga',
#  'Itapeva',
#  'Itapevi',
#  'Itapira',
#  'Itaporanga',
#  'Itapura',
#  'Itapuí',
#  'Itaquaquecetuba',
#  'Itararé',
#  'Itariri',
#  'Itatiba',
#  'Itatinga',
#  'Itaí',
#  'Itaóca',
#  'Itirapina',
#  'Itobi',
#  'Itu',
#  'Itupeva',
#  'Ituverava',
#  'Itápolis',
#  'JABOTICABAL',
#  'JACAREI',
#  'JACI',
#  'JACUPIRANGA',
#  'JAGUARIUNA',
#  'JAMBEIRO',
#  'JANDIRA',
#  'JARDINOPOLIS',
#  'JARINU',
#  'JAU',
#  'JUNDIAI',
#  'JUQUITIBA',
#  'Jaboticabal',
#  'Jacareí',
#  'Jaci',
#  'Jacupiranga',
#  'Jaguariúna',
#  'Jales',
#  'Jambeiro',
#  'Jandira',
#  'Jardinópolis',
#  'Jarinu',
#  'Jaú',
#  'Jeriquara',
#  'Joanópolis',
#  'José Bonifácio',
#  'João Ramalho',
#  'Jundiaí',
#  'Junqueirópolis',
#  'Juquitiba',
#  'Juquiá',
#  'Júlio Mesquita',
#  'LARANJAL PAULISTA',
#  'LAVINIA',
#  'LAVRINHAS',
#  'LEME',
#  'LIMEIRA',
#  'LINS',
#  'LORENA',
#  'LOURENÇO DA SERRA',
#  'LOUVEIRA',
#  'Lagoinha',
#  'Laranjal Paulista',
#  'Lavrinhas',
#  'Lavínia',
#  'Leme',
#  'Lençóis Paulista',
#  'Limeira',
#  'Lindóia',
#  'Lins',
#  'Lorena',
#  'Lourdes',
#  'Louveira',
#  'Lucianópolis',
#  'Lucélia',
#  'Luiziânia',
#  'Lupércio',
#  'Luís Antônio',
#  'MACATUBA',
#  'MAIRINQUE',
#  'MAIRIPORA',
#  'MARILIA',
#  'MARTINOPOLIS',
#  'MATAO',
#  'MAUA',
#  'MINEIROS DO TIETE',
#  'MIRACATU',
#  'MOGI DAS CRUZES',
#  'MOGI-GUACU',
#  'MOGI-MIRIM',
#  'MOMBUCA',
#  'MONGAGUA',
#  'MONTE APRAZIVEL',
#  'MONTE MOR',
#  'MORRO AGUDO',
#  'Macatuba',
#  'Macaubal',
#  'Macedônia',
#  'Mairinque',
#  'Mairiporã',
#  'Manduri',
#  'Marabá Paulista',
#  'Maracaí',
#  'Mariápolis',
#  'Martinópolis',
#  'Marília',
#  'Matão',
#  'Mauá',
#  'Mendonça',
#  'Mesópolis',
#  'Miguelópolis',
#  'Mineiros do Tietê',
#  'Mira Estrela',
#  'Miracatu',
#  'Mirandópolis',
#  'Mirante do Paranapanema',
#  'Mirassol',
#  'Mirassolândia',
#  'Mococa',
#  'Mogi Guaçu',
#  'Mogi Mirim',
#  'Mogi das Cruzes',
#  'Mombuca',
#  'Mongaguá',
#  'Monte Alto',
#  'Monte Aprazível',
#  'Monte Azul Paulista',
#  'Monte Mor',
#  'Monteiro Lobato',
#  'Monções',
#  'Morro Agudo',
#  'Morungaba',
#  'Motuca',
#  'NAZARE PAULISTA',
#  'NEVES PAULISTA',
#  'NOVA ALIANCA',
#  'NOVA ODESSA',
#  'Narandiba',
#  'Natividade da Serra',
#  'Nazaré Paulista',
#  'Nhandeara',
#  'Nipoã',
#  'Nova Campina',
#  'Nova Canaã Paulista',
#  'Nova Granada',
#  'Nova Guataporanga',
#  'Nova Independência',
#  'Nova Odessa',
#  'Novo Horizonte',
#  'Nuporanga',
#  'OLIMPIA',
#  'ONDA VERDE',
#  'OSASCO',
#  'OURINHOS',
#  'Ocauçu',
#  'Olímpia',
#  'Onda Verde',
#  'Orlândia',
#  'Osasco',
#  'Osvaldo Cruz',
#  'Ourinhos',
#  'Ouro Verde',
#  'Ouroeste',
#  'PALMITAL',
#  'PANORAMA',
#  'PARIQUERA-ACU',
#  'PAULICEIA',
#  'PAULINIA',
#  'PAULO DE FARIA',
#  'PEDERNEIRAS',
#  'PEDREGULHO',
#  'PEDRO DE TOLEDO',
#  'PERUIBE',
#  'PIEDADE',
#  'PILAR DO SUL',
#  'PINDAMONHANGABA',
#  'PIQUETE',
#  'PIRACICABA',
#  'PIRAPORA DO BOM JESUS',
#  'POA',
#  'POLONI',
#  'PONGAI',
#  'PONTAL',
#  'PORTO FELIZ',
#  'PORTO FERREIRA',
#  'PRACINHA',
#  'PRADOPOLIS',
#  'PRAIA GRANDE',
#  'PRESIDENTE PRUDENTE',
#  'Pacaembu',
#  'Palestina',
#  'Palmares Paulista',
#  "Palmeira D'Oeste",
#  'Palmital',
#  'Panorama',
#  'Paraguaçu Paulista',
#  'Paraibuna',
#  'Paranapanema',
#  'Paranapuã',
#  'Parapuã',
#  'Paraíso',
#  'Pardinho',
#  'Pariquera-Açu',
#  'Parisi',
#  'Patrocínio Paulista',
#  'Paulistânia',
#  'Paulo de Faria',
#  'Paulínia',
#  'Pederneiras',
#  'Pedregulho',
#  'Pedreira',
#  'Pedro de Toledo',
#  'Penápolis',
#  'Pereira Barreto',
#  'Peruíbe',
#  'Piacatu',
#  'Piedade',
#  'Pilar do Sul',
#  'Pindamonhangaba',
#  'Pindorama',
#  'Pinhalzinho',
#  'Piquerobi',
#  'Piquete',
#  'Piracaia',
#  'Piracicaba',
#  'Piraju',
#  'Pirajuí',
#  'Pirangi',
#  'Pirapora do Bom Jesus',
#  'Pirapozinho',
#  'Pirassununga',
#  'Piratininga',
#  'Pitangueiras',
#  'Planalto',
#  'Policia Federal',
#  'Poloni',
#  'Pompéia',
#  'Pontal',
#  'Pontalinda',
#  'Pontes Gestal',
#  'Populina',
#  'Porangaba',
#  'Porto Feliz',
#  'Porto Ferreira',
#  'Potim',
#  'Potirendaba',
#  'Poá',
#  'Pradópolis',
#  'Praia Grande',
#  'Pratânia',
#  'Presidente Alves',
#  'Presidente Epitácio',
#  'Presidente Prudente',
#  'Presidente Venceslau',
#  'Promissão',
#  'QUATA',
#  'Quatá',
#  'Queiroz',
#  'Queluz',
#  'REGISTRADO EM (MG)',
#  'REGISTRADO NA PF',
#  'REGISTRADO NA PF - BO 206/17',
#  'REGISTRO',
#  'RIBEIRAO BRANCO',
#  'RIBEIRAO GRANDE',
#  'RIBEIRAO PIRES',
#  'RIBEIRAO PRETO',
#  'RIFAINA',
#  'RINCAO',
#  'RINOPOLIS',
#  'RIO CLARO',
#  'RIO GRANDE DA SERRA',
#  'ROSANA',
#  'Rafard',
#  'Rancharia',
#  'Redenção da Serra',
#  'Regente Feijó',
#  'Reginópolis',
#  'Registro',
#  'Restinga',
#  'Ribeira',
#  'Ribeirão Bonito',
#  'Ribeirão Branco',
#  'Ribeirão Grande',
#  'Ribeirão Pires',
#  'Ribeirão Preto',
#  'Ribeirão do Sul',
#  'Ribeirão dos Índios',
#  'Rincão',
#  'Rinópolis',
#  'Rio Claro',
#  'Rio Grande da Serra',
#  'Rio das Pedras',
#  'Riolândia',
#  'Rosana',
#  'Roseira',
#  'Rubinéia',
#  'Rubiácea',
#  'S.ANDRE',
#  'S.BARBARA D OESTE',
#  'S.BERNARDO DO CAMPO',
#  'S.CAETANO DO SUL',
#  'S.CARLOS',
#  'S.CRUZ DAS PALMEIRAS',
#  'S.ISABEL',
#  'S.JOSE DO RIO PRETO',
#  'S.JOSE DOS CAMPOS',
#  'S.LUIS DO PARAITINGA',
#  'S.PEDRO',
#  'S.ROQUE',
#  'S.SEBASTIAO',
#  'S.SIMAO',
#  'S.VICENTE',
#  'SABINO',
#  'SALESOPOLIS',
#  'SALTO',
#  'SALTO DE PIRAPORA',
#  'SANTANA DE PARNAIBA',
#  'SANTOS',
#  'SAO JOAO DA BOA VISTA',
#  'SEC Adamantina',
#  'SEC Araraquara',
#  'SEC Araçatuba',
#  'SEC Cruzeiro',
#  'SEC Jaú',
#  'SEC Mogi-Guaçu',
#  'SEC Presidente Prudente',
#  'SEC Presidente Venceslau',
#  'SEC Ribeirão Preto',
#  'SEC São José Campos',
#  'SERRA NEGRA',
#  'SERRANA',
#  'SERTAOZINHO',
#  'SETE BARRAS',
#  'SOCORRO',
#  'SOROCABA',
#  'SUMARE',
#  'SUZANO',
#  'Sabino',
#  'Sagres',
#  'Sales',
#  'Sales Oliveira',
#  'Salesópolis',
#  'Salmourão',
#  'Salto',
#  'Salto Grande',
#  'Salto de Pirapora',
#  'Santa Adélia',
#  'Santa Albertina',
#  'Santa Branca',
#  "Santa Bárbara D'Oeste",
#  'Santa Cruz da Conceição',
#  'Santa Cruz das Palmeiras',
#  'Santa Cruz do Rio Pardo',
#  'Santa Ernestina',
#  'Santa Fé do Sul',
#  'Santa Gertrudes',
#  'Santa Isabel',
#  'Santa Lucia',
#  'Santa Mercedes',
#  'Santa Rita do Passa Quatro',
#  'Santa Rosa do Viterbo',
#  'Santana de Parnaíba',
#  'Santo Anastácio',
#  'Santo André',
#  'Santo Antonio da Alegria',
#  'Santo Antonio do Aracanguá',
#  'Santo Antônio de Posse',
#  'Santo Expedito',
#  'Santos',
#  'Sarapuí',
#  'Sarutaiá',
#  'Sebastianópolis do Sul',
#  'Serra Azul',
#  'Serra Negra',
#  'Serrana',
#  'Sertãozinho',
#  'Sete Barras',
#  'Severínia',
#  'Silveiras',
#  'Socorro',
#  'Sorocaba',
#  'Sumaré',
#  'Suzano',
#  'Suzanápolis',
#  'SÃO MANUEL',
#  'São Bento do Sapucaí',
#  'São Bernardo do Campo',
#  'São Caetano do Sul',
#  'São Carlos',
#  'São Joaquim da Barra',
#  'São José do Rio Pardo',
#  'São José do Rio Preto',
#  'São José dos Campos',
#  'São João da Boa Vista',
#  'São João das Duas Pontes',
#  "São João do Pau D'Alho",
#  'São Lourenço da Serra',
#  'São Luís do Paraitinga',
#  'São Manuel',
#  'São Miguel Arcanjo',
#  'São Paulo',
#  'São Pedro',
#  'São Pedro do Turvo',
#  'São Roque',
#  'São Sebastião',
#  'São Sebastião da Grama',
#  'São Simão',
#  'São Vicente',
#  'TABOAO DA SERRA',
#  'TANABI',
#  'TAQUARITINGA',
#  'TAQUARITUBA',
#  'TATUI',
#  'TAUBATE',
#  'TERRA ROXA',
#  'TIETE',
#  'TORRINHA',
#  'TREMEMBE',
#  'TUPA',
#  'Tabapuã',
#  'Tabatinga',
#  'Taboão da Serra',
#  'Taciba',
#  'Taiaçu',
#  'Tambaú',
#  'Tanabi',
#  'Tapiratiba',
#  'Tapiraí',
#  'Taquaritinga',
#  'Taquarituba',
#  'Taquarivaí',
#  'Tarumã',
#  'Tatuí',
#  'Taubaté',
#  'Tejupá',
#  'Teodoro Sampaio',
#  'Terra Roxa',
#  'Tietê',
#  'Torrinha',
#  'Tremembé',
#  'Tuiuti',
#  'Tupi Paulista',
#  'Tupã',
#  'UBATUBA',
#  'UCHOA',
#  'Ubarana',
#  'Ubatuba',
#  'Ubirajara',
#  'Uchôa',
#  'União Paulista',
#  'Uru',
#  'Urupês',
#  'Urânia',
#  'VALINHOS',
#  'VARGEM',
#  'VARGEM GRANDE PAULISTA',
#  'VARZEA PAULISTA',
#  'VOTORANTIM',
#  'Valentim Gentil',
#  'Valinhos',
#  'Valparaíso',
#  'Vargem',
#  'Vargem Grande Paulista',
#  'Vargem Grande do Sul',
#  'Vera Cruz',
#  'Vinhedo',
#  'Viradouro',
#  'Vista Alegre do Alto',
#  'Votorantim',
#  'Votuporanga',
#  'Várzea Paulista',
#  'Zacarias',
#  'Águas de Lindóia',
#  'Águas de Santa Bárbara',
#  'Álvares Machado',
#  'Álvaro de Carvalho',
#  'Óleo']

# %%
# Contando o número de ocorrências
dfsp_geral.groupby(['cidade']).size().sort_values(ascending=False)
# Out:
# cidade
# São Paulo         4673
# Campinas           560
# Guarulhos          350
# Sorocaba           216
# Ribeirão Preto     212
#                   ...
# Pontes Gestal        1
# Sales Oliveira       1
# ITAPEVA              1
# ITAI                 1
# Sagres               1
# Length: 805, dtype: int64

# %%
# Mostrando as 5 campeãs em ocorrências no estado de São Paulo
dfsp_geral.groupby(['cidade']).size().sort_values(ascending=False).head(5).plot.bar()

# %%
# Filtrando por cidade = São Paulo
ft = dfsp_geral['cidade'] == 'São Paulo'
dfsp_geral = dfsp_geral.loc[ft]

# %%
# Drop das ocorrências de 2017
ft2018 = dfsp_geral['ano_ocorrencia'] == 2018
ft2019 = dfsp_geral['ano_ocorrencia'] == 2019
ft2020 = dfsp_geral['ano_ocorrencia'] == 2020
ft2021 = dfsp_geral['ano_ocorrencia'] == 2021

dfsp_geral = dfsp_geral.loc[ft2018 | ft2019 | ft2020 | ft2021]

# %%
# Verificando alteração
dfsp_geral.shape
# Out:
# (4273, 26)

# %%
# Verificando index
dfsp_geral.loc[0]
# Out:
#   departamento_circunscricao seccional_circunscricao     cidade  \
# 0                      DECAP                  1ª SEC  São Paulo
# 0                      DECAP                  1ª SEC  São Paulo
#
#       dp_circunscricao  n_vitimas  mes_ocorrencia  ano_ocorrencia  \
# 0  002 DP - Bom Retiro        1.0               1            2018
# 0   005 DP - Aclimação        1.0               1            2018
#
#            datahora_bo num_bo ano_bo              dt_fato hora_fato  \
# 0  2018-01-07 00:00:00     16   2018  2018-01-06 00:00:00  20:06:00
# 0  2018-01-21 00:00:00    550   2018  2018-01-21 00:00:00  00:02:00
#
#   tipo_local_fato                         logradouro n_logradouro   latitude  \
# 0     Via pública  AVENIDA PRESIDENTE CASTELO BRANCO         6173 -23.523712
# 0     Via pública    AVENIDA BRIGADEIRO LUIS ANTONIO       1572.0 -23.562435
#
#    longitude tipo_pessoa sexo_pessoa idade_pessoa       dt_nasc_pessoa  \
# 0 -46.606388      Vítima   Masculino          NaN                  NaT
# 0 -46.645048      Vítima   Masculino         59.0  1958-02-18 00:00:00
#
#    cor_pele   profissao        tipo_crime corporacao_policial  \
# 0  Ignorada         NaN  HOMICÍDIO DOLOSO                 NaN
# 0    Branca  JORNALISTA       LATROCÍNIO                  NaN
#
#   situacao_policial
# 0               NaN
# 0               NaN

# %%
# Resetando o index
dfsp_geral = dfsp_geral.reset_index()

# %%
# Verificando se foi corrigido
dfsp_geral.tail(3)
# Out:
#       index                departamento_circunscricao  \
# 4270   4038  DECAP
# 4271   4039                                     DECAP
# 4272   4041                                     DECAP
#
#                seccional_circunscricao     cidade          dp_circunscricao  \
# 4270  DHPP - DEP. HOM. PROTECAO PESSOA  São Paulo  069 DP - Teotônio Vilela
# 4271                 DEL.SEC.1º CENTRO  São Paulo   003 DP - Campos Elíseos
# 4272             DEL.SEC.8º SAO MATEUS  São Paulo        041 DP - Vila Rica
#
#       n_vitimas  mes_ocorrencia  ano_ocorrencia          datahora_bo num_bo  \
# 4270        NaN              12            2021  2021-12-29 00:00:00    481
# 4271        NaN              12            2021  2021-12-30 00:00:00    483
# 4272        NaN              12            2021  2021-12-30 00:00:00   7059
#
#      ano_bo              dt_fato hora_fato tipo_local_fato  \
# 4270   2021  2021-12-29 00:00:00  12:45:00      Residência
# 4271   2021  2021-12-29 00:00:00  23:45:00      Hospedagem
# 4272   2021  2021-12-29 00:00:00  22:52:00     Via pública
#
#                                          logradouro n_logradouro   latitude  \
# 4270  DA VEDAÇÃO DA DIVULGAÇÃO DOS DADOS RELATIVOS           NaN        NaN
# 4271                             RUA GENERAL OSORIO          413 -23.537508
# 4272                         AVENIDA RIO DAS PEDRAS          655 -23.569583
#
#       longitude   tipo_pessoa sexo_pessoa idade_pessoa       dt_nasc_pessoa  \
# 4270        NaN  Autor/Vitima   Masculino          NaN                  NaN
# 4271  -46.64165  Autor/Vitima   Masculino          NaN                  NaN
# 4272 -46.508261  Autor/Vitima   Masculino           27  1994-03-16 00:00:00
#
#      cor_pele profissao                                tipo_crime  \
# 4270    Parda       NaN  MORTE DECORRENTE DE INTERVENÇÃO POLICIAL
# 4271   Branca       NaN  MORTE DECORRENTE DE INTERVENÇÃO POLICIAL
# 4272    Parda       NaN  MORTE DECORRENTE DE INTERVENÇÃO POLICIAL
#
#      corporacao_policial situacao_policial
# 4270                  PM           serviço
# 4271                  PM           serviço
# 4272                  PM           serviço

# %%
# Verificando as colunas
dfsp_geral.columns
# Out:
# Index(['index', 'departamento_circunscricao', 'seccional_circunscricao',
#        'cidade', 'dp_circunscricao', 'n_vitimas', 'mes_ocorrencia',
#        'ano_ocorrencia', 'datahora_bo', 'num_bo', 'ano_bo', 'dt_fato',
#        'hora_fato', 'tipo_local_fato', 'logradouro', 'n_logradouro',
#        'latitude', 'longitude', 'tipo_pessoa', 'sexo_pessoa', 'idade_pessoa',
#        'dt_nasc_pessoa', 'cor_pele', 'profissao', 'tipo_crime',
#        'corporacao_policial', 'situacao_policial'],
#       dtype='object')

# %%
# Dropando coluna com o index antigo
dfsp_geral.drop(['index'], axis=1, inplace= True)

# Verificando colunas pós drop
dfsp_geral.columns
# Out:
# Index(['departamento_circunscricao', 'seccional_circunscricao', 'cidade',
#        'dp_circunscricao', 'n_vitimas', 'mes_ocorrencia', 'ano_ocorrencia',
#        'datahora_bo', 'num_bo', 'ano_bo', 'dt_fato', 'hora_fato',
#        'tipo_local_fato', 'logradouro', 'n_logradouro', 'latitude',
#        'longitude', 'tipo_pessoa', 'sexo_pessoa', 'idade_pessoa',
#        'dt_nasc_pessoa', 'cor_pele', 'profissao', 'tipo_crime',
#        'corporacao_policial', 'situacao_policial'],
#       dtype='object')

# %%
# Criando backup do Data Frame
dfsp_geral_bk = dfsp_geral.copy()

# Plot dos dados
dfsp_geral.head(3)
# Out:
#   departamento_circunscricao seccional_circunscricao     cidade  \
# 0                      DECAP                  1ª SEC  São Paulo
# 1                      DECAP                  1ª SEC  São Paulo
# 2                      DECAP                  1ª SEC  São Paulo
#
#       dp_circunscricao  n_vitimas  mes_ocorrencia  ano_ocorrencia  \
# 0  002 DP - Bom Retiro        1.0               1            2018
# 1  002 DP - Bom Retiro        1.0               1            2018
# 2        008 DP - Brás        1.0               1            2018
#
#            datahora_bo num_bo ano_bo              dt_fato hora_fato  \
# 0  2018-01-07 00:00:00     16   2018  2018-01-06 00:00:00  20:06:00
# 1  2018-01-06 00:00:00    106   2018  2018-01-06 00:00:00  19:00:00
# 2  2018-01-18 00:00:00    370   2018  2018-01-18 00:00:00  18:00:00
#
#        tipo_local_fato                                     logradouro  \
# 0          Via pública              AVENIDA PRESIDENTE CASTELO BRANCO
# 1           Residência  DA VEDAÇÃO DA DIVULGAÇÃO DOS DADOS RELATIVOS
# 2  Comércio e serviços                                   RUA DA MOOCA
#
#   n_logradouro   latitude  longitude tipo_pessoa sexo_pessoa idade_pessoa  \
# 0         6173 -23.523712 -46.606388      Vítima   Masculino          NaN
# 1          NaN        NaN        NaN      Vítima   Masculino         44.0
# 2          820   -23.5539 -46.617413      Vítima    Feminino         59.0
#
#         dt_nasc_pessoa  cor_pele        profissao        tipo_crime  \
# 0                  NaT  Ignorada              NaN  HOMICÍDIO DOLOSO
# 1  1973-06-06 00:00:00    Branca  CABELEIREIRO(A)  HOMICÍDIO DOLOSO
# 2  1958-08-02 00:00:00     Parda      COMERCIANTE  HOMICÍDIO DOLOSO
#
#   corporacao_policial situacao_policial
# 0                 NaN               NaN
# 1                 NaN               NaN
# 2                 NaN               NaN

# %% [markdown]
# ##📝 **6 - Tratando inconsistências no Data Frame Geral**

# %%
# Criando backup do Data Frame
dfsp_geral = dfsp_geral_bk.copy()

# %% [markdown]
# ###▶️ **Verificando inconsistências nos dados por colunas**
#
#  Encontramos no data frame, seguindo os passos mostrados abaixo, as seguintes inconsistências:
#  - ano_ocorrencia tem 2017 (só trabalharemos com 2018 a 2021)
#  - datahora_bo também possui 2017
#  - num_bo - dropar (dados sem padrão e sem relecancia)
#  - ano_bo - tem 2017 e 'SEM RESPOSTA DA DELEGACIA. CASO MANTIDO' normalizar para data ou tratar como null
#  - linha 247 dropar (dado irrelevante e linha toda faltante
#  - hora_fato possui strings A NOITE', 'A TARDE', 'DE MADRUGADA', 'EM HORA INCERTA', 'PELA MANHÃ', 'PELA MANHÃ          ', 'RDO NÃO LOCALIZADO', será gerada uma nova coluna a partir dela com (manha (06:00 as 11:59), tarde (12:00 as 17:59), noite (18:00 as 23:54) e madrugada (00:00 as 05:59))
#  - dp_circunscricao: corrigir **003 DP - Campos Elíseos**(certo) 003 DP - Campos Elísios(errado)
#  - dp_circunscricao (pode ser criada uma tabela com o nome da DP representando o bairro da ocorrencia)
#  - tipo_local_fato: Palavras escritas de formas diferentes:
#  Via pública, Via Pública, VIA PÚBLICA, Via pública...
#  - Remover espaços em branco no começo e final das colunas que forem strings
#  - n_logradouro com muita inconcistência (não será útil, dropar)
#  - tipo_pessoa - Palavras escritas de forma diferente: Vítima, vítima e 'Vítima              '
#  - coluna situacao_policial fazer replace de serviço e Serviço
#  - Verificar se ano_nasc_pessoa bate com data_nasc_pessoa

# %%
# Pegando o nome das colunas
dfsp_geral.columns
# Out:
# Index(['departamento_circunscricao', 'seccional_circunscricao', 'cidade',
#        'dp_circunscricao', 'n_vitimas', 'mes_ocorrencia', 'ano_ocorrencia',
#        'datahora_bo', 'num_bo', 'ano_bo', 'dt_fato', 'hora_fato',
#        'tipo_local_fato', 'logradouro', 'n_logradouro', 'latitude',
#        'longitude', 'tipo_pessoa', 'sexo_pessoa', 'idade_pessoa',
#        'dt_nasc_pessoa', 'cor_pele', 'profissao', 'tipo_crime',
#        'corporacao_policial', 'situacao_policial'],
#       dtype='object')

# %%
# Filtros de análise

# ft = dfsp_geral['tipo_pessoa'] == 'Autor/Vítima'
# ft2 = dfsp_geral['dp_circunscricao'] == '077 DP - Santa Cecília'
# dfsp_geral.loc[ft]

# %%
# Filtros por coluna

# dfsp_geral.groupby(dfsp_geral['dt_fato']).size().sort_values()
dfsp_geral['dt_fato'].unique()
# sorted(dfsp_geral['dt_fato'].unique())
# Out:
# array([Timestamp('2018-01-06 00:00:00'), Timestamp('2018-01-18 00:00:00'),
#        Timestamp('2018-01-02 00:00:00'), ...,
#        datetime.datetime(2021, 12, 10, 0, 0),
#        datetime.datetime(2021, 12, 11, 0, 0),
#        datetime.datetime(2021, 12, 16, 0, 0)], dtype=object)

# %% [markdown]
# ###▶️ **Realizando drop de colunas e linhas irrelevantes**

# %%
# Plot do Data Frame
dfsp_geral.head(1)
# Out:
#   departamento_circunscricao seccional_circunscricao     cidade  \
# 0                      DECAP                  1ª SEC  São Paulo
#
#       dp_circunscricao  n_vitimas  mes_ocorrencia  ano_ocorrencia  \
# 0  002 DP - Bom Retiro        1.0               1            2018
#
#            datahora_bo num_bo ano_bo              dt_fato hora_fato  \
# 0  2018-01-07 00:00:00     16   2018  2018-01-06 00:00:00  20:06:00
#
#   tipo_local_fato                         logradouro n_logradouro   latitude  \
# 0     Via pública  AVENIDA PRESIDENTE CASTELO BRANCO         6173 -23.523712
#
#    longitude tipo_pessoa sexo_pessoa idade_pessoa dt_nasc_pessoa  cor_pele  \
# 0 -46.606388      Vítima   Masculino          NaN            NaT  Ignorada
#
#   profissao        tipo_crime corporacao_policial situacao_policial
# 0       NaN  HOMICÍDIO DOLOSO                 NaN               NaN

# %%
# drop de colunas que não serão usadas
dfsp_geral.drop(columns=['departamento_circunscricao',
                         'seccional_circunscricao',
                         'mes_ocorrencia','ano_ocorrencia',
                         'datahora_bo','num_bo', 'ano_bo'], axis = 1, inplace= True)

# %%
# Plot do Data Frame pós alteração
dfsp_geral.head(1)
# Out:
#       cidade     dp_circunscricao  n_vitimas              dt_fato hora_fato  \
# 0  São Paulo  002 DP - Bom Retiro        1.0  2018-01-06 00:00:00  20:06:00
#
#   tipo_local_fato                         logradouro n_logradouro   latitude  \
# 0     Via pública  AVENIDA PRESIDENTE CASTELO BRANCO         6173 -23.523712
#
#    longitude tipo_pessoa sexo_pessoa idade_pessoa dt_nasc_pessoa  cor_pele  \
# 0 -46.606388      Vítima   Masculino          NaN            NaT  Ignorada
#
#   profissao        tipo_crime corporacao_policial situacao_policial
# 0       NaN  HOMICÍDIO DOLOSO                 NaN               NaN

# %%
# Filtrando por linha inconsistente
dfsp_geral.loc[dfsp_geral['dt_fato'] == 'RDO NÃO LOCALIZADO']
# Out:
#          cidade dp_circunscricao  n_vitimas             dt_fato  \
# 3009  São Paulo   081 DP - Belém        NaN  RDO NÃO LOCALIZADO
#
#                hora_fato     tipo_local_fato          logradouro  \
# 3009  RDO NÃO LOCALIZADO  RDO NÃO LOCALIZADO  RDO NÃO LOCALIZADO
#
#             n_logradouro            latitude           longitude  \
# 3009  RDO NÃO LOCALIZADO  RDO NÃO LOCALIZADO  RDO NÃO LOCALIZADO
#
#              tipo_pessoa         sexo_pessoa        idade_pessoa  \
# 3009  RDO NÃO LOCALIZADO  RDO NÃO LOCALIZADO  RDO NÃO LOCALIZADO
#
#           dt_nasc_pessoa            cor_pele           profissao  \
# 3009  RDO NÃO LOCALIZADO  RDO NÃO LOCALIZADO  RDO NÃO LOCALIZADO
#
#                            tipo_crime corporacao_policial situacao_policial
# 3009  LESÃO CORPORAL SEGUIDA DE MORTE                 NaN               NaN

# %%
# Drop da linha inconsistente
dfsp_geral.drop(labels=3009, axis = 0, inplace = True)

# Verificando se foi removido
dfsp_geral.loc[dfsp_geral['dt_fato'] == 'RDO NÃO LOCALIZADO']
# Out:
# Empty DataFrame
# Columns: [cidade, dp_circunscricao, n_vitimas, dt_fato, hora_fato, tipo_local_fato, logradouro, n_logradouro, latitude, longitude, tipo_pessoa, sexo_pessoa, idade_pessoa, dt_nasc_pessoa, cor_pele, profissao, tipo_crime, corporacao_policial, situacao_policial]
# Index: []

# %% [markdown]
# ###▶️ **Retirando espaços em branco (strip)**

# %%
# Verificando tipo das colunas 
dfsp_geral.columns
# Out:
# Index(['cidade', 'dp_circunscricao', 'n_vitimas', 'dt_fato', 'hora_fato',
#        'tipo_local_fato', 'logradouro', 'n_logradouro', 'latitude',
#        'longitude', 'tipo_pessoa', 'sexo_pessoa', 'idade_pessoa',
#        'dt_nasc_pessoa', 'cor_pele', 'profissao', 'tipo_crime',
#        'corporacao_policial', 'situacao_policial'],
#       dtype='object')

# %%
# Criando lista de strings
colunas = ['cidade','dp_circunscricao','tipo_local_fato','logradouro','n_logradouro',
           'tipo_pessoa','sexo_pessoa', 'cor_pele','profissao','tipo_crime',
           'corporacao_policial','situacao_policial']

# %%
# Fazendo strip das colunas
for x in colunas:
  dfsp_geral[x] = dfsp_geral[x].str.strip()

# %% [markdown]
# ###▶️ **Corrigindo linhas nulas e duplicadas**

# %%
# Verificando total de linhas
dfsp_geral.shape
# Out:
# (4272, 19)

# %%
dfsp_geral.isna().sum()
# Out:
# cidade                    0
# dp_circunscricao          0
# n_vitimas              1304
# dt_fato                   0
# hora_fato                 0
# tipo_local_fato           1
# logradouro                0
# n_logradouro           4271
# latitude                872
# longitude               873
# tipo_pessoa               0
# sexo_pessoa               0
# idade_pessoa            914
# dt_nasc_pessoa          993
# cor_pele                  0
# profissao              1878
# tipo_crime                0
# corporacao_policial    3052
# situacao_policial      3052
# dtype: int64

# %%
#Verificando a quantidade de duplicados
dfsp_geral.duplicated().sum()
# Out:
# 72

# %%
#Deletar linhas duplicadas
dfsp_geral.drop_duplicates(keep=False,inplace=True)

# %%
# Conferindo se foi corrigido
dfsp_geral.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ###▶️ **Corrigindo idade_pessoa**

# %%
# Filtrando por linha inconsistente, Verificado todas as datas de nascimento e a unica que nao bate o nascimento com a idade é essa
dfsp_geral.loc[dfsp_geral['idade_pessoa'] == 118]
# Out:
#          cidade          dp_circunscricao  n_vitimas              dt_fato  \
# 2745  São Paulo  075 DP - Jardim Arpoador        1.0  2018-05-27 00:00:00
#
#      hora_fato tipo_local_fato             logradouro n_logradouro latitude  \
# 2745  18:08:00     Via pública  RUA ORESTES COLOMBARI          NaN -23.5886
#
#      longitude tipo_pessoa sexo_pessoa idade_pessoa       dt_nasc_pessoa  \
# 2745  -46.7694      Vítima   Masculino        118.0  1966-07-03 00:00:00
#
#      cor_pele      profissao  tipo_crime corporacao_policial situacao_policial
# 2745    Parda  APOSENTADO(A)  LATROCÍNIO                 NaN               NaN

# %%
#Corrigir idade_pessoa de 118 para 52 (2018-1966)
dfsp_geral.idade_pessoa.replace('118','52',inplace=True)

# %% [markdown]
# ###▶️ **Corrigindo a coluna Tipo_pessoa**

# %%
dfsp_geral['tipo_pessoa'].unique()
# Out:
# array(['Vítima', 'Autor/Vitima', 'Adolescente Inf/Vit', 'Adolescente',
#        'vítima', 'Encontro de Cadáver', 'Partes', 'Indiciado',
#        'Desaparecido', 'Investigado', 'Adolescente infrator', 'Autor'],
#       dtype=object)

# %%
#Corrigir palavra"Vítima'
dfsp_geral.tipo_pessoa.replace('vítima','Vítima',inplace=True)
dfsp_geral.tipo_pessoa.replace('Adolescente','Adolescente infrator',inplace=True)
dfsp_geral.tipo_pessoa.replace('Autor/Vitima','Autor/Vítima',inplace=True)

# %%
dfsp_geral['tipo_pessoa'].unique()
# Out:
# array(['Vítima', 'Autor/Vítima', 'Adolescente Inf/Vit',
#        'Adolescente infrator', 'Encontro de Cadáver', 'Partes',
#        'Indiciado', 'Desaparecido', 'Investigado', 'Autor'], dtype=object)

# %% [markdown]
# ###▶️ **Normalizando o dado Via Publica na coluna tipo_local_fato**

# %%
dfsp_geral['tipo_local_fato'].unique()
# Out:
# array(['Via pública', 'Residência', 'Comércio e serviços', 'Saúde',
#        'Area não ocupada', 'Condominio Comercial', 'Restaurante e afins',
#        'Hospedagem', 'Lazer e recreação', 'Repartição Pública',
#        'Centro Comerc./Empresarial', 'Serviços e bens públicos',
#        'Condominio Residencial', 'Terminal/Estação',
#        'Local clandestino/ilegal', 'Favela', 'Entidade assistencial',
#        'Rodovia/Estrada', 'Unidade rural', 'Templo e afins',
#        'Estabelecimento de ensino', 'Escritório',
#        'Estabelecimento prisional', nan, 'Carro Forte', 'Shopping Center',
#        'Via Pública', 'VIA PÚBLICA', 'Estabelecimento industrial',
#        'Estabelecimento bancário'], dtype=object)

# %%
#Corrigir palavra 'Via Publica'
dfsp_geral.tipo_local_fato.replace('VIA PÚBLICA','Via Pública',inplace=True)
dfsp_geral.tipo_local_fato.replace('Via pública','Via Pública',inplace=True)

# %%
dfsp_geral['tipo_local_fato'].unique()
# Out:
# array(['Via Pública', 'Residência', 'Comércio e serviços', 'Saúde',
#        'Area não ocupada', 'Condominio Comercial', 'Restaurante e afins',
#        'Hospedagem', 'Lazer e recreação', 'Repartição Pública',
#        'Centro Comerc./Empresarial', 'Serviços e bens públicos',
#        'Condominio Residencial', 'Terminal/Estação',
#        'Local clandestino/ilegal', 'Favela', 'Entidade assistencial',
#        'Rodovia/Estrada', 'Unidade rural', 'Templo e afins',
#        'Estabelecimento de ensino', 'Escritório',
#        'Estabelecimento prisional', nan, 'Carro Forte', 'Shopping Center',
#        'Estabelecimento industrial', 'Estabelecimento bancário'],
#       dtype=object)

# %% [markdown]
# ###▶️ **Normalizando Coluna dp_circunscrição**

# %%
dfsp_geral['dp_circunscricao'].unique()
# Out:
# array(['002 DP - Bom Retiro', '008 DP - Brás', '078 DP - Jardins',
#        '017 DP - Ipiranga', '083 DP - Parque Bristol',
#        '014 DP - Pinheiros', '023 DP - Perdizes', '037 DP - Campo Limpo',
#        '046 DP - Perus', '075 DP - Jardim Arpoador',
#        '087 DP - Vila Pereira Barreto', '089 DP - Portal do Morumbi',
#        '013 DP - Casa Verde', '038 DP - Vila Amália', '073 DP - Jaçanã',
#        '074 DP - Jaraguá', '010 DP - Penha de França',
#        '058 DP - Vila Formosa', '011 DP - Santo Amaro',
#        '025 DP - Parelheiros', '047 DP - Capão Redondo',
#        '085 DP - Jardim Mirna', '092 DP - Parque Santo Antônio',
#        '098 DP - Jardim Míriam', '100 DP - Jardim Herculano',
#        '101 DP - Jardim das Imbuias', '059 DP - Jardim Noemia',
#        '062 DP - Ermelino Matarazzo', '063 DP - Vila Jacuí',
#        '068 DP - Lajeado', '044 DP - Guaianazes',
#        '054 DP - Cidade Tiradentes', '055 DP - Parque São Rafael',
#        '070 DP - Vila Ema', '001 DP - Sé', '006 DP - Cambuci',
#        '077 DP - Santa Cecília', '009 DP - Carandiru',
#        '039 DP - Vila Gustavo', '045 DP - Vila Brasilândia',
#        '072 DP - Vila Penteado', '030 DP - Tatuapé',
#        '048 DP - Cidade Dutra', '080 DP - Vila Joaniza',
#        '099 DP - Campo Grande', '022 DP - São Miguel Paulista',
#        '024 DP - Ponte Rasa', '050 DP - Itaim Paulista',
#        '065 DP - Artur Alvim', '067 DP - Jardim Robru',
#        '049 DP - São Mateus', '053 DP - Parque do Carmo',
#        '066 DP - Vale do Aricanduva', '069 DP - Teotônio Vilela',
#        '003 DP - Campos Elísios', '005 DP - Aclimação',
#        '016 DP - Vila Clementino', '033 DP - Pirituba',
#        '093 DP - Jaguaré', '020 DP - Água Fria',
#        '028 DP - Freguesia do Ó', '029 DP - Vila Diva',
#        '042 DP - Parque São Lucas', '043 DP - Cidade Ademar',
#        '102 DP - Socorro', '032 DP - Itaquera',
#        '064 DP - Cidade A E Carvalho', '095 DP - Heliópolis',
#        '097 DP - Americanópolis', '034 DP - Vila Sonia',
#        '051 DP - Butantã', '040 DP - Vila Santa Maria',
#        '090 DP - Parque Novo Mundo', '021 DP - Vila Matilde',
#        '103 DP - Cohab Itaquera', '012 DP - Pari', '027 DP - Campo Belo',
#        '007 DP - Lapa', '026 DP - Sacomã', '019 DP - Vila Maria',
#        '004 DP - Consolação', '096 DP - Monções', '041 DP - Vila Rica',
#        '015 DP - Itaim Bibi', '091 DP - Ceagesp',
#        '052 DP - Parque São Jorge', '081 DP - Belém',
#        '036 DP - Vila Mariana', '035 DP - Jabaquara',
#        '057 DP - Parque da Moóca', '056 DP - Vila Alpina',
#        '018 DP - Alto da Moóca', '031 DP - Vila Carrão',
#        '003 DP - Campos Elíseos', '018 DP - Alto da Mooca',
#        '057 DP - Parque da Mooca', '05º D.P. ACLIMACAO'], dtype=object)

# %%
#Corrigir palavra"003 DP - Campos Elíseos'
dfsp_geral.dp_circunscricao.replace('003 DP - Campos Elísios','003 DP - Campos Elíseos',inplace=True)
dfsp_geral.dp_circunscricao.replace('02º D.P. BOM RETIRO','002 DP - Bom Retiro',inplace=True)
dfsp_geral.dp_circunscricao.replace('05º D.P. ACLIMACAO','005 DP - Aclimação',inplace=True)
dfsp_geral.dp_circunscricao.replace('057 DP - Parque da Moóca','057 DP - Parque da Mooca',inplace=True)
dfsp_geral.dp_circunscricao.replace('81º D.P. BELEM','081 DP - Belém',inplace=True)
dfsp_geral.dp_circunscricao.replace('018 DP - Alto da Moóca','018 DP - Alto da Mooca',inplace=True)

# %%
#Confirmando
dfsp_geral['dp_circunscricao'].unique()
# Out:
# array(['002 DP - Bom Retiro', '008 DP - Brás', '078 DP - Jardins',
#        '017 DP - Ipiranga', '083 DP - Parque Bristol',
#        '014 DP - Pinheiros', '023 DP - Perdizes', '037 DP - Campo Limpo',
#        '046 DP - Perus', '075 DP - Jardim Arpoador',
#        '087 DP - Vila Pereira Barreto', '089 DP - Portal do Morumbi',
#        '013 DP - Casa Verde', '038 DP - Vila Amália', '073 DP - Jaçanã',
#        '074 DP - Jaraguá', '010 DP - Penha de França',
#        '058 DP - Vila Formosa', '011 DP - Santo Amaro',
#        '025 DP - Parelheiros', '047 DP - Capão Redondo',
#        '085 DP - Jardim Mirna', '092 DP - Parque Santo Antônio',
#        '098 DP - Jardim Míriam', '100 DP - Jardim Herculano',
#        '101 DP - Jardim das Imbuias', '059 DP - Jardim Noemia',
#        '062 DP - Ermelino Matarazzo', '063 DP - Vila Jacuí',
#        '068 DP - Lajeado', '044 DP - Guaianazes',
#        '054 DP - Cidade Tiradentes', '055 DP - Parque São Rafael',
#        '070 DP - Vila Ema', '001 DP - Sé', '006 DP - Cambuci',
#        '077 DP - Santa Cecília', '009 DP - Carandiru',
#        '039 DP - Vila Gustavo', '045 DP - Vila Brasilândia',
#        '072 DP - Vila Penteado', '030 DP - Tatuapé',
#        '048 DP - Cidade Dutra', '080 DP - Vila Joaniza',
#        '099 DP - Campo Grande', '022 DP - São Miguel Paulista',
#        '024 DP - Ponte Rasa', '050 DP - Itaim Paulista',
#        '065 DP - Artur Alvim', '067 DP - Jardim Robru',
#        '049 DP - São Mateus', '053 DP - Parque do Carmo',
#        '066 DP - Vale do Aricanduva', '069 DP - Teotônio Vilela',
#        '003 DP - Campos Elíseos', '005 DP - Aclimação',
#        '016 DP - Vila Clementino', '033 DP - Pirituba',
#        '093 DP - Jaguaré', '020 DP - Água Fria',
#        '028 DP - Freguesia do Ó', '029 DP - Vila Diva',
#        '042 DP - Parque São Lucas', '043 DP - Cidade Ademar',
#        '102 DP - Socorro', '032 DP - Itaquera',
#        '064 DP - Cidade A E Carvalho', '095 DP - Heliópolis',
#        '097 DP - Americanópolis', '034 DP - Vila Sonia',
#        '051 DP - Butantã', '040 DP - Vila Santa Maria',
#        '090 DP - Parque Novo Mundo', '021 DP - Vila Matilde',
#        '103 DP - Cohab Itaquera', '012 DP - Pari', '027 DP - Campo Belo',
#        '007 DP - Lapa', '026 DP - Sacomã', '019 DP - Vila Maria',
#        '004 DP - Consolação', '096 DP - Monções', '041 DP - Vila Rica',
#        '015 DP - Itaim Bibi', '091 DP - Ceagesp',
#        '052 DP - Parque São Jorge', '081 DP - Belém',
#        '036 DP - Vila Mariana', '035 DP - Jabaquara',
#        '057 DP - Parque da Mooca', '056 DP - Vila Alpina',
#        '018 DP - Alto da Mooca', '031 DP - Vila Carrão'], dtype=object)

# %% [markdown]
# ###▶️ **Normalizando Coluna situacao_policial**

# %%
# Verificando dados
dfsp_geral['situacao_policial'].unique()
# Out:
# array([nan, 'serviço', 'folga', 'Serviço'], dtype=object)

# %%
# Corrigindo palavra serviço
dfsp_geral.situacao_policial.replace('Serviço','serviço',inplace=True)

# %%
# Verificando alteração
dfsp_geral['situacao_policial'].unique()
# Out:
# array([nan, 'serviço', 'folga'], dtype=object)

# %% [markdown]
# ###▶️ **Verificando a coluna sexo_pessoa e corrigindo**

# %%
# Verificando dados
dfsp_geral.groupby(['sexo_pessoa'],dropna=False).size().sort_values(ascending=False)
# Out:
# sexo_pessoa
# Masculino     3704
# Feminino       403
# Indefinido      54
# dtype: int64

# %%
# Corrigindo palavra
dfsp_geral.sexo_pessoa.replace('masculino','Masculino',inplace=True)

# %%
# Verificando correção
dfsp_geral.groupby(['sexo_pessoa'],dropna=False).size().sort_values(ascending=False)
# Out:
# sexo_pessoa
# Masculino     3704
# Feminino       403
# Indefinido      54
# dtype: int64

# %%
# Padronizando Indefinido para 
dfsp_geral['sexo_pessoa'].replace('Indefinido', 'Desconhecido', inplace=True)

# %% [markdown]
# ###▶️ **Normalizando dados em cor_pele**

# %%
dfsp_geral.groupby(['cor_pele'],dropna=False).size().sort_values(ascending=False)
# Out:
# cor_pele
# Parda            2085
# Branca           1491
# Preta             421
# Ignorada          124
# Amarela            27
# Não informada      10
# Vermelha            2
# Outros              1
# dtype: int64

# %%
#Corrigir palavra
dfsp_geral.cor_pele.replace('preta','Preta',inplace=True)
dfsp_geral.cor_pele.replace('Outros','Não informada',inplace=True)
dfsp_geral.cor_pele.replace('Ignorada','Não informada',inplace=True)

# %%
dfsp_geral.groupby(['cor_pele'],dropna=False).size().sort_values(ascending=False)
# Out:
# cor_pele
# Parda            2085
# Branca           1491
# Preta             421
# Não informada     135
# Amarela            27
# Vermelha            2
# dtype: int64

# %% [markdown]
# ###▶️ **Verificando profissao**

# %%
# dfsp_geral['profissao'].astype(str)
dfsp_geral['profissao'].unique()
# Out:
# array([nan, 'CABELEIREIRO(A)', 'COMERCIANTE', 'APOSENTADO(A)',
#        'DESEMPREGADO', 'LAVADOR', 'ESTUDANTE', 'NAO INFORMADA',
#        'AJUDANTE', 'DESEMPREGADO(A)', 'RELOJOEIRO(A)', 'PEDREIRO',
#        'TECNICO EM ENFERMAGEM', 'FISCAL', 'AUTONOMO(A)',
#        'AJUDANTE DE PEDREIRO', 'FUNILEIRO(A)', 'MOTORISTA', 'FRENTISTA',
#        'COSTUREIRO(A)', 'VIGILANTE', 'SERVENTE', 'ATENDENTE',
#        'AUXILIAR DE FARMACIA', 'GRAFICO(A)', 'BALCONISTA',
#        'AJUDANTE DE MOTORISTA', 'ENCARREGADO', 'POLICIAL MILITAR',
#        'AGENTE DE SEGURANCA', 'VENDEDOR(A)', 'VENDEDOR(A) AMBULANTE',
#        'AUXILIAR DE MECANICO', 'PRENDAS DOMESTICAS',
#        'OPERADOR DE MAQUINA', 'DENTISTA', 'AJUDANTE DE ELETRICISTA',
#        'ENCANADOR(A)', 'PINTOR DE PAREDES', 'JARDINEIRO(A)',
#        'POLIDOR DE VEICULOS', 'AUXILIAR DE ENFERMAGEN', 'ENFERMEIRO(A)',
#        'AJUDANTE DE COZINHA', 'PORTEIRO(A)', 'MOTO-BOY', 'PROMOTOR(A)',
#        'PINTOR(A)', 'MECANICO(A)', 'MONTADOR(A)', 'SEGURANCA',
#        'AJUDANTE DE PINTOR', 'PROMOTOR DE VENDAS', 'AJUDANTE GERAL',
#        'MEDICO VETERINARIO', 'CASEIRO(A)', 'OUTROS', 'TAXISTA',
#        'AUXILIAR DE LIMPEZA', 'TECNICO EM TELECOMUNICACOES',
#        'REPOSITOR(A)', 'TECNICO(A)', 'ANESTESISTA',
#        'CONTROLADOR(A) DE QUALIDADE', 'ANALISTA', 'ENTREGADOR DE GAS',
#        'AUXILIAR DE SERVIÇOS GERAIS', 'INSTALADOR(A)', 'ESTAMPADOR(A)',
#        'MUSICO(A)', 'EMPREGADO DOMESTICO', 'GARÇON(ETE)',
#        'TECNICO EM REFRIGERACAO', 'GERENTE', 'CARTEIRO(A)',
#        'CARPINTEIRO(A)', 'GARI', 'SERRALHEIRO(A)', 'FEIRANTE', 'CHAPA',
#        'COZINHEIRO(A)', 'SAPATEIRO(A)', 'FAXINEIRO(A)', 'PIZZAIOLO(A)',
#        'SEM PROFISSAO DEFINIDA', 'PROFESSOR(A)', 'BARBEIRO', 'DESIGNER',
#        'ARTESAO(A)', 'BOMBEIRO(A)', 'COLETOR', 'ARMADOR(A)',
#        'AUXILIAR DE EXPEDICAO', 'CONTADOR(A)', 'CONFEITEIRO(A)',
#        'MICRO-EMPRESARIO', 'ENGENHEIRO(A)', 'EMPRESARIO(A)', 'ZELADOR(A)',
#        'POLICIAL CIVIL', 'ADVOGADO(A)', 'ANALISTA DE SUPORTE',
#        'PROCURADOR(A)', 'AUXILIAR ADMINISTRATIVO', 'ELETRICISTA',
#        'RECEPCIONISTA', 'OPERADOR DE CAIXA', 'ACOUGUEIRO(A)',
#        'SERVENTUARIO(A) DA JUSTICA', 'SOLDADOR(A)', 'MOTOTAXISTA',
#        'COBRADOR(A)', 'AUXILIAR DE LABORATORIO', 'WEB DESIGNER',
#        'GESSEIRO(A)', 'AGENTE PENITENCIARIO', 'CAIXA',
#        'ATENDENTE DE LANCHANOTE', 'AUXILIAR DE GARCOM',
#        'LIMPADOR DE VIDROS', 'AUXILIAR DE PRODUCAO',
#        'ENCARREGADO(A) DE SETOR', 'PROMOTOR DE EVENTOS', 'ESTOQUISTA',
#        'ENGENHEIRO CIVIL', 'AJUDANTE DE SERRALHEIRO',
#        'ADMINISTRADOR DE EMPRESAS', 'METALURGICO(A)', 'CAMINHONEIRO',
#        'FOTOGRAFO(A)', 'MECANICO DE AUTOMOVEL', 'PENSIONISTA',
#        'AGENTE OPERACIONAL', 'MODELISTA', 'OPERADOR DE PRODUCAO',
#        'MARCENEIRO(A)', 'CALDEIREIRO', 'OFFICE-BOY', 'VIDRACEIRO(A)',
#        'SUPERVISOR(A)', 'AUXILIAR DE ESCRITÓRIO', 'PEIXEIRO', 'MANICURE',
#        'SONOPLASTA', 'BORRACHEIRO(A)', 'LAMINADOR(A)',
#        'MONTADOR DE MOVEIS MADEIRA', 'MECANICO(A) DE MANUTENCAO',
#        'ENTREGADOR DE PIZZA', 'OPERADOR(A) TELEMARKETING',
#        'FARMACEUTICO(A)', 'LAVADOR(A) DE CARRO', 'DESPACHANTE',
#        'ARTISTA PLASTICO', 'PRENSISTA', 'CORRETOR(A) DE IMOVEIS',
#        'METROVIARIO(A)', 'PANFLETEIRO', 'OPERADOR DE COMPUTADOR',
#        'ANALISTA QUIMICO', 'OPERADOR DE MARKETING', 'POLICIAL FEDERAL',
#        'AUDITOR(A)', 'MOTORISTA DE AMBULANCIA', 'ENCARREGADO DE OBRAS',
#        'EMPREITEIRO(A)', 'ENTREGADOR(A)', 'RECICLADOR',
#        'GUARDA MUNICIPAL', 'INSTRUMENTADOR CIRURGICO', 'CORRETOR(A)',
#        'PROSTITUTA', 'TECNICO(A) EM INFORMATICA', 'PINTOR DE AUTOMOVEIS',
#        'AGRICULTOR(A)', 'FAXINEIRO(A', 'ASSESSOR PARLAMENTAR',
#        'CONSELHEIRO(A) TUTELAR', 'ASSISTENTE ADMINISTRATIVO',
#        'MANEQUIM/MODELO', 'CARREGADOR(A)', 'MEDICO(A)', 'TECNOLOGO',
#        'ELETRICISTA DE AUTOMOVEIS', 'BABÁ', 'SERVIDOR PUBLICO ESTADUAL',
#        'TATUADOR', 'ANALISTA FINANCEIRO', 'ATENDENTE PORTARIA HOTEL',
#        'CHURRASQUEIRO', 'JORNALISTA', 'POLICIAL MILITAR aposentado',
#        'ARQUITETO(A)', 'ASSISTENTE JUDICIARIO', 'DELEGADO(A)',
#        'DIRETOR(A) DE ENSINO', 'TECNICO EM RAIO X', 'AGENTE DE APOIO',
#        'CORTADOR', 'ANALISTA DE SISTEMAS', 'FUNCION.PUBLICO ESTADUAL',
#        'ESTAGIARIO(A)', 'CHAVEIRO(A)', 'ECONOMISTA', 'COMPRADOR(A)',
#        'SUPERVISOR DE SEGURANCA', 'AUXILIAR DE ESTOQUE',
#        'AUXILIAR OPERACIONAL', 'BANCARIO(A)', 'DIRETOR(A)',
#        'GERENTE COMERCIAL', 'MENSAGEIRO(A)', 'CHEFE',
#        'GUARDADOR DE CARROS', 'LAVRADOR(A)', 'FORNEIRO(A)', 'PADEIRO(A)',
#        'PROTETICO(A)', 'DESEMPREGADO(A', 'AUXILIAR DE MANUTENCAO',
#        'OPERARIO(A)', 'EMPACOTADOR', 'JARDINEIRO(A',
#        'REPRESENTANTE COMERCIAL', 'AUXILIAR GERAL', 'EMBALADOR(A)'],
#       dtype=object)

# %%
#Renomeando Profissoes
dfsp_geral.profissao.replace({'APOSENTADO':'APOSENTADO(A)','APOSENTADO(A':'APOSENTADO(A)',
                            'AUTONOMO': 'AUTONOMO(A)', 'AUTONOMO(A':'AUTONOMO(A)',
                            'DESEMPREGADO': 'DESEMPREGADO(A)', 'DESEMPREGADO(': 'DESEMPREGADO(A)',
                            'DESEMPREGADO(A': 'DESEMPREGADO(A)',
                            'FAXINEIRO(A':'FAXINEIRO(A)', 
                            'JARDINEIRO(A': 'JARDINEIRO(A)',
                            'NAO INFORMADA' : np.nan,
                            'POLICIAL MILITAR - REFORMADO': 'POLICIAL MILITAR REFORMADO',
                            'POLICIAL MILITAR aposentado': 'POLICIAL MILITAR APOSENTADO',
                            'PROFESSOR': 'PROFESSOR(A)', 
                            'REPOSITOR':'REPOSITOR(A)'}, inplace=True)

# %%
dfsp_geral.groupby(['profissao'],dropna=False).size().sort_values(ascending=False)
# Out:
# profissao
# NaN                        2069
# ESTUDANTE                   360
# DESEMPREGADO(A)             323
# AUTONOMO(A)                 114
# COMERCIANTE                  76
#                            ...
# GUARDADOR DE CARROS           1
# AUXILIAR DE LABORATORIO       1
# AUXILIAR DE MANUTENCAO        1
# GERENTE COMERCIAL             1
# FARMACEUTICO(A)               1
# Length: 221, dtype: int64

# %% [markdown]
# ###▶️ **Replace em Corporacao**

# %%
dfsp_geral.groupby(['corporacao_policial'],dropna=False).size().sort_values(ascending=False)
# Out:
# corporacao_policial
# NaN    2996
# PM     1116
# PC       49
# dtype: int64

# %%
#Corrigir palavra
dfsp_geral.corporacao_policial.replace('PM','Polícia Militar',inplace=True)
dfsp_geral.corporacao_policial.replace('PC','Polícia Civil',inplace=True)

# %%
dfsp_geral
# Out:
#          cidade          dp_circunscricao  n_vitimas              dt_fato  \
# 0     São Paulo       002 DP - Bom Retiro        1.0  2018-01-06 00:00:00
# 1     São Paulo       002 DP - Bom Retiro        1.0  2018-01-06 00:00:00
# 2     São Paulo             008 DP - Brás        1.0  2018-01-18 00:00:00
# 3     São Paulo          078 DP - Jardins        1.0  2018-01-02 00:00:00
# 4     São Paulo         017 DP - Ipiranga        1.0  2018-01-14 00:00:00
# ...         ...                       ...        ...                  ...
# 4268  São Paulo            046 DP - Perus        NaN  2021-12-22 00:00:00
# 4269  São Paulo        041 DP - Vila Rica        NaN  2021-12-27 00:00:00
# 4270  São Paulo  069 DP - Teotônio Vilela        NaN  2021-12-29 00:00:00
# 4271  São Paulo   003 DP - Campos Elíseos        NaN  2021-12-29 00:00:00
# 4272  São Paulo        041 DP - Vila Rica        NaN  2021-12-29 00:00:00
#
#      hora_fato      tipo_local_fato  \
# 0     20:06:00          Via Pública
# 1     19:00:00           Residência
# 2     18:00:00  Comércio e serviços
# 3     18:48:00           Residência
# 4     15:00:00          Via Pública
# ...        ...                  ...
# 4268  01:20:00          Via Pública
# 4269  21:15:00          Via Pública
# 4270  12:45:00           Residência
# 4271  23:45:00           Hospedagem
# 4272  22:52:00          Via Pública
#
#                                         logradouro n_logradouro   latitude  \
# 0                AVENIDA PRESIDENTE CASTELO BRANCO          NaN -23.523712
# 1     DA VEDAÇÃO DA DIVULGAÇÃO DOS DADOS RELATIVOS          NaN        NaN
# 2                                     RUA DA MOOCA          NaN   -23.5539
# 3     DA VEDAÇÃO DA DIVULGAÇÃO DOS DADOS RELATIVOS          NaN        NaN
# 4                          RUA DOM MARCOS TEIXEIRA          NaN -23.585876
# ...                                            ...          ...        ...
# 4268                                 RUA DINAMARCA          NaN -23.415827
# 4269                            RUA DOS BANQUEIROS          NaN -23.586236
# 4270  DA VEDAÇÃO DA DIVULGAÇÃO DOS DADOS RELATIVOS          NaN        NaN
# 4271                            RUA GENERAL OSORIO          NaN -23.537508
# 4272                        AVENIDA RIO DAS PEDRAS          NaN -23.569583
#
#       longitude   tipo_pessoa sexo_pessoa idade_pessoa       dt_nasc_pessoa  \
# 0    -46.606388        Vítima   Masculino          NaN                  NaT
# 1           NaN        Vítima   Masculino         44.0  1973-06-06 00:00:00
# 2    -46.617413        Vítima    Feminino         59.0  1958-08-02 00:00:00
# 3           NaN        Vítima    Feminino          0.0  2017-09-16 00:00:00
# 4    -46.598195        Vítima    Feminino          NaN                  NaT
# ...         ...           ...         ...          ...                  ...
# 4268 -46.747289  Autor/Vítima   Masculino           28  1993-05-19 00:00:00
# 4269 -46.523283  Autor/Vítima   Masculino           32  1989-09-29 00:00:00
# 4270        NaN  Autor/Vítima   Masculino          NaN                  NaN
# 4271  -46.64165  Autor/Vítima   Masculino          NaN                  NaN
# 4272 -46.508261  Autor/Vítima   Masculino           27  1994-03-16 00:00:00
#
#            cor_pele        profissao  \
# 0     Não informada              NaN
# 1            Branca  CABELEIREIRO(A)
# 2             Parda      COMERCIANTE
# 3            Branca              NaN
# 4     Não informada              NaN
# ...             ...              ...
# 4268          Parda  DESEMPREGADO(A)
# 4269          Parda         AJUDANTE
# 4270          Parda              NaN
# 4271         Branca              NaN
# 4272          Parda              NaN
#
#                                     tipo_crime corporacao_policial  \
# 0                             HOMICÍDIO DOLOSO                 NaN
# 1                             HOMICÍDIO DOLOSO                 NaN
# 2                             HOMICÍDIO DOLOSO                 NaN
# 3                             HOMICÍDIO DOLOSO                 NaN
# 4                             HOMICÍDIO DOLOSO                 NaN
# ...                                        ...                 ...
# 4268  MORTE DECORRENTE DE INTERVENÇÃO POLICIAL     Polícia Militar
# 4269  MORTE DECORRENTE DE INTERVENÇÃO POLICIAL     Polícia Militar
# 4270  MORTE DECORRENTE DE INTERVENÇÃO POLICIAL     Polícia Militar
# 4271  MORTE DECORRENTE DE INTERVENÇÃO POLICIAL     Polícia Militar
# 4272  MORTE DECORRENTE DE INTERVENÇÃO POLICIAL     Polícia Militar
#
#      situacao_policial
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 4268           serviço
# 4269           serviço
# 4270           serviço
# 4271           serviço
# 4272           serviço
#
# [4161 rows x 19 columns]

# %% [markdown]
# ###▶️ **Normalizando dados coluna hora_fato**

# %%
dfsp_geral['hora_fato'].unique()
# Out:
# array(['20:06:00', '19:00:00', '18:00:00', ..., '11:28:00', '12:48:00',
#        '05:25:00'], dtype=object)

# %%
# Verificando dados
ft = dfsp_geral['hora_fato'] == 'EM HORA INCERTA'
dfsp_geral['hora_fato'].loc[ft].count()
# Out:
# 24

# %% [markdown]
# Vamos normalizar os dados pela média para conseguir juntar em datetime segundo os dados abaixo:
# - 'PELA MANHÃ          ', == '09:00:00'
# - 'PELA MANHÃ', == '09:00:00'
# - 'NÃO INFORMADO', == '23:59:00'
# - 'EM HORA INCERTA', == '23:59:00'
# - 'DE MADRUGADA', == '03:00:00'
# - 'A TARDE', == '15:00:00'
# - 'A NOITE', == '21:00:00'
#
# **Obs**: Reservamos o horario '23:59:00' para colocar os valores nulos pois não havia nenhuma ocorrência neste horario.

# %%
sorted(dfsp_geral['hora_fato'].unique(), reverse= True)
# Out:
# ['PELA MANHÃ          ',
#  'PELA MANHÃ',
#  'EM HORA INCERTA',
#  'DE MADRUGADA',
#  'A TARDE',
#  'A NOITE',
#  '23:58:00',
#  '23:56:00',
#  '23:55:00',
#  '23:54:00',
#  '23:53:00',
#  '23:52:00',
#  '23:50:00',
#  '23:49:00',
#  '23:48:00',
#  '23:47:00',
#  '23:46:00',
#  '23:45:00',
#  '23:44:00',
#  '23:43:00',
#  '23:42:00',
#  '23:41:00',
#  '23:40:00',
#  '23:39:00',
#  '23:38:00',
#  '23:37:00',
#  '23:36:00',
#  '23:35:00',
#  '23:34:00',
#  '23:33:00',
#  '23:32:00',
#  '23:31:00',
#  '23:30:00',
#  '23:29:00',
#  '23:27:00',
#  '23:26:00',
#  '23:25:00',
#  '23:24:00',
#  '23:23:00',
#  '23:22:00',
#  '23:21:00',
#  '23:20:00',
#  '23:19:00',
#  '23:18:00',
#  '23:17:00',
#  '23:15:00',
#  '23:14:00',
#  '23:12:00',
#  '23:11:00',
#  '23:10:00',
#  '23:09:00',
#  '23:08:00',
#  '23:07:00',
#  '23:06:00',
#  '23:05:00',
#  '23:03:00',
#  '23:00:00',
#  '22:59:00',
#  '22:58:00',
#  '22:57:00',
#  '22:55:00',
#  '22:54:00',
#  '22:53:00',
#  '22:52:00',
#  '22:51:00',
#  '22:50:00',
#  '22:49:00',
#  '22:48:00',
#  '22:47:00',
#  '22:46:00',
#  '22:45:00',
#  '22:43:00',
#  '22:42:00',
#  '22:41:00',
#  '22:40:00',
#  '22:39:00',
#  '22:37:00',
#  '22:36:00',
#  '22:35:00',
#  '22:33:00',
#  '22:32:00',
#  '22:31:00',
#  '22:30:00',
#  '22:29:00',
#  '22:28:00',
#  '22:27:00',
#  '22:25:00',
#  '22:22:00',
#  '22:21:00',
#  '22:20:00',
#  '22:19:00',
#  '22:18:00',
#  '22:17:00',
#  '22:16:00',
#  '22:15:00',
#  '22:14:00',
#  '22:12:00',
#  '22:11:00',
#  '22:10:00',
#  '22:09:00',
#  '22:07:00',
#  '22:06:00',
#  '22:05:00',
#  '22:04:00',
#  '22:03:00',
#  '22:02:00',
#  '22:00:00',
#  '21:59:00',
#  '21:58:00',
#  '21:57:00',
#  '21:56:00',
#  '21:55:00',
#  '21:54:00',
#  '21:53:00',
#  '21:52:00',
#  '21:51:00',
#  '21:50:00',
#  '21:49:00',
#  '21:48:00',
#  '21:47:00',
#  '21:46:00',
#  '21:45:00',
#  '21:44:00',
#  '21:43:00',
#  '21:42:00',
#  '21:41:00',
#  '21:40:00',
#  '21:39:00',
#  '21:38:00',
#  '21:37:00',
#  '21:36:00',
#  '21:35:00',
#  '21:34:00',
#  '21:33:00',
#  '21:32:00',
#  '21:30:00',
#  '21:29:00',
#  '21:28:00',
#  '21:27:00',
#  '21:25:00',
#  '21:24:00',
#  '21:23:00',
#  '21:22:00',
#  '21:21:00',
#  '21:20:00',
#  '21:19:00',
#  '21:17:00',
#  '21:16:00',
#  '21:15:00',
#  '21:14:00',
#  '21:11:00',
#  '21:10:00',
#  '21:09:00',
#  '21:08:00',
#  '21:06:00',
#  '21:05:00',
#  '21:04:00',
#  '21:03:00',
#  '21:02:00',
#  '21:01:00',
#  '21:00:00',
#  '20:59:00',
#  '20:58:00',
#  '20:57:00',
#  '20:55:00',
#  '20:53:00',
#  '20:52:00',
#  '20:51:00',
#  '20:50:00',
#  '20:49:00',
#  '20:48:00',
#  '20:47:00',
#  '20:45:00',
#  '20:43:00',
#  '20:41:00',
#  '20:40:00',
#  '20:39:00',
#  '20:38:00',
#  '20:36:00',
#  '20:35:00',
#  '20:34:00',
#  '20:33:00',
#  '20:32:00',
#  '20:31:00',
#  '20:30:00',
#  '20:28:00',
#  '20:27:00',
#  '20:26:00',
#  '20:25:00',
#  '20:24:00',
#  '20:23:00',
#  '20:20:00',
#  '20:19:00',
#  '20:18:00',
#  '20:17:00',
#  '20:16:00',
#  '20:15:00',
#  '20:14:00',
#  '20:13:00',
#  '20:12:00',
#  '20:11:00',
#  '20:10:00',
#  '20:09:00',
#  '20:07:00',
#  '20:06:00',
#  '20:05:00',
#  '20:04:00',
#  '20:03:00',
#  '20:02:00',
#  '20:01:00',
#  '20:00:00',
#  '19:59:00',
#  '19:58:00',
#  '19:57:00',
#  '19:56:00',
#  '19:55:00',
#  '19:54:00',
#  '19:53:00',
#  '19:52:00',
#  '19:51:00',
#  '19:50:00',
#  '19:48:00',
#  '19:47:00',
#  '19:46:00',
#  '19:45:00',
#  '19:44:00',
#  '19:43:00',
#  '19:42:00',
#  '19:41:00',
#  '19:40:00',
#  '19:38:00',
#  '19:37:00',
#  '19:36:00',
#  '19:35:00',
#  '19:34:00',
#  '19:31:00',
#  '19:30:00',
#  '19:29:00',
#  '19:28:00',
#  '19:27:00',
#  '19:26:00',
#  '19:25:00',
#  '19:24:00',
#  '19:23:00',
#  '19:22:00',
#  '19:21:00',
#  '19:20:00',
#  '19:19:00',
#  '19:18:00',
#  '19:15:00',
#  '19:14:00',
#  '19:12:00',
#  '19:10:00',
#  '19:09:00',
#  '19:08:00',
#  '19:07:00',
#  '19:06:00',
#  '19:05:00',
#  '19:03:00',
#  '19:02:00',
#  '19:00:00',
#  '18:59:00',
#  '18:58:00',
#  '18:55:00',
#  '18:54:00',
#  '18:53:00',
#  '18:52:00',
#  '18:50:00',
#  '18:49:00',
#  '18:48:00',
#  '18:46:00',
#  '18:45:00',
#  '18:44:00',
#  '18:43:00',
#  '18:42:00',
#  '18:40:00',
#  '18:37:00',
#  '18:36:00',
#  '18:35:00',
#  '18:34:00',
#  '18:33:00',
#  '18:31:00',
#  '18:30:00',
#  '18:29:00',
#  '18:27:00',
#  '18:26:00',
#  '18:25:00',
#  '18:21:00',
#  '18:20:00',
#  '18:19:00',
#  '18:15:00',
#  '18:14:00',
#  '18:13:00',
#  '18:11:00',
#  '18:10:00',
#  '18:08:00',
#  '18:07:00',
#  '18:05:00',
#  '18:02:00',
#  '18:00:00',
#  '17:59:00',
#  '17:58:00',
#  '17:56:00',
#  '17:55:00',
#  '17:54:00',
#  '17:53:00',
#  '17:52:00',
#  '17:50:00',
#  '17:49:00',
#  '17:48:00',
#  '17:45:00',
#  '17:42:00',
#  '17:41:00',
#  '17:40:00',
#  '17:38:00',
#  '17:37:00',
#  '17:36:00',
#  '17:35:00',
#  '17:33:00',
#  '17:31:00',
#  '17:30:00',
#  '17:27:00',
#  '17:26:00',
#  '17:25:00',
#  '17:22:00',
#  '17:21:00',
#  '17:20:00',
#  '17:16:00',
#  '17:15:00',
#  '17:14:00',
#  '17:10:00',
#  '17:08:00',
#  '17:04:00',
#  '17:03:00',
#  '17:00:00',
#  '16:56:00',
#  '16:55:00',
#  '16:53:00',
#  '16:52:00',
#  '16:51:00',
#  '16:50:00',
#  '16:48:00',
#  '16:47:00',
#  '16:45:00',
#  '16:43:00',
#  '16:42:00',
#  '16:40:00',
#  '16:39:00',
#  '16:38:00',
#  '16:36:00',
#  '16:35:00',
#  '16:33:00',
#  '16:32:00',
#  '16:30:00',
#  '16:26:00',
#  '16:25:00',
#  '16:24:00',
#  '16:21:00',
#  '16:20:00',
#  '16:19:00',
#  '16:17:00',
#  '16:15:00',
#  '16:14:00',
#  '16:12:00',
#  '16:10:00',
#  '16:07:00',
#  '16:06:00',
#  '16:05:00',
#  '16:04:00',
#  '16:03:00',
#  '16:02:00',
#  '16:00:00',
#  '15:58:00',
#  '15:56:00',
#  '15:55:00',
#  '15:51:00',
#  '15:50:00',
#  '15:48:00',
#  '15:45:00',
#  '15:43:00',
#  '15:42:00',
#  '15:41:00',
#  '15:40:00',
#  '15:39:00',
#  '15:36:00',
#  '15:35:00',
#  '15:33:00',
#  '15:32:00',
#  '15:30:00',
#  '15:27:00',
#  '15:24:00',
#  '15:21:00',
#  '15:20:00',
#  '15:19:00',
#  '15:18:00',
#  '15:17:00',
#  '15:16:00',
#  '15:15:00',
#  '15:14:00',
#  '15:12:00',
#  '15:11:00',
#  '15:10:00',
#  '15:08:00',
#  '15:05:00',
#  '15:03:00',
#  '15:00:00',
#  '14:59:00',
#  '14:55:00',
#  '14:53:00',
#  '14:52:00',
#  '14:51:00',
#  '14:50:00',
#  '14:49:00',
#  '14:46:00',
#  '14:45:00',
#  '14:43:00',
#  '14:42:00',
#  '14:40:00',
#  '14:39:00',
#  '14:38:00',
#  '14:37:00',
#  '14:35:00',
#  '14:34:00',
#  '14:32:00',
#  '14:31:00',
#  '14:30:00',
#  '14:28:00',
#  '14:26:00',
#  '14:25:00',
#  '14:24:00',
#  '14:22:00',
#  '14:20:00',
#  '14:18:00',
#  '14:17:00',
#  '14:16:00',
#  '14:15:00',
#  '14:12:00',
#  '14:11:00',
#  '14:10:00',
#  '14:09:00',
#  '14:08:00',
#  '14:07:00',
#  '14:05:00',
#  '14:02:00',
#  '14:01:00',
#  '14:00:00',
#  '13:59:00',
#  '13:58:00',
#  '13:55:00',
#  '13:50:00',
#  '13:49:00',
#  '13:48:00',
#  '13:45:00',
#  '13:41:00',
#  '13:40:00',
#  '13:39:00',
#  '13:38:00',
#  '13:35:00',
#  '13:33:00',
#  '13:32:00',
#  '13:31:00',
#  '13:30:00',
#  '13:29:00',
#  '13:28:00',
#  '13:25:00',
#  '13:22:00',
#  '13:20:00',
#  '13:19:00',
#  '13:18:00',
#  '13:17:00',
#  '13:15:00',
#  '13:14:00',
#  '13:12:00',
#  '13:10:00',
#  '13:09:00',
#  '13:07:00',
#  '13:05:00',
#  '13:03:00',
#  '13:02:00',
#  '13:00:00',
#  '12:57:00',
#  '12:55:00',
#  '12:54:00',
#  '12:53:00',
#  '12:52:00',
#  '12:51:00',
#  '12:50:00',
#  '12:48:00',
#  '12:46:00',
#  '12:45:00',
#  '12:40:00',
#  '12:37:00',
#  '12:36:00',
#  '12:35:00',
#  '12:34:00',
#  '12:30:00',
#  '12:28:00',
#  '12:27:00',
#  '12:25:00',
#  '12:23:00',
#  '12:22:00',
#  '12:20:00',
#  '12:17:00',
#  '12:15:00',
#  '12:12:00',
#  '12:11:00',
#  '12:10:00',
#  '12:09:00',
#  '12:08:00',
#  '12:07:00',
#  '12:05:00',
#  '12:03:00',
#  '12:00:00',
#  '11:55:00',
#  '11:54:00',
#  '11:52:00',
#  '11:50:00',
#  '11:49:00',
#  '11:48:00',
#  '11:46:00',
#  '11:45:00',
#  '11:44:00',
#  '11:43:00',
#  '11:42:00',
#  '11:41:00',
#  '11:40:00',
#  '11:39:00',
#  '11:38:00',
#  '11:37:00',
#  '11:36:00',
#  '11:35:00',
#  '11:34:00',
#  '11:31:00',
#  '11:30:00',
#  '11:29:00',
#  '11:28:00',
#  '11:25:00',
#  '11:24:00',
#  '11:23:00',
#  '11:22:00',
#  '11:21:00',
#  '11:20:00',
#  '11:16:00',
#  '11:15:00',
#  '11:14:00',
#  '11:13:00',
#  '11:12:00',
#  '11:10:00',
#  '11:08:00',
#  '11:04:00',
#  '11:01:00',
#  '11:00:00',
#  '10:58:00',
#  '10:55:00',
#  '10:53:00',
#  '10:52:00',
#  '10:51:00',
#  '10:50:00',
#  '10:48:00',
#  '10:46:00',
#  '10:45:00',
#  '10:44:00',
#  '10:42:00',
#  '10:41:00',
#  '10:40:00',
#  '10:39:00',
#  '10:38:00',
#  '10:36:00',
#  '10:35:00',
#  '10:34:00',
#  '10:33:00',
#  '10:30:00',
#  '10:29:00',
#  '10:24:00',
#  '10:22:00',
#  '10:20:00',
#  '10:18:00',
#  '10:16:00',
#  '10:13:00',
#  '10:12:00',
#  '10:11:00',
#  '10:10:00',
#  '10:07:00',
#  '10:06:00',
#  '10:05:00',
#  '10:04:00',
#  '10:02:00',
#  '10:01:00',
#  '10:00:00',
#  '09:58:00',
#  '09:55:00',
#  '09:52:00',
#  '09:50:00',
#  '09:48:00',
#  '09:45:00',
#  '09:42:00',
#  '09:40:00',
#  '09:38:00',
#  '09:37:00',
#  '09:35:00',
#  '09:34:00',
#  '09:32:00',
#  '09:31:00',
#  '09:30:00',
#  '09:28:00',
#  '09:27:00',
#  '09:26:00',
#  '09:25:00',
#  '09:23:00',
#  '09:20:00',
#  '09:18:00',
#  '09:15:00',
#  '09:10:00',
#  '09:09:00',
#  '09:08:00',
#  '09:07:00',
#  '09:06:00',
#  '09:05:00',
#  '09:03:00',
#  '09:02:00',
#  '09:00:00',
#  '08:58:00',
#  '08:57:00',
#  '08:55:00',
#  '08:50:00',
#  '08:49:00',
#  '08:48:00',
#  '08:45:00',
#  '08:44:00',
#  '08:42:00',
#  '08:41:00',
#  '08:40:00',
#  '08:39:00',
#  '08:36:00',
#  '08:35:00',
#  '08:34:00',
#  '08:33:00',
#  '08:30:00',
#  '08:28:00',
#  '08:26:00',
#  '08:25:00',
#  '08:24:00',
#  '08:23:00',
#  '08:22:00',
#  '08:20:00',
#  '08:19:00',
#  '08:18:00',
#  '08:17:00',
#  '08:16:00',
#  '08:15:00',
#  '08:13:00',
#  '08:10:00',
#  '08:08:00',
#  '08:07:00',
#  '08:06:00',
#  '08:05:00',
#  '08:03:00',
#  '08:02:00',
#  '08:00:00',
#  '07:55:00',
#  '07:54:00',
#  '07:52:00',
#  '07:51:00',
#  '07:50:00',
#  '07:46:00',
#  '07:45:00',
#  '07:44:00',
#  '07:43:00',
#  '07:42:00',
#  '07:41:00',
#  '07:40:00',
#  '07:39:00',
#  '07:37:00',
#  '07:36:00',
#  '07:35:00',
#  '07:34:00',
#  '07:32:00',
#  '07:31:00',
#  '07:30:00',
#  '07:29:00',
#  '07:28:00',
#  '07:27:00',
#  '07:26:00',
#  '07:25:00',
#  '07:23:00',
#  '07:22:00',
#  '07:20:00',
#  '07:19:00',
#  '07:16:00',
#  '07:15:00',
#  '07:13:00',
#  '07:10:00',
#  '07:09:00',
#  '07:06:00',
#  '07:05:00',
#  '07:04:00',
#  '07:02:00',
#  '07:01:00',
#  '07:00:00',
#  '06:58:00',
#  '06:57:00',
#  '06:55:00',
#  '06:53:00',
#  '06:52:00',
#  '06:51:00',
#  '06:50:00',
#  '06:49:00',
#  '06:46:00',
#  '06:45:00',
#  '06:44:00',
#  '06:43:00',
#  '06:42:00',
#  '06:41:00',
#  '06:40:00',
#  '06:39:00',
#  '06:38:00',
#  '06:37:00',
#  '06:36:00',
#  '06:35:00',
#  '06:34:00',
#  '06:33:00',
#  '06:32:00',
#  '06:30:00',
#  '06:29:00',
#  '06:28:00',
#  '06:27:00',
#  '06:26:00',
#  '06:25:00',
#  '06:24:00',
#  '06:23:00',
#  '06:20:00',
#  '06:18:00',
#  '06:17:00',
#  '06:16:00',
#  '06:15:00',
#  '06:13:00',
#  '06:12:00',
#  '06:10:00',
#  '06:09:00',
#  '06:08:00',
#  '06:06:00',
#  '06:05:00',
#  '06:03:00',
#  '06:02:00',
#  '06:01:00',
#  '06:00:00',
#  '05:58:00',
#  '05:57:00',
#  '05:56:00',
#  '05:55:00',
#  '05:53:00',
#  '05:52:00',
#  '05:51:00',
#  '05:50:00',
#  '05:49:00',
#  '05:47:00',
#  '05:45:00',
#  '05:42:00',
#  '05:41:00',
#  '05:40:00',
#  '05:39:00',
#  '05:38:00',
#  '05:36:00',
#  '05:35:00',
#  '05:33:00',
#  '05:32:00',
#  '05:31:00',
#  '05:30:00',
#  '05:29:00',
#  '05:28:00',
#  '05:26:00',
#  '05:25:00',
#  '05:23:00',
#  '05:20:00',
#  '05:18:00',
#  '05:16:00',
#  '05:15:00',
#  '05:13:00',
#  '05:12:00',
#  '05:11:00',
#  '05:10:00',
#  '05:09:00',
#  '05:08:00',
#  '05:07:00',
#  '05:06:00',
#  '05:05:00',
#  '05:03:00',
#  '05:02:00',
#  '05:01:00',
#  '05:00:00',
#  '04:59:00',
#  '04:55:00',
#  '04:50:00',
#  '04:49:00',
#  '04:48:00',
#  '04:47:00',
#  '04:46:00',
#  '04:45:00',
#  '04:43:00',
#  '04:42:00',
#  '04:41:00',
#  '04:40:00',
#  '04:39:00',
#  '04:38:00',
#  '04:37:00',
#  '04:35:00',
#  '04:33:00',
#  '04:30:00',
#  '04:28:00',
#  '04:27:00',
#  '04:26:00',
#  '04:25:00',
#  '04:24:00',
#  '04:23:00',
#  '04:22:00',
#  '04:20:00',
#  '04:19:00',
#  '04:18:00',
#  '04:17:00',
#  '04:15:00',
#  '04:14:00',
#  '04:10:00',
#  '04:08:00',
#  '04:07:00',
#  '04:06:00',
#  '04:05:00',
#  '04:04:00',
#  '04:03:00',
#  '04:02:00',
#  '04:00:00',
#  '03:55:00',
#  '03:54:00',
#  '03:53:00',
#  '03:51:00',
#  '03:50:00',
#  '03:48:00',
#  '03:47:00',
#  '03:45:00',
#  '03:44:00',
#  '03:43:00',
#  '03:41:00',
#  '03:40:00',
#  '03:39:00',
#  '03:38:00',
#  '03:37:00',
#  '03:35:00',
#  '03:30:00',
#  '03:29:00',
#  '03:28:00',
#  '03:27:00',
#  '03:25:00',
#  '03:24:00',
#  '03:23:00',
#  '03:22:00',
#  '03:21:00',
#  '03:20:00',
#  '03:19:00',
#  '03:17:00',
#  '03:16:00',
#  '03:15:00',
#  '03:14:00',
#  '03:13:00',
#  '03:11:00',
#  '03:10:00',
#  '03:09:00',
#  '03:08:00',
#  '03:05:00',
#  '03:03:00',
#  '03:02:00',
#  '03:01:00',
#  '03:00:00',
#  '02:58:00',
#  '02:57:00',
#  '02:55:00',
#  '02:54:00',
#  '02:53:00',
#  '02:51:00',
#  '02:50:00',
#  '02:49:00',
#  '02:48:00',
#  '02:45:00',
#  '02:44:00',
#  '02:42:00',
#  '02:41:00',
#  '02:40:00',
#  '02:38:00',
#  '02:36:00',
#  '02:35:00',
#  '02:34:00',
#  '02:32:00',
#  '02:30:00',
#  '02:27:00',
#  '02:26:00',
#  '02:25:00',
#  '02:23:00',
#  '02:22:00',
#  '02:20:00',
#  '02:19:00',
#  '02:16:00',
#  '02:15:00',
#  '02:13:00',
#  '02:12:00',
#  '02:11:00',
#  '02:10:00',
#  '02:09:00',
#  '02:08:00',
#  '02:07:00',
#  '02:06:00',
#  '02:05:00',
#  '02:04:00',
#  '02:02:00',
#  '02:00:00',
#  '01:58:00',
#  '01:57:00',
#  '01:55:00',
#  '01:54:00',
#  '01:53:00',
#  '01:52:00',
#  '01:51:00',
#  '01:50:00',
#  '01:49:00',
#  '01:47:00',
#  '01:45:00',
#  '01:44:00',
#  '01:43:00',
#  '01:41:00',
#  '01:40:00',
#  '01:39:00',
#  '01:38:00',
#  '01:36:00',
#  '01:35:00',
#  '01:33:00',
#  '01:32:00',
#  '01:31:00',
#  '01:30:00',
#  '01:28:00',
#  '01:27:00',
#  '01:26:00',
#  '01:25:00',
#  '01:24:00',
#  '01:23:00',
#  '01:22:00',
#  '01:20:00',
#  '01:19:00',
#  '01:18:00',
#  '01:17:00',
#  '01:16:00',
#  '01:15:00',
#  '01:14:00',
#  '01:12:00',
#  '01:10:00',
#  '01:09:00',
#  '01:07:00',
#  '01:06:00',
#  '01:05:00',
#  '01:02:00',
#  '01:01:00',
#  '01:00:00',
#  '00:58:00',
#  '00:57:00',
#  '00:55:00',
#  '00:54:00',
#  '00:53:00',
#  '00:52:00',
#  '00:50:00',
#  '00:48:00',
#  '00:47:00',
#  '00:45:00',
#  '00:44:00',
#  '00:43:00',
#  '00:42:00',
#  '00:41:00',
#  '00:40:00',
#  '00:38:00',
#  '00:36:00',
#  '00:35:00',
#  '00:34:00',
#  '00:31:00',
#  '00:30:00',
#  '00:29:00',
#  '00:28:00',
#  '00:27:00',
#  '00:25:00',
#  '00:24:00',
#  '00:23:00',
#  '00:22:00',
#  '00:21:00',
#  '00:20:00',
#  '00:19:00',
#  '00:17:00',
#  '00:16:00',
#  '00:15:00',
#  '00:13:00',
#  '00:12:00',
#  '00:11:00',
#  '00:10:00',
#  '00:07:00',
#  '00:06:00',
#  '00:05:00',
#  '00:04:00',
#  ...]

# %%
# Replace de dados
dfsp_geral['hora_fato'].replace(['PELA MANHÃ          ',
                                 'PELA MANHÃ'], '09:00:00', inplace=True)

dfsp_geral['hora_fato'].replace(['NÃO INFORMADO','EM HORA INCERTA'],
                                '23:59:00', inplace=True)

dfsp_geral['hora_fato'].replace('A TARDE','15:00:00', inplace=True)

dfsp_geral['hora_fato'].replace('A NOITE','21:00:00', inplace=True)

dfsp_geral['hora_fato'].replace('DE MADRUGADA','03:00:00', inplace=True)

# %%
# Verificando correção
sorted(dfsp_geral['hora_fato'].astype(str).unique(), reverse=True)
# Out:
# ['23:59:00',
#  '23:58:00',
#  '23:56:00',
#  '23:55:00',
#  '23:54:00',
#  '23:53:00',
#  '23:52:00',
#  '23:50:00',
#  '23:49:00',
#  '23:48:00',
#  '23:47:00',
#  '23:46:00',
#  '23:45:00',
#  '23:44:00',
#  '23:43:00',
#  '23:42:00',
#  '23:41:00',
#  '23:40:00',
#  '23:39:00',
#  '23:38:00',
#  '23:37:00',
#  '23:36:00',
#  '23:35:00',
#  '23:34:00',
#  '23:33:00',
#  '23:32:00',
#  '23:31:00',
#  '23:30:00',
#  '23:29:00',
#  '23:27:00',
#  '23:26:00',
#  '23:25:00',
#  '23:24:00',
#  '23:23:00',
#  '23:22:00',
#  '23:21:00',
#  '23:20:00',
#  '23:19:00',
#  '23:18:00',
#  '23:17:00',
#  '23:15:00',
#  '23:14:00',
#  '23:12:00',
#  '23:11:00',
#  '23:10:00',
#  '23:09:00',
#  '23:08:00',
#  '23:07:00',
#  '23:06:00',
#  '23:05:00',
#  '23:03:00',
#  '23:00:00',
#  '22:59:00',
#  '22:58:00',
#  '22:57:00',
#  '22:55:00',
#  '22:54:00',
#  '22:53:00',
#  '22:52:00',
#  '22:51:00',
#  '22:50:00',
#  '22:49:00',
#  '22:48:00',
#  '22:47:00',
#  '22:46:00',
#  '22:45:00',
#  '22:43:00',
#  '22:42:00',
#  '22:41:00',
#  '22:40:00',
#  '22:39:00',
#  '22:37:00',
#  '22:36:00',
#  '22:35:00',
#  '22:33:00',
#  '22:32:00',
#  '22:31:00',
#  '22:30:00',
#  '22:29:00',
#  '22:28:00',
#  '22:27:00',
#  '22:25:00',
#  '22:22:00',
#  '22:21:00',
#  '22:20:00',
#  '22:19:00',
#  '22:18:00',
#  '22:17:00',
#  '22:16:00',
#  '22:15:00',
#  '22:14:00',
#  '22:12:00',
#  '22:11:00',
#  '22:10:00',
#  '22:09:00',
#  '22:07:00',
#  '22:06:00',
#  '22:05:00',
#  '22:04:00',
#  '22:03:00',
#  '22:02:00',
#  '22:00:00',
#  '21:59:00',
#  '21:58:00',
#  '21:57:00',
#  '21:56:00',
#  '21:55:00',
#  '21:54:00',
#  '21:53:00',
#  '21:52:00',
#  '21:51:00',
#  '21:50:00',
#  '21:49:00',
#  '21:48:00',
#  '21:47:00',
#  '21:46:00',
#  '21:45:00',
#  '21:44:00',
#  '21:43:00',
#  '21:42:00',
#  '21:41:00',
#  '21:40:00',
#  '21:39:00',
#  '21:38:00',
#  '21:37:00',
#  '21:36:00',
#  '21:35:00',
#  '21:34:00',
#  '21:33:00',
#  '21:32:00',
#  '21:30:00',
#  '21:29:00',
#  '21:28:00',
#  '21:27:00',
#  '21:25:00',
#  '21:24:00',
#  '21:23:00',
#  '21:22:00',
#  '21:21:00',
#  '21:20:00',
#  '21:19:00',
#  '21:17:00',
#  '21:16:00',
#  '21:15:00',
#  '21:14:00',
#  '21:11:00',
#  '21:10:00',
#  '21:09:00',
#  '21:08:00',
#  '21:06:00',
#  '21:05:00',
#  '21:04:00',
#  '21:03:00',
#  '21:02:00',
#  '21:01:00',
#  '21:00:00',
#  '20:59:00',
#  '20:58:00',
#  '20:57:00',
#  '20:55:00',
#  '20:53:00',
#  '20:52:00',
#  '20:51:00',
#  '20:50:00',
#  '20:49:00',
#  '20:48:00',
#  '20:47:00',
#  '20:45:00',
#  '20:43:00',
#  '20:41:00',
#  '20:40:00',
#  '20:39:00',
#  '20:38:00',
#  '20:36:00',
#  '20:35:00',
#  '20:34:00',
#  '20:33:00',
#  '20:32:00',
#  '20:31:00',
#  '20:30:00',
#  '20:28:00',
#  '20:27:00',
#  '20:26:00',
#  '20:25:00',
#  '20:24:00',
#  '20:23:00',
#  '20:20:00',
#  '20:19:00',
#  '20:18:00',
#  '20:17:00',
#  '20:16:00',
#  '20:15:00',
#  '20:14:00',
#  '20:13:00',
#  '20:12:00',
#  '20:11:00',
#  '20:10:00',
#  '20:09:00',
#  '20:07:00',
#  '20:06:00',
#  '20:05:00',
#  '20:04:00',
#  '20:03:00',
#  '20:02:00',
#  '20:01:00',
#  '20:00:00',
#  '19:59:00',
#  '19:58:00',
#  '19:57:00',
#  '19:56:00',
#  '19:55:00',
#  '19:54:00',
#  '19:53:00',
#  '19:52:00',
#  '19:51:00',
#  '19:50:00',
#  '19:48:00',
#  '19:47:00',
#  '19:46:00',
#  '19:45:00',
#  '19:44:00',
#  '19:43:00',
#  '19:42:00',
#  '19:41:00',
#  '19:40:00',
#  '19:38:00',
#  '19:37:00',
#  '19:36:00',
#  '19:35:00',
#  '19:34:00',
#  '19:31:00',
#  '19:30:00',
#  '19:29:00',
#  '19:28:00',
#  '19:27:00',
#  '19:26:00',
#  '19:25:00',
#  '19:24:00',
#  '19:23:00',
#  '19:22:00',
#  '19:21:00',
#  '19:20:00',
#  '19:19:00',
#  '19:18:00',
#  '19:15:00',
#  '19:14:00',
#  '19:12:00',
#  '19:10:00',
#  '19:09:00',
#  '19:08:00',
#  '19:07:00',
#  '19:06:00',
#  '19:05:00',
#  '19:03:00',
#  '19:02:00',
#  '19:00:00',
#  '18:59:00',
#  '18:58:00',
#  '18:55:00',
#  '18:54:00',
#  '18:53:00',
#  '18:52:00',
#  '18:50:00',
#  '18:49:00',
#  '18:48:00',
#  '18:46:00',
#  '18:45:00',
#  '18:44:00',
#  '18:43:00',
#  '18:42:00',
#  '18:40:00',
#  '18:37:00',
#  '18:36:00',
#  '18:35:00',
#  '18:34:00',
#  '18:33:00',
#  '18:31:00',
#  '18:30:00',
#  '18:29:00',
#  '18:27:00',
#  '18:26:00',
#  '18:25:00',
#  '18:21:00',
#  '18:20:00',
#  '18:19:00',
#  '18:15:00',
#  '18:14:00',
#  '18:13:00',
#  '18:11:00',
#  '18:10:00',
#  '18:08:00',
#  '18:07:00',
#  '18:05:00',
#  '18:02:00',
#  '18:00:00',
#  '17:59:00',
#  '17:58:00',
#  '17:56:00',
#  '17:55:00',
#  '17:54:00',
#  '17:53:00',
#  '17:52:00',
#  '17:50:00',
#  '17:49:00',
#  '17:48:00',
#  '17:45:00',
#  '17:42:00',
#  '17:41:00',
#  '17:40:00',
#  '17:38:00',
#  '17:37:00',
#  '17:36:00',
#  '17:35:00',
#  '17:33:00',
#  '17:31:00',
#  '17:30:00',
#  '17:27:00',
#  '17:26:00',
#  '17:25:00',
#  '17:22:00',
#  '17:21:00',
#  '17:20:00',
#  '17:16:00',
#  '17:15:00',
#  '17:14:00',
#  '17:10:00',
#  '17:08:00',
#  '17:04:00',
#  '17:03:00',
#  '17:00:00',
#  '16:56:00',
#  '16:55:00',
#  '16:53:00',
#  '16:52:00',
#  '16:51:00',
#  '16:50:00',
#  '16:48:00',
#  '16:47:00',
#  '16:45:00',
#  '16:43:00',
#  '16:42:00',
#  '16:40:00',
#  '16:39:00',
#  '16:38:00',
#  '16:36:00',
#  '16:35:00',
#  '16:33:00',
#  '16:32:00',
#  '16:30:00',
#  '16:26:00',
#  '16:25:00',
#  '16:24:00',
#  '16:21:00',
#  '16:20:00',
#  '16:19:00',
#  '16:17:00',
#  '16:15:00',
#  '16:14:00',
#  '16:12:00',
#  '16:10:00',
#  '16:07:00',
#  '16:06:00',
#  '16:05:00',
#  '16:04:00',
#  '16:03:00',
#  '16:02:00',
#  '16:00:00',
#  '15:58:00',
#  '15:56:00',
#  '15:55:00',
#  '15:51:00',
#  '15:50:00',
#  '15:48:00',
#  '15:45:00',
#  '15:43:00',
#  '15:42:00',
#  '15:41:00',
#  '15:40:00',
#  '15:39:00',
#  '15:36:00',
#  '15:35:00',
#  '15:33:00',
#  '15:32:00',
#  '15:30:00',
#  '15:27:00',
#  '15:24:00',
#  '15:21:00',
#  '15:20:00',
#  '15:19:00',
#  '15:18:00',
#  '15:17:00',
#  '15:16:00',
#  '15:15:00',
#  '15:14:00',
#  '15:12:00',
#  '15:11:00',
#  '15:10:00',
#  '15:08:00',
#  '15:05:00',
#  '15:03:00',
#  '15:00:00',
#  '14:59:00',
#  '14:55:00',
#  '14:53:00',
#  '14:52:00',
#  '14:51:00',
#  '14:50:00',
#  '14:49:00',
#  '14:46:00',
#  '14:45:00',
#  '14:43:00',
#  '14:42:00',
#  '14:40:00',
#  '14:39:00',
#  '14:38:00',
#  '14:37:00',
#  '14:35:00',
#  '14:34:00',
#  '14:32:00',
#  '14:31:00',
#  '14:30:00',
#  '14:28:00',
#  '14:26:00',
#  '14:25:00',
#  '14:24:00',
#  '14:22:00',
#  '14:20:00',
#  '14:18:00',
#  '14:17:00',
#  '14:16:00',
#  '14:15:00',
#  '14:12:00',
#  '14:11:00',
#  '14:10:00',
#  '14:09:00',
#  '14:08:00',
#  '14:07:00',
#  '14:05:00',
#  '14:02:00',
#  '14:01:00',
#  '14:00:00',
#  '13:59:00',
#  '13:58:00',
#  '13:55:00',
#  '13:50:00',
#  '13:49:00',
#  '13:48:00',
#  '13:45:00',
#  '13:41:00',
#  '13:40:00',
#  '13:39:00',
#  '13:38:00',
#  '13:35:00',
#  '13:33:00',
#  '13:32:00',
#  '13:31:00',
#  '13:30:00',
#  '13:29:00',
#  '13:28:00',
#  '13:25:00',
#  '13:22:00',
#  '13:20:00',
#  '13:19:00',
#  '13:18:00',
#  '13:17:00',
#  '13:15:00',
#  '13:14:00',
#  '13:12:00',
#  '13:10:00',
#  '13:09:00',
#  '13:07:00',
#  '13:05:00',
#  '13:03:00',
#  '13:02:00',
#  '13:00:00',
#  '12:57:00',
#  '12:55:00',
#  '12:54:00',
#  '12:53:00',
#  '12:52:00',
#  '12:51:00',
#  '12:50:00',
#  '12:48:00',
#  '12:46:00',
#  '12:45:00',
#  '12:40:00',
#  '12:37:00',
#  '12:36:00',
#  '12:35:00',
#  '12:34:00',
#  '12:30:00',
#  '12:28:00',
#  '12:27:00',
#  '12:25:00',
#  '12:23:00',
#  '12:22:00',
#  '12:20:00',
#  '12:17:00',
#  '12:15:00',
#  '12:12:00',
#  '12:11:00',
#  '12:10:00',
#  '12:09:00',
#  '12:08:00',
#  '12:07:00',
#  '12:05:00',
#  '12:03:00',
#  '12:00:00',
#  '11:55:00',
#  '11:54:00',
#  '11:52:00',
#  '11:50:00',
#  '11:49:00',
#  '11:48:00',
#  '11:46:00',
#  '11:45:00',
#  '11:44:00',
#  '11:43:00',
#  '11:42:00',
#  '11:41:00',
#  '11:40:00',
#  '11:39:00',
#  '11:38:00',
#  '11:37:00',
#  '11:36:00',
#  '11:35:00',
#  '11:34:00',
#  '11:31:00',
#  '11:30:00',
#  '11:29:00',
#  '11:28:00',
#  '11:25:00',
#  '11:24:00',
#  '11:23:00',
#  '11:22:00',
#  '11:21:00',
#  '11:20:00',
#  '11:16:00',
#  '11:15:00',
#  '11:14:00',
#  '11:13:00',
#  '11:12:00',
#  '11:10:00',
#  '11:08:00',
#  '11:04:00',
#  '11:01:00',
#  '11:00:00',
#  '10:58:00',
#  '10:55:00',
#  '10:53:00',
#  '10:52:00',
#  '10:51:00',
#  '10:50:00',
#  '10:48:00',
#  '10:46:00',
#  '10:45:00',
#  '10:44:00',
#  '10:42:00',
#  '10:41:00',
#  '10:40:00',
#  '10:39:00',
#  '10:38:00',
#  '10:36:00',
#  '10:35:00',
#  '10:34:00',
#  '10:33:00',
#  '10:30:00',
#  '10:29:00',
#  '10:24:00',
#  '10:22:00',
#  '10:20:00',
#  '10:18:00',
#  '10:16:00',
#  '10:13:00',
#  '10:12:00',
#  '10:11:00',
#  '10:10:00',
#  '10:07:00',
#  '10:06:00',
#  '10:05:00',
#  '10:04:00',
#  '10:02:00',
#  '10:01:00',
#  '10:00:00',
#  '09:58:00',
#  '09:55:00',
#  '09:52:00',
#  '09:50:00',
#  '09:48:00',
#  '09:45:00',
#  '09:42:00',
#  '09:40:00',
#  '09:38:00',
#  '09:37:00',
#  '09:35:00',
#  '09:34:00',
#  '09:32:00',
#  '09:31:00',
#  '09:30:00',
#  '09:28:00',
#  '09:27:00',
#  '09:26:00',
#  '09:25:00',
#  '09:23:00',
#  '09:20:00',
#  '09:18:00',
#  '09:15:00',
#  '09:10:00',
#  '09:09:00',
#  '09:08:00',
#  '09:07:00',
#  '09:06:00',
#  '09:05:00',
#  '09:03:00',
#  '09:02:00',
#  '09:00:00',
#  '08:58:00',
#  '08:57:00',
#  '08:55:00',
#  '08:50:00',
#  '08:49:00',
#  '08:48:00',
#  '08:45:00',
#  '08:44:00',
#  '08:42:00',
#  '08:41:00',
#  '08:40:00',
#  '08:39:00',
#  '08:36:00',
#  '08:35:00',
#  '08:34:00',
#  '08:33:00',
#  '08:30:00',
#  '08:28:00',
#  '08:26:00',
#  '08:25:00',
#  '08:24:00',
#  '08:23:00',
#  '08:22:00',
#  '08:20:00',
#  '08:19:00',
#  '08:18:00',
#  '08:17:00',
#  '08:16:00',
#  '08:15:00',
#  '08:13:00',
#  '08:10:00',
#  '08:08:00',
#  '08:07:00',
#  '08:06:00',
#  '08:05:00',
#  '08:03:00',
#  '08:02:00',
#  '08:00:00',
#  '07:55:00',
#  '07:54:00',
#  '07:52:00',
#  '07:51:00',
#  '07:50:00',
#  '07:46:00',
#  '07:45:00',
#  '07:44:00',
#  '07:43:00',
#  '07:42:00',
#  '07:41:00',
#  '07:40:00',
#  '07:39:00',
#  '07:37:00',
#  '07:36:00',
#  '07:35:00',
#  '07:34:00',
#  '07:32:00',
#  '07:31:00',
#  '07:30:00',
#  '07:29:00',
#  '07:28:00',
#  '07:27:00',
#  '07:26:00',
#  '07:25:00',
#  '07:23:00',
#  '07:22:00',
#  '07:20:00',
#  '07:19:00',
#  '07:16:00',
#  '07:15:00',
#  '07:13:00',
#  '07:10:00',
#  '07:09:00',
#  '07:06:00',
#  '07:05:00',
#  '07:04:00',
#  '07:02:00',
#  '07:01:00',
#  '07:00:00',
#  '06:58:00',
#  '06:57:00',
#  '06:55:00',
#  '06:53:00',
#  '06:52:00',
#  '06:51:00',
#  '06:50:00',
#  '06:49:00',
#  '06:46:00',
#  '06:45:00',
#  '06:44:00',
#  '06:43:00',
#  '06:42:00',
#  '06:41:00',
#  '06:40:00',
#  '06:39:00',
#  '06:38:00',
#  '06:37:00',
#  '06:36:00',
#  '06:35:00',
#  '06:34:00',
#  '06:33:00',
#  '06:32:00',
#  '06:30:00',
#  '06:29:00',
#  '06:28:00',
#  '06:27:00',
#  '06:26:00',
#  '06:25:00',
#  '06:24:00',
#  '06:23:00',
#  '06:20:00',
#  '06:18:00',
#  '06:17:00',
#  '06:16:00',
#  '06:15:00',
#  '06:13:00',
#  '06:12:00',
#  '06:10:00',
#  '06:09:00',
#  '06:08:00',
#  '06:06:00',
#  '06:05:00',
#  '06:03:00',
#  '06:02:00',
#  '06:01:00',
#  '06:00:00',
#  '05:58:00',
#  '05:57:00',
#  '05:56:00',
#  '05:55:00',
#  '05:53:00',
#  '05:52:00',
#  '05:51:00',
#  '05:50:00',
#  '05:49:00',
#  '05:47:00',
#  '05:45:00',
#  '05:42:00',
#  '05:41:00',
#  '05:40:00',
#  '05:39:00',
#  '05:38:00',
#  '05:36:00',
#  '05:35:00',
#  '05:33:00',
#  '05:32:00',
#  '05:31:00',
#  '05:30:00',
#  '05:29:00',
#  '05:28:00',
#  '05:26:00',
#  '05:25:00',
#  '05:23:00',
#  '05:20:00',
#  '05:18:00',
#  '05:16:00',
#  '05:15:00',
#  '05:13:00',
#  '05:12:00',
#  '05:11:00',
#  '05:10:00',
#  '05:09:00',
#  '05:08:00',
#  '05:07:00',
#  '05:06:00',
#  '05:05:00',
#  '05:03:00',
#  '05:02:00',
#  '05:01:00',
#  '05:00:00',
#  '04:59:00',
#  '04:55:00',
#  '04:50:00',
#  '04:49:00',
#  '04:48:00',
#  '04:47:00',
#  '04:46:00',
#  '04:45:00',
#  '04:43:00',
#  '04:42:00',
#  '04:41:00',
#  '04:40:00',
#  '04:39:00',
#  '04:38:00',
#  '04:37:00',
#  '04:35:00',
#  '04:33:00',
#  '04:30:00',
#  '04:28:00',
#  '04:27:00',
#  '04:26:00',
#  '04:25:00',
#  '04:24:00',
#  '04:23:00',
#  '04:22:00',
#  '04:20:00',
#  '04:19:00',
#  '04:18:00',
#  '04:17:00',
#  '04:15:00',
#  '04:14:00',
#  '04:10:00',
#  '04:08:00',
#  '04:07:00',
#  '04:06:00',
#  '04:05:00',
#  '04:04:00',
#  '04:03:00',
#  '04:02:00',
#  '04:00:00',
#  '03:55:00',
#  '03:54:00',
#  '03:53:00',
#  '03:51:00',
#  '03:50:00',
#  '03:48:00',
#  '03:47:00',
#  '03:45:00',
#  '03:44:00',
#  '03:43:00',
#  '03:41:00',
#  '03:40:00',
#  '03:39:00',
#  '03:38:00',
#  '03:37:00',
#  '03:35:00',
#  '03:30:00',
#  '03:29:00',
#  '03:28:00',
#  '03:27:00',
#  '03:25:00',
#  '03:24:00',
#  '03:23:00',
#  '03:22:00',
#  '03:21:00',
#  '03:20:00',
#  '03:19:00',
#  '03:17:00',
#  '03:16:00',
#  '03:15:00',
#  '03:14:00',
#  '03:13:00',
#  '03:11:00',
#  '03:10:00',
#  '03:09:00',
#  '03:08:00',
#  '03:05:00',
#  '03:03:00',
#  '03:02:00',
#  '03:01:00',
#  '03:00:00',
#  '02:58:00',
#  '02:57:00',
#  '02:55:00',
#  '02:54:00',
#  '02:53:00',
#  '02:51:00',
#  '02:50:00',
#  '02:49:00',
#  '02:48:00',
#  '02:45:00',
#  '02:44:00',
#  '02:42:00',
#  '02:41:00',
#  '02:40:00',
#  '02:38:00',
#  '02:36:00',
#  '02:35:00',
#  '02:34:00',
#  '02:32:00',
#  '02:30:00',
#  '02:27:00',
#  '02:26:00',
#  '02:25:00',
#  '02:23:00',
#  '02:22:00',
#  '02:20:00',
#  '02:19:00',
#  '02:16:00',
#  '02:15:00',
#  '02:13:00',
#  '02:12:00',
#  '02:11:00',
#  '02:10:00',
#  '02:09:00',
#  '02:08:00',
#  '02:07:00',
#  '02:06:00',
#  '02:05:00',
#  '02:04:00',
#  '02:02:00',
#  '02:00:00',
#  '01:58:00',
#  '01:57:00',
#  '01:55:00',
#  '01:54:00',
#  '01:53:00',
#  '01:52:00',
#  '01:51:00',
#  '01:50:00',
#  '01:49:00',
#  '01:47:00',
#  '01:45:00',
#  '01:44:00',
#  '01:43:00',
#  '01:41:00',
#  '01:40:00',
#  '01:39:00',
#  '01:38:00',
#  '01:36:00',
#  '01:35:00',
#  '01:33:00',
#  '01:32:00',
#  '01:31:00',
#  '01:30:00',
#  '01:28:00',
#  '01:27:00',
#  '01:26:00',
#  '01:25:00',
#  '01:24:00',
#  '01:23:00',
#  '01:22:00',
#  '01:20:00',
#  '01:19:00',
#  '01:18:00',
#  '01:17:00',
#  '01:16:00',
#  '01:15:00',
#  '01:14:00',
#  '01:12:00',
#  '01:10:00',
#  '01:09:00',
#  '01:07:00',
#  '01:06:00',
#  '01:05:00',
#  '01:02:00',
#  '01:01:00',
#  '01:00:00',
#  '00:58:00',
#  '00:57:00',
#  '00:55:00',
#  '00:54:00',
#  '00:53:00',
#  '00:52:00',
#  '00:50:00',
#  '00:48:00',
#  '00:47:00',
#  '00:45:00',
#  '00:44:00',
#  '00:43:00',
#  '00:42:00',
#  '00:41:00',
#  '00:40:00',
#  '00:38:00',
#  '00:36:00',
#  '00:35:00',
#  '00:34:00',
#  '00:31:00',
#  '00:30:00',
#  '00:29:00',
#  '00:28:00',
#  '00:27:00',
#  '00:25:00',
#  '00:24:00',
#  '00:23:00',
#  '00:22:00',
#  '00:21:00',
#  '00:20:00',
#  '00:19:00',
#  '00:17:00',
#  '00:16:00',
#  '00:15:00',
#  '00:13:00',
#  '00:12:00',
#  '00:11:00',
#  '00:10:00',
#  '00:07:00',
#  '00:06:00',
#  '00:05:00',
#  '00:04:00',
#  '00:03:00',
#  '00:02:00',
#  '00:01:00',
#  '00:00:00']

# %% [markdown]
# ###▶️ **Juntando coluna dt_fato com hora_fato e criando coluna periodo**

# %%
# Plot das colunas que iremos juntar
dfsp_geral[['dt_fato','hora_fato']].tail(5)
# Out:
#                   dt_fato hora_fato
# 4268  2021-12-22 00:00:00  01:20:00
# 4269  2021-12-27 00:00:00  21:15:00
# 4270  2021-12-29 00:00:00  12:45:00
# 4271  2021-12-29 00:00:00  23:45:00
# 4272  2021-12-29 00:00:00  22:52:00

# %%
# Transformando colunas no formato string
dfsp_geral['dt_fato'] = dfsp_geral['dt_fato'].astype(str)
dfsp_geral['hora_fato'] = dfsp_geral['hora_fato'].astype(str)

# Juntando colunas
dfsp_geral['datahora_fato'] = dfsp_geral['dt_fato'].str.slice(0,10) + ' ' + dfsp_geral['hora_fato']

# %%
dfsp_geral['datahora_fato']
# Out:
# 0       2018-01-06 20:06:00
# 1       2018-01-06 19:00:00
# 2       2018-01-18 18:00:00
# 3       2018-01-02 18:48:00
# 4       2018-01-14 15:00:00
#                ...
# 4268    2021-12-22 01:20:00
# 4269    2021-12-27 21:15:00
# 4270    2021-12-29 12:45:00
# 4271    2021-12-29 23:45:00
# 4272    2021-12-29 22:52:00
# Name: datahora_fato, Length: 4161, dtype: object

# %%
# Tornando colunna datetime
dfsp_geral['datahora_fato']= pd.to_datetime(dfsp_geral['datahora_fato'])

# %%
dfsp_geral['datahora_fato']
# Out:
# 0      2018-01-06 20:06:00
# 1      2018-01-06 19:00:00
# 2      2018-01-18 18:00:00
# 3      2018-01-02 18:48:00
# 4      2018-01-14 15:00:00
#                ...
# 4268   2021-12-22 01:20:00
# 4269   2021-12-27 21:15:00
# 4270   2021-12-29 12:45:00
# 4271   2021-12-29 23:45:00
# 4272   2021-12-29 22:52:00
# Name: datahora_fato, Length: 4161, dtype: datetime64[ns]

# %% [markdown]
#  - Manhã (06:00 as 11:59)
#  - Tarde (12:00 as 17:59)
#  - Noite (18:00 as 23:58)
#  - Madrugada (00:00 as 05:59)
#  - Não Informado (23:59:00)

# %%
# Criando função para juntar horarios
def define_periodo(linha):
  horario = linha['hora_fato']
  if '06:00:00' <= horario <= '11:59:00':
    return 'Manhã'
  elif '12:00:00' <= horario <= '17:59:00':
    return 'Tarde'
  elif '18:00:00' <= horario <= '23:58:00':
    return 'Noite'
  elif '00:00:00' <= horario <= '05:59:00':
    return 'Madrugada'
  else:
    return 'Não Informado'

# Aplicando função
dfsp_geral['periodo_ocorrencia'] = dfsp_geral.apply(define_periodo, axis=1)

# %%
dfsp_geral[['hora_fato','periodo_ocorrencia']]
# Out:
#      hora_fato periodo_ocorrencia
# 0     20:06:00              Noite
# 1     19:00:00              Noite
# 2     18:00:00              Noite
# 3     18:48:00              Noite
# 4     15:00:00              Tarde
# ...        ...                ...
# 4268  01:20:00          Madrugada
# 4269  21:15:00              Noite
# 4270  12:45:00              Tarde
# 4271  23:45:00              Noite
# 4272  22:52:00              Noite
#
# [4161 rows x 2 columns]

# %%
dfsp_geral.head(1)
# Out:
#       cidade     dp_circunscricao  n_vitimas              dt_fato hora_fato  \
# 0  São Paulo  002 DP - Bom Retiro        1.0  2018-01-06 00:00:00  20:06:00
#
#   tipo_local_fato                         logradouro n_logradouro   latitude  \
# 0     Via Pública  AVENIDA PRESIDENTE CASTELO BRANCO          NaN -23.523712
#
#    longitude tipo_pessoa sexo_pessoa idade_pessoa dt_nasc_pessoa  \
# 0 -46.606388      Vítima   Masculino          NaN            NaT
#
#         cor_pele profissao        tipo_crime corporacao_policial  \
# 0  Não informada       NaN  HOMICÍDIO DOLOSO                 NaN
#
#   situacao_policial       datahora_fato periodo_ocorrencia
# 0               NaN 2018-01-06 20:06:00              Noite

# %%
# Drop de colunas que não serão mais úteis
dfsp_geral.drop(columns=['dt_fato','hora_fato'], inplace=True)

# %%
# Verificando alterações
dfsp_geral.head(1)
# Out:
#       cidade     dp_circunscricao  n_vitimas tipo_local_fato  \
# 0  São Paulo  002 DP - Bom Retiro        1.0     Via Pública
#
#                           logradouro n_logradouro   latitude  longitude  \
# 0  AVENIDA PRESIDENTE CASTELO BRANCO          NaN -23.523712 -46.606388
#
#   tipo_pessoa sexo_pessoa idade_pessoa dt_nasc_pessoa       cor_pele  \
# 0      Vítima   Masculino          NaN            NaT  Não informada
#
#   profissao        tipo_crime corporacao_policial situacao_policial  \
# 0       NaN  HOMICÍDIO DOLOSO                 NaN               NaN
#
#         datahora_fato periodo_ocorrencia
# 0 2018-01-06 20:06:00              Noite

# %% [markdown]
# ###▶️ **Juntando colunas latitude e longitude**

# %%
# Juntando colunas
dfsp_geral['latitude_longitude'] = dfsp_geral['latitude'].astype(str) + ',' + dfsp_geral['longitude'].astype(str)

# %%
# Organizando nulos
dfsp_geral['latitude_longitude'].replace('nan,nan', np.nan, inplace= True)
dfsp_geral['latitude_longitude'].replace('0.0,0.0', '-23.7761804,-46.6987938', inplace= True)
dfsp_geral['latitude_longitude'].replace('23.6342176567598,-46.74277316177', '-23.6342176567598,-46.74277316177', inplace= True)
dfsp_geral['latitude_longitude'].replace('-23.6176095929999,nan', '-23.6174356,-46.728489', inplace= True)
dfsp_geral['latitude_longitude'].replace('-23.5656,46.61166', '-23.5656,-46.61166', inplace= True)

# %%
ft = dfsp_geral['latitude_longitude'] == '23.6342176567598,-46.74277316177'
dfsp_geral.loc[ft]
# Out:
# Empty DataFrame
# Columns: [cidade, dp_circunscricao, n_vitimas, tipo_local_fato, logradouro, n_logradouro, latitude, longitude, tipo_pessoa, sexo_pessoa, idade_pessoa, dt_nasc_pessoa, cor_pele, profissao, tipo_crime, corporacao_policial, situacao_policial, datahora_fato, periodo_ocorrencia, latitude_longitude]
# Index: []

# %%
# Dropando colunas extras
dfsp_geral.drop(columns=['latitude', 'longitude'], inplace=True)

# %%
# Verificando resultado
dfsp_geral.head(3)
# Out:
#       cidade     dp_circunscricao  n_vitimas      tipo_local_fato  \
# 0  São Paulo  002 DP - Bom Retiro        1.0          Via Pública
# 1  São Paulo  002 DP - Bom Retiro        1.0           Residência
# 2  São Paulo        008 DP - Brás        1.0  Comércio e serviços
#
#                                      logradouro n_logradouro tipo_pessoa  \
# 0             AVENIDA PRESIDENTE CASTELO BRANCO          NaN      Vítima
# 1  DA VEDAÇÃO DA DIVULGAÇÃO DOS DADOS RELATIVOS          NaN      Vítima
# 2                                  RUA DA MOOCA          NaN      Vítima
#
#   sexo_pessoa idade_pessoa       dt_nasc_pessoa       cor_pele  \
# 0   Masculino          NaN                  NaT  Não informada
# 1   Masculino         44.0  1973-06-06 00:00:00         Branca
# 2    Feminino         59.0  1958-08-02 00:00:00          Parda
#
#          profissao        tipo_crime corporacao_policial situacao_policial  \
# 0              NaN  HOMICÍDIO DOLOSO                 NaN               NaN
# 1  CABELEIREIRO(A)  HOMICÍDIO DOLOSO                 NaN               NaN
# 2      COMERCIANTE  HOMICÍDIO DOLOSO                 NaN               NaN
#
#         datahora_fato periodo_ocorrencia                  latitude_longitude
# 0 2018-01-06 20:06:00              Noite         -23.523712052,-46.606388286
# 1 2018-01-06 19:00:00              Noite                                 NaN
# 2 2018-01-18 18:00:00              Noite  -23.5538998601755,-46.617413203967

# %% [markdown]
# ### **▶️ Criando coluna com range de idade**

# %%
dfsp_geral['idade_pessoa'].astype(float)
# Out:
# 0        NaN
# 1       44.0
# 2       59.0
# 3        0.0
# 4        NaN
#         ...
# 4268    28.0
# 4269    32.0
# 4270     NaN
# 4271     NaN
# 4272    27.0
# Name: idade_pessoa, Length: 4161, dtype: float64

# %%
# Criando função para juntar as idades
def define_faixa_etaria(linha):
  idade = linha['idade_pessoa']
  if idade < 18:
    return '<18'
  elif 18 <= idade <= 24:
    return '18-24'
  elif 25 <= idade <= 44:
    return '25-44'
  elif 45 <= idade <= 64:
    return '45-64'
  elif idade >= 65:
    return '65+'
  else:
    return 'Desconhecido'

# Aplicando função
dfsp_geral['faixa_etaria_pessoa'] = dfsp_geral.apply(define_faixa_etaria, axis=1)

# %%
# Verificando alteração
dfsp_geral[['idade_pessoa','faixa_etaria_pessoa']]
# Out:
#      idade_pessoa faixa_etaria_pessoa
# 0             NaN        Desconhecido
# 1            44.0               25-44
# 2            59.0               45-64
# 3             0.0                 <18
# 4             NaN        Desconhecido
# ...           ...                 ...
# 4268           28               25-44
# 4269           32               25-44
# 4270          NaN        Desconhecido
# 4271          NaN        Desconhecido
# 4272           27               25-44
#
# [4161 rows x 2 columns]

# %% [markdown]
# ### ▶️ **Reordenando Colunas do Data Frame**

# %%
df = dfsp_geral.copy()

# Verificando ordem das colunas
df.columns
# Out:
# Index(['cidade', 'dp_circunscricao', 'n_vitimas', 'tipo_local_fato',
#        'logradouro', 'n_logradouro', 'tipo_pessoa', 'sexo_pessoa',
#        'idade_pessoa', 'dt_nasc_pessoa', 'cor_pele', 'profissao', 'tipo_crime',
#        'corporacao_policial', 'situacao_policial', 'datahora_fato',
#        'periodo_ocorrencia', 'latitude_longitude', 'faixa_etaria_pessoa'],
#       dtype='object')

# %%
# Verificando a qnt de colunas
df.shape
# Out:
# (4161, 19)

# %%
# Organizando Data Frame
df = df[['tipo_crime','n_vitimas','datahora_fato','periodo_ocorrencia',
         'tipo_pessoa', 'sexo_pessoa','dt_nasc_pessoa','idade_pessoa', 'faixa_etaria_pessoa', 'cor_pele', 'profissao',
         'cidade','dp_circunscricao','tipo_local_fato','logradouro','n_logradouro','latitude_longitude',
         'corporacao_policial','situacao_policial']]

# %%
# Verificando se não esqueceu nenhuma coluna
df.shape
# Out:
# (4161, 19)

# %%
df.head()
# Out:
#          tipo_crime  n_vitimas       datahora_fato periodo_ocorrencia  \
# 0  HOMICÍDIO DOLOSO        1.0 2018-01-06 20:06:00              Noite
# 1  HOMICÍDIO DOLOSO        1.0 2018-01-06 19:00:00              Noite
# 2  HOMICÍDIO DOLOSO        1.0 2018-01-18 18:00:00              Noite
# 3  HOMICÍDIO DOLOSO        1.0 2018-01-02 18:48:00              Noite
# 4  HOMICÍDIO DOLOSO        1.0 2018-01-14 15:00:00              Tarde
#
#   tipo_pessoa sexo_pessoa       dt_nasc_pessoa idade_pessoa  \
# 0      Vítima   Masculino                  NaT          NaN
# 1      Vítima   Masculino  1973-06-06 00:00:00         44.0
# 2      Vítima    Feminino  1958-08-02 00:00:00         59.0
# 3      Vítima    Feminino  2017-09-16 00:00:00          0.0
# 4      Vítima    Feminino                  NaT          NaN
#
#   faixa_etaria_pessoa       cor_pele        profissao     cidade  \
# 0        Desconhecido  Não informada              NaN  São Paulo
# 1               25-44         Branca  CABELEIREIRO(A)  São Paulo
# 2               45-64          Parda      COMERCIANTE  São Paulo
# 3                 <18         Branca              NaN  São Paulo
# 4        Desconhecido  Não informada              NaN  São Paulo
#
#       dp_circunscricao      tipo_local_fato  \
# 0  002 DP - Bom Retiro          Via Pública
# 1  002 DP - Bom Retiro           Residência
# 2        008 DP - Brás  Comércio e serviços
# 3     078 DP - Jardins           Residência
# 4    017 DP - Ipiranga          Via Pública
#
#                                      logradouro n_logradouro  \
# 0             AVENIDA PRESIDENTE CASTELO BRANCO          NaN
# 1  DA VEDAÇÃO DA DIVULGAÇÃO DOS DADOS RELATIVOS          NaN
# 2                                  RUA DA MOOCA          NaN
# 3  DA VEDAÇÃO DA DIVULGAÇÃO DOS DADOS RELATIVOS          NaN
# 4                       RUA DOM MARCOS TEIXEIRA          NaN
#
#                     latitude_longitude corporacao_policial situacao_policial
# 0          -23.523712052,-46.606388286                 NaN               NaN
# 1                                  NaN                 NaN               NaN
# 2   -23.5538998601755,-46.617413203967                 NaN               NaN
# 3                                  NaN                 NaN               NaN
# 4  -23.5858762097894,-46.5981945475789                 NaN               NaN

# %% [markdown]
# ##💿 **7 - Upload de arquivo final**

# %%
# Gerando arquivo do formato csv
df.to_csv('sp_tratado.csv', index = False)

# %% [markdown]
# ###⬆️ **Envio ao MongoDB**

# %%
# Conector do mongo atlas
uri = "mongodb+srv://giovana-soulcode.quvpom8.mongodb.net/?authSource=%24external&authMechanism=MONGODB-X509&retryWrites=true&w=majority"

# Altenticando o Mongo
client = MongoClient(uri, 
                     tls=True,
                     tlsCertificateKeyFile='/content/X509-cert-7346878477947766211.pem')

# %%
# escolha/crie o database e colecao
db = client['projeto_final']
colecao = db['sp_tratado']

# verificar conexão / Qtd. documentos da coleção
colecao.count_documents({})
# Out:
# 0

# %%
# Transformando Nulos em 0 (Mongo não aceita NaT)
df['dt_nasc_pessoa'].replace([np.nan, pd.NA],0, inplace=True)
df['datahora_fato'].replace([np.nan, pd.NA],0, inplace=True)

# %%
# Convertendo para formato dicionário
df_dict = df.to_dict("records")


#Enviar o df para colecao selecionada no mongo
colecao.insert_many(df_dict)

# %%
# Verificando a quantidade de documentos da coleção
colecao.count_documents({})
# Out:
# 4161

# %% [markdown]
# ###⬆️ **Envio ao Google Cloud Storage**

# %%
# função para fazer upload de arquivo no bucket
def upload_blob(bucket, arquivo, destino):
    client = storage.Client()
    bucket = client.bucket(bucket)
    blob = bucket.blob(destino)

    blob.upload_from_filename(arquivo)

    print(
        f"Arquivo {arquivo} enviado a {destino}."
    )

# %%
# Upload do arquivo 
bucket = 'projeto-final-agsw'
arquivo = '/content/sp_tratado.csv'
destino = 'tratados/sp_tratado.csv'
upload_blob(bucket, arquivo, destino)
# Out:
# Arquivo /content/sp_tratado.csv enviado a tratados/sp_tratado.csv.

# %% [markdown]
# ###⬆️ **Envio ao Google Cloud Storage pelo Data Flow(Apache Beam)**

# %% [markdown]
# Fizemos uma demonstração de como funciona o envio do arquivo por meio do Data Flow. O código abaixo cria um modelo de nome 'modelo_batch_sp', que será executado na GCP.

# %%
import apache_beam as beam
import os
from apache_beam.options.pipeline_options import PipelineOptions

# Criando as configurações da Pipeline para conexão com o GCP
pipeline_options = {
    'project':'projeto-final-373521', 
    'runner':'DataflowRunner',
    'region':'southamerica-east1',
    'staging_location':'gs://pipeline-apachebeam/staging/', 
    'temp_location':'gs://pipeline-apachebeam/temp/',
    'template_location':'gs://pipeline-apachebeam/models/modelo_batch_sp'
}

serviceAccount = '/content/projeto-final-373521-25961e56ca37.json'
os.environ['GOOGLE_APPLICATION_CREDENTIALS'] = serviceAccount

# Transformando o dicionário para o tipo de PipelineOption
pipeline_options = PipelineOptions.from_dictionary(pipeline_options)

# Criando a Pipeline com as opções estabelecidas
p1 = beam.Pipeline(options=pipeline_options)

pipe = (
    p1
    |'Abrir arquivo csv'>> beam.io.ReadFromText('gs://projeto-final-agsw/tratados/sp_tratado.csv', skip_header_lines=False)
    |'Separador de dados'>> beam.Map(lambda record: record.split(','))
    |'Load final'>> beam.io.WriteToText('gs://projeto-final-agsw/tratados/sp_tratado_beam',file_name_suffix='.csv')
)

p1.run()
# Out:
#   <style>
#     div.alert {
#       white-space: pre-line;
#     }
#   </style>
#             <link rel="stylesheet" href="https://stackpath.bootstrapcdn.com/bootstrap/4.4.1/css/bootstrap.min.css" integrity="sha384-Vkoo8x4CGsO3+Hhxv8T/Q5PaXtkKtu6ug5TOeNV6gBiFeWPGFN9MuhOf23Q9Ifjh" crossorigin="anonymous">
#             <div class="alert alert-info">No cache_root detected. Defaulting to staging_location gs://pipeline-apachebeam/staging/ for cache location.</div>
# <DataflowPipelineResult None at 0x7f2b84fd25b0>

# %% [markdown]
# ## 📈 **8 - Criando os insigths preliminares**

# %% [markdown]
# ### 🔎 **Realizando Insights**

# %%
# Filtros por coluna

# dfsp_geral.groupby(dfsp_geral['dt_fato']).size().sort_values()
# dfsp_geral['profissao'].unique()
# sorted(dfsp_geral['profissao'].unique())

# Filtros de análise

# ft = dfsp_geral['tipo_pessoa'] == 'Autor/Vítima'
# ft2 = dfsp_geral['dp_circunscricao'] == '077 DP - Santa Cecília'
# dfsp_geral.loc[ft]

# %%
# Insigth 1: Qual o ranking do tipo de crime
case1 = df.groupby(df['tipo_crime']).size().sort_values(ascending=False)
case1.plot.bar(figsize=(12,8),xlabel='Tipo de Crime',
               ylabel='numero de ocorrências', 
               color='#fbc010')

# %%
# Insight 2: Qual o número de ocorrências a cada dia do mês?

# Isolando os dados
dias = list(sorted(df['datahora_fato'].dt.day.unique()))
valores_dia = df.groupby(df['datahora_fato'].dt.day).size()

# Criando novo Data Frame
case2 = pd.DataFrame({'dias': dias, 'total_oc' : valores_dia})

# Setando as variáveis
fig, ax = plt.subplots(figsize = (16,3))
case2.plot('dias', 'total_oc', ax = ax, color ='#fbc010')

# Ajustando o gráfico
ax.set_xticks(range(len(case2['dias'])))
ax.set_xticklabels(case2['dias'])
plt.xlabel('Dias do Mês \n')
plt.ylabel('Número de ocorrências \n')
plt.title('\n Número de ocorrências a cada dia do mês \n')

# Plot
plt.show()

# %%
# Insight 3: Qual a profissão dos homens com maior número de ocorrências?

# Separando por sexo Masculino
fthomem = df['sexo_pessoa'] == 'Masculino'
ftnulo = df['profissao'] != 'NAO INFORMADA'
case3 = df.loc[fthomem & ftnulo]

# Criando novo Data Frame
case3 = case3.groupby(case3['profissao']).size().sort_values(ascending=False).head(5)

# Setando as variáveis
fig, ax = plt.subplots(figsize = (16,8))
case3.plot.bar()

# Ajustando o gráfico
plt.xlabel('Profissão \n')
plt.ylabel('Número de ocorrências \n')
plt.title('\n Profissões com maiores numeros de casos entre os Homens \n')

#Plot
plt.show()

# %%
df
# Out:
#                                     tipo_crime  n_vitimas       datahora_fato  \
# 0                             HOMICÍDIO DOLOSO        1.0 2018-01-06 20:06:00
# 1                             HOMICÍDIO DOLOSO        1.0 2018-01-06 19:00:00
# 2                             HOMICÍDIO DOLOSO        1.0 2018-01-18 18:00:00
# 3                             HOMICÍDIO DOLOSO        1.0 2018-01-02 18:48:00
# 4                             HOMICÍDIO DOLOSO        1.0 2018-01-14 15:00:00
# ...                                        ...        ...                 ...
# 4268  MORTE DECORRENTE DE INTERVENÇÃO POLICIAL        NaN 2021-12-22 01:20:00
# 4269  MORTE DECORRENTE DE INTERVENÇÃO POLICIAL        NaN 2021-12-27 21:15:00
# 4270  MORTE DECORRENTE DE INTERVENÇÃO POLICIAL        NaN 2021-12-29 12:45:00
# 4271  MORTE DECORRENTE DE INTERVENÇÃO POLICIAL        NaN 2021-12-29 23:45:00
# 4272  MORTE DECORRENTE DE INTERVENÇÃO POLICIAL        NaN 2021-12-29 22:52:00
#
#      periodo_ocorrencia   tipo_pessoa sexo_pessoa       dt_nasc_pessoa  \
# 0                 Noite        Vítima   Masculino                  NaT
# 1                 Noite        Vítima   Masculino  1973-06-06 00:00:00
# 2                 Noite        Vítima    Feminino  1958-08-02 00:00:00
# 3                 Noite        Vítima    Feminino  2017-09-16 00:00:00
# 4                 Tarde        Vítima    Feminino                  NaT
# ...                 ...           ...         ...                  ...
# 4268          Madrugada  Autor/Vítima   Masculino  1993-05-19 00:00:00
# 4269              Noite  Autor/Vítima   Masculino  1989-09-29 00:00:00
# 4270              Tarde  Autor/Vítima   Masculino                  NaN
# 4271              Noite  Autor/Vítima   Masculino                  NaN
# 4272              Noite  Autor/Vítima   Masculino  1994-03-16 00:00:00
#
#      idade_pessoa faixa_etaria_pessoa       cor_pele        profissao  \
# 0             NaN        Desconhecido  Não informada              NaN
# 1            44.0               25-44         Branca  CABELEIREIRO(A)
# 2            59.0               45-64          Parda      COMERCIANTE
# 3             0.0                 <18         Branca              NaN
# 4             NaN        Desconhecido  Não informada              NaN
# ...           ...                 ...            ...              ...
# 4268           28               25-44          Parda  DESEMPREGADO(A)
# 4269           32               25-44          Parda         AJUDANTE
# 4270          NaN        Desconhecido          Parda              NaN
# 4271          NaN        Desconhecido         Branca              NaN
# 4272           27               25-44          Parda              NaN
#
#          cidade          dp_circunscricao      tipo_local_fato  \
# 0     São Paulo       002 DP - Bom Retiro          Via Pública
# 1     São Paulo       002 DP - Bom Retiro           Residência
# 2     São Paulo             008 DP - Brás  Comércio e serviços
# 3     São Paulo          078 DP - Jardins           Residência
# 4     São Paulo         017 DP - Ipiranga          Via Pública
# ...         ...                       ...                  ...
# 4268  São Paulo            046 DP - Perus          Via Pública
# 4269  São Paulo        041 DP - Vila Rica          Via Pública
# 4270  São Paulo  069 DP - Teotônio Vilela           Residência
# 4271  São Paulo   003 DP - Campos Elíseos           Hospedagem
# 4272  São Paulo        041 DP - Vila Rica          Via Pública
#
#                                         logradouro n_logradouro  \
# 0                AVENIDA PRESIDENTE CASTELO BRANCO          NaN
# 1     DA VEDAÇÃO DA DIVULGAÇÃO DOS DADOS RELATIVOS          NaN
# 2                                     RUA DA MOOCA          NaN
# 3     DA VEDAÇÃO DA DIVULGAÇÃO DOS DADOS RELATIVOS          NaN
# 4                          RUA DOM MARCOS TEIXEIRA          NaN
# ...                                            ...          ...
# 4268                                 RUA DINAMARCA          NaN
# 4269                            RUA DOS BANQUEIROS          NaN
# 4270  DA VEDAÇÃO DA DIVULGAÇÃO DOS DADOS RELATIVOS          NaN
# 4271                            RUA GENERAL OSORIO          NaN
# 4272                        AVENIDA RIO DAS PEDRAS          NaN
#
#                        latitude_longitude corporacao_policial  \
# 0             -23.523712052,-46.606388286                 NaN
# 1                                     NaN                 NaN
# 2      -23.5538998601755,-46.617413203967                 NaN
# 3                                     NaN                 NaN
# 4     -23.5858762097894,-46.5981945475789                 NaN
# ...                                   ...                 ...
# 4268  -23.4158266352029,-46.7472891521056     Polícia Militar
# 4269  -23.5862357639055,-46.5232831894972     Polícia Militar
# 4270                                  NaN     Polícia Militar
# 4271      -23.5375081569999,-46.641650037     Polícia Militar
# 4272      -23.569583496,-46.5082611879999     Polícia Militar
#
#      situacao_policial
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 4268           serviço
# 4269           serviço
# 4270           serviço
# 4271           serviço
# 4272           serviço
#
# [4161 rows x 19 columns]
